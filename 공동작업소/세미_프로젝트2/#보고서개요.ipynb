# %% [markdown]
# 1. 분석 개요
#     * 분석의 배경 및 목적     - 주제를 선정한 이유와 알고자 하는 내용을 서술
#                                 : 주제선정 이유 :
#                                 : 알고자 하는 내용 :
#
#     * 분석 범위             - 분석의 대상이 되는 표본에 대한 설명
#                                 : 대분류 = 분석의 대상 호텔, 공항, 관광
#                                 : 공항 : '제주공항'으로 한정(고정값)
#                                 : 관광지 : 제주특별자치도 관광공사 제공 공공데이터 사용
#                                 : 호텔 : 제주특별자치도 관광공사 제공 숙박업정보(2022년 데이터) 및
#                                         야놀자,마이리얼트립 크롤링데이터(2023.07.20~2023.07.26/성인2명으로 조건 설정)
# 2. 데이터 구축 및 분석 방법
#     * 분석 프로세스          - 분석 과정 나열 (도표, 순서도 등)
#                                 : <1단계> 제주공항의 위치 데이터 및 시각화
#                                 : <2단계> 관광지명 및 위치 데이터 및 시각화
#                                 : <3단계> 호텔 공공데이터 전처리 및 시각화
#                                 : <4단계> 호텔 크롤링 데이터 전처리 및 병합
#                                 : <5단계> 수집한 데이터들의 상관관계 분석
#
#     * 데이터 수집 및 분석 방법     - 데이터 수집 방법 및 과정
#                                 :순서1. 01_jeju_airport 마크다운 파일
#                                 :순서2. 02_jeju_attraction 마크다운 파일
#                                 :순서3. 03_jeju_hotel 마크다운 파일
#
# 3. 분석결과                 - 표와 시각화 자료 위주 및 간략한 설명
#                                 :01_jeju_airport 마크다운 파일
#                                 :02_jeju_attraction 마크다운 파일
#                                 :03_jeju_hotel 마크다운 파일
#                                  :04_data_analysis 마크다운 파일
#
# 4. 결론                    - 알아낸 사실
#                                 : 소비자의 만족도에 영향을 미치는 요인은 무엇인가?
#                                 : 1) 가격
#                                 : 2) 관광지와의 거리
#                                 : 3) 공항과의 거리
#                                 : 알아낸 사실 결과 도출
# ------------------------------------------------------------
# <1> 제주공항 O
# - 제주공항 folium 시각화
#
# <2> 관광지 :
# - 공공데이터
# 	: 관광지 주소 구하기 -> 전처리 O
# 	: 관광지 -> 행정구역 별 밀집도 SVG시각화
#
# <3> 호텔 :
# - 공공데이터  O
# 	: 제주도 시별 호텔의 수 막대그래프 시각화
# 	: 제주도 숙박 유형별 구분 파이그래프 시각화
# 	: 제주도 숙박 유형별 객실수 분포 hue파라미터(구분:시)를 사용한 막대그래프
#
# - 공공데이터 + 야놀자.마이리얼트립 크롤링데이터 병합 O
# 	: 전처리 O
# 	: 병합한 데이터를 행정구역 별 밀집도 SVG 시각화 O
# 	: 행정구역 별 관광지 svg 지도 시각화와 비교하기
#
# - 소비자의 만족도를 평점이라고 가정
# 	: 만족도의 요인(가격, 제주공항과의 거리, 관광지와의 거리)라고 가정
# 	step1- 호텔의 가격과 평점 데이터 가져오기 (세모. 전처리단계 남음)
# 	step2- 호텔의 평점과 가격의 상관관계 : 평점이 높으면 가격도 높은가?
# 	step3- 호텔의 평점과 제주공항과의 거리와의 관계 : 제주공항과 거리가 가까울 수록 평점이 높은가? O(분석결과 시각화만 하면 된다.)
# 	step4- 호텔의 평점과 관광지와의 거리 상관관계: 관광지와 거리가 가까울 수록 평점이 높은가?
