# %%
'''
def Jeju(start:str="출발지",finish:list="도착지들"):
    import bs4
    import selenium
    import chromedriver_autoinstaller
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.ui import WebDriverWait
    from selenium.webdriver import Chrome
    import time
    from selenium.webdriver.common.keys import Keys
    import datetime as dt
    
    def kakao(x,y):
        driver=Chrome()
        time.sleep(3)
        driver.get('https://map.kakao.com/')
        try:
            need_remove=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".coach_layer.coach_layer_type1 .view_coach"))
            need_remove.click()
        except:
            pass
        path_page=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"search.tab2"))
        path_page.click()
        try:  
            need_remove2=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".layer_body .desc_coach"))
            need_remove2.click()
        except:
            pass
        print("작업준비 끝, 출발지와 도착지(list))를 입력하세요")

        start=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".waypointWindow>input"))
        start.send_keys(Keys.ENTER)
        start.click()
        start2=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".WaypointInput>input"))
        start2.send_keys(x) #출발지 입력
        start2.send_keys(Keys.DOWN)
        start2.send_keys(Keys.ENTER)
        time.sleep(1)

        finish=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"info.route.waypointSuggest.input1"))
        finish.send_keys(y) #도착지 입력
        finish.send_keys(Keys.DOWN)
        finish.send_keys(Keys.ENTER)
        time.sleep(1)

        texi=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"cartab"))
        texi.click()
        print("준비완료")

        soup=bs4.BeautifulSoup(driver.page_source)
        #우리가 원하던 정보(시간,거리,통행료,택시비,주유비) -> contents class 안에 있음.
        #datas=soup.select(".contents")[0]
        #info=dict.fromkeys(['time','distance','toll','taxi','oil'])
        #for key in info:
            #info[key]=datas.select(f".{key}")[0].text
        return soup.select(".contents")
    
    Good={}
    Bad=[]
    for area in finish:
        try:
            Good[area]=kakao(start,area)
        except:
            Bad.append(area)
    return {'Good':Good,"Bad":Bad}'''
# Out:
# '\ndef Jeju(start:str="출발지",finish:list="도착지들"):\n    import bs4\n    import selenium\n    import chromedriver_autoinstaller\n    from selenium.webdriver.common.by import By\n    from selenium.webdriver.support.ui import WebDriverWait\n    from selenium.webdriver import Chrome\n    import time\n    from selenium.webdriver.common.keys import Keys\n    import datetime as dt\n    \n    def kakao(x,y):\n        driver=Chrome()\n        time.sleep(3)\n        driver.get(\'https://map.kakao.com/\')\n        try:\n            need_remove=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".coach_layer.coach_layer_type1 .view_coach"))\n            need_remove.click()\n        except:\n            pass\n        path_page=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"search.tab2"))\n        path_page.click()\n        try:  \n            need_remove2=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".layer_body .desc_coach"))\n            need_remove2.click()\n        except:\n            pass\n        print("작업준비 끝, 출발지와 도착지(list))를 입력하세요")\n\n        start=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".waypointWindow>input"))\n        start.send_keys(Keys.ENTER)\n        start.click()\n        start2=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".WaypointInput>input"))\n        start2.send_keys(x) #출발지 입력\n        start2.send_keys(Keys.DOWN)\n        start2.send_keys(Keys.ENTER)\n        time.sleep(1)\n\n        finish=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"info.route.waypointSuggest.input1"))\n        finish.send_keys(y) #도착지 입력\n        finish.send_keys(Keys.DOWN)\n        finish.send_keys(Keys.ENTER)\n        time.sleep(1)\n\n        texi=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"cartab"))\n        texi.click()\n        print("준비완료")\n\n        soup=bs4.BeautifulSoup(driver.page_source)\n        #우리가 원하던 정보(시간,거리,통행료,택시비,주유비) -> contents class 안에 있음.\n        #datas=soup.select(".contents")[0]\n        #info=dict.fromkeys([\'time\',\'distance\',\'toll\',\'taxi\',\'oil\'])\n        #for key in info:\n            #info[key]=datas.select(f".{key}")[0].text\n        return soup.select(".contents")\n    \n    Good={}\n    Bad=[]\n    for area in finish:\n        try:\n            Good[area]=kakao(start,area)\n        except:\n            Bad.append(area)\n    return {\'Good\':Good,"Bad":Bad}'

# %%
import pandas as pd

# %%
D=pd.read_csv('제주특별자치도_관광숙박업현황_20221122.csv',encoding='euc-kr')
data=pd.DataFrame(D)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 D=pd.read_csv('제주특별자치도_관광숙박업현황_20221122.csv',encoding='euc-kr')
#       2 data=pd.DataFrame(D)
#
# File c:\Users\hanjieun_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\hanjieun_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\hanjieun_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\hanjieun_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\hanjieun_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '제주특별자치도_관광숙박업현황_20221122.csv'

# %%
def KAKAO(START,FINISH):

    import bs4
    import selenium
    import chromedriver_autoinstaller
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.ui import WebDriverWait
    from selenium.webdriver import Chrome
    import time
    from selenium.webdriver.common.keys import Keys
    import datetime as dt

    driver=Chrome()
    time.sleep(3)
    driver.get('https://map.kakao.com/')
    try:
        need_remove=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".coach_layer.coach_layer_type1 .view_coach"))
        need_remove.click()
    except:
        pass
    path_page=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"search.tab2"))
    path_page.click()
    try:  
        need_remove2=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".layer_body .desc_coach"))
        need_remove2.click()
    except:
        pass

    start=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".waypointWindow>input"))
    start.send_keys(Keys.ENTER)
    start.click()
    #_______________________________________________________________#
    start2=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,".WaypointInput>input"))
    start2.send_keys(START) #출발지 입력
    start2.send_keys(Keys.DOWN)
    start2.send_keys(Keys.ENTER)
    time.sleep(1)

    finish=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"info.route.waypointSuggest.input1"))
    finish.send_keys("메가스터디IT 강남점") #도착지 입력
    finish.send_keys(Keys.DOWN)
    finish.send_keys(Keys.ENTER)
    time.sleep(1)

    texi=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"cartab"))
    texi.click()
    print("준비완료")
    #________________________<반복>________________________________________#
    final={}
    for finishs in FINISH:
        try:
            refinish1=WebDriverWait(driver,3).until(lambda x: x.find_element(By.CSS_SELECTOR,"#info .WaypointBoxView.dest .waypointWindow .valueBox"))
            refinish1.click()
            refinish2=WebDriverWait(driver,3).until(lambda x: x.find_element(By.ID,"info.route.waypointSuggest.input1"))
            refinish2.clear()
            refinish2.send_keys(finishs)
            refinish2.send_keys(Keys.ENTER)
            time.sleep(1)
            texi.click()
            time.sleep(1)
            soup=bs4.BeautifulSoup(driver.page_source)
            datas=soup.select(".contents")[0]
            info=dict.fromkeys(['time','distance','toll','taxi','oil'])
            for key in info:
                info[key]=datas.select(f".{key}")[0].text        
            final[finishs]=info
            time.sleep(1)
        except:
            continue
    return final

# %%
# KAKAO("제주공항",["하니크라운호텔","공천포"])

# %%
df = pd.read_excel('./숙박.xlsx')
df.drop('Unnamed: 0',axis=1,inplace=True)
df[351:]
# Out:
#       place_name             address_name
# 351        아시아호텔    제주특별자치도 제주시 노형동 917-8
# 352      힐스테이트제주     제주특별자치도 제주시 연동 263-2
# 353  베스트웨스턴 제주호텔  제주특별자치도 제주시 노형동 1295-16
# 354        빠레브호텔     제주특별자치도 서귀포시 강정동 173
# 355   제주부영호텔앤리조트  제주특별자치도 서귀포시 중문동 2700-2
# ..           ...                      ...
# 637        포시즌호텔      제주특별자치도 제주시 노형동 914
# 638       호텔스카브로    제주특별자치도 서귀포시 하예동 1793
# 639        오로라호텔    제주특별자치도 제주시 내도동 239-1
# 640        호텔더단잠       제주특별자치도 제주시 연동 273
# 641         국제호텔    제주특별자치도 제주시 연동 251-62
#
# [291 rows x 2 columns]

# %%
df[351:]['address_name']
# Out:
# 351      제주특별자치도 제주시 노형동 917-8
# 352       제주특별자치도 제주시 연동 263-2
# 353    제주특별자치도 제주시 노형동 1295-16
# 354       제주특별자치도 서귀포시 강정동 173
# 355    제주특별자치도 서귀포시 중문동 2700-2
#                 ...
# 637        제주특별자치도 제주시 노형동 914
# 638      제주특별자치도 서귀포시 하예동 1793
# 639      제주특별자치도 제주시 내도동 239-1
# 640         제주특별자치도 제주시 연동 273
# 641      제주특별자치도 제주시 연동 251-62
# Name: address_name, Length: 291, dtype: object

# %%
hotel_distance = KAKAO('제주공항',df['address_name'])
hotel_distance
# Out:
# 준비완료
# {'제주특별자치도 제주시 이도일동 1315': {'time': '7시간 2분',
#   'distance': '555.8km',
#   'toll': '통행료 약 22,400원',
#   'taxi': '택시비 약 519,800원',
#   'oil': '주유비 약 67,007원'},
#  '제주특별자치도 제주시 연동 291-30': {'time': '8분',
#   'distance': '2.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,400원',
#   'oil': '주유비 약 424원'},
#  '제주특별자치도 제주시 연동 272-34': {'time': '8분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 468원'},
#  '제주특별자치도 제주시 삼도2동 1192-18': {'time': '8분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 468원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 1201': {'time': '1시간 19분',
#   'distance': '47.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,400원',
#   'oil': '주유비 약 6,984원'},
#  '제주특별자치도 제주시 삼도이동 1197': {'time': '13분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,600원',
#   'oil': '주유비 약 614원'},
#  '제주특별자치도 제주시 연동 260-9': {'time': '9분',
#   'distance': '2.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,400원',
#   'oil': '주유비 약 424원'},
#  '제주특별자치도 제주시 연동 272-29': {'time': '9분',
#   'distance': '3.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,800원',
#   'oil': '주유비 약 453원'},
#  '제주특별자치도 제주시 용담일동 159-1': {'time': '9분',
#   'distance': '3.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 526원'},
#  '제주특별자치도 제주시 삼도이동 57-2': {'time': '11분',
#   'distance': '3.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,200원',
#   'oil': '주유비 약 555원'},
#  '제주특별자치도 제주시 구좌읍 동복리 1652-2': {'time': '49분',
#   'distance': '24.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 22,800원',
#   'oil': '주유비 약 3,521원'},
#  '제주특별자치도 제주시 연동 291-41': {'time': '8분',
#   'distance': '2.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,400원',
#   'oil': '주유비 약 409원'},
#  '제주특별자치도 제주시 애월읍 신엄리 920': {'time': '32분',
#   'distance': '13.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 13,500원',
#   'oil': '주유비 약 2,016원'},
#  '제주특별자치도 제주시 삼도2동 1254': {'time': '12분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 614원'},
#  '제주특별자치도 제주시 조천읍 함덕리 1252-55': {'time': '44분',
#   'distance': '19.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 19,400원',
#   'oil': '주유비 약 2,893원'},
#  '충북 증평군 도안면 연촌리 산 58': {'time': '44분',
#   'distance': '19.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 19,400원',
#   'oil': '주유비 약 2,893원'},
#  '제주특별자치도 제주시 한림읍 협재리 2838': {'time': '6시간 14분',
#   'distance': '463.9km',
#   'toll': '통행료 약 11,100원',
#   'taxi': '택시비 약 431,700원',
#   'oil': '주유비 약 53,579원'},
#  '제주특별자치도 제주시 연동 270-1': {'time': '8분',
#   'distance': '2.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,500원',
#   'oil': '주유비 약 395원'},
#  '제주특별자치도 제주시 이도일동 1244-7': {'time': '16분',
#   'distance': '4.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,500원',
#   'oil': '주유비 약 716원'},
#  '제주특별자치도 제주시 이도이동 1176-11': {'time': '15분',
#   'distance': '4.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,400원',
#   'oil': '주유비 약 687원'},
#  '제주특별자치도 제주시 노형동 912-3': {'time': '11분',
#   'distance': '4.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,400원',
#   'oil': '주유비 약 584원'},
#  '제주특별자치도 제주시 연동 301-3': {'time': '11분',
#   'distance': '4.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,400원',
#   'oil': '주유비 약 584원'},
#  '제주특별자치도 제주시 삼도일동 580-31': {'time': '11분',
#   'distance': '3.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,300원',
#   'oil': '주유비 약 555원'},
#  '제주특별자치도 제주시 용담삼동 2389': {'time': '13분',
#   'distance': '5.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,000원',
#   'oil': '주유비 약 789원'},
#  '제주특별자치도 제주시 연동 251-1': {'time': '9분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,900원',
#   'oil': '주유비 약 468원'},
#  '제주특별자치도 제주시 용담삼동 1161': {'time': '10분',
#   'distance': '4.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,300원',
#   'oil': '주유비 약 643원'},
#  '제주특별자치도 제주시 연동 2324-6': {'time': '8분',
#   'distance': '3.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,400원',
#   'oil': '주유비 약 438원'},
#  '제주특별자치도 제주시 노형동 928-1': {'time': '12분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,700원',
#   'oil': '주유비 약 614원'},
#  '제주특별자치도 제주시 이도이동 1776-14': {'time': '12분',
#   'distance': '4.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,000원',
#   'oil': '주유비 약 701원'},
#  '제주특별자치도 제주시 연동 300-4': {'time': '7분',
#   'distance': '2.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,100원',
#   'oil': '주유비 약 351원'},
#  '서울 종로구 낙원동 142': {'time': '7분',
#   'distance': '2.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,100원',
#   'oil': '주유비 약 351원'},
#  '제주특별자치도 서귀포시 안덕면 서광리 산 41': {'time': '49분',
#   'distance': '33.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 29,400원',
#   'oil': '주유비 약 4,953원'},
#  '제주특별자치도 제주시 내도동 15-1': {'time': '15분',
#   'distance': '6.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,800원',
#   'oil': '주유비 약 920원'},
#  '제주특별자치도 제주시 용담삼동 2555': {'time': '15분',
#   'distance': '7.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,500원',
#   'oil': '주유비 약 1,052원'},
#  '제주특별자치도 제주시 애월읍 고내리 77-4': {'time': '37분',
#   'distance': '16.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,800원',
#   'oil': '주유비 약 2,425원'},
#  '제주특별자치도 제주시 외도일동 401-8': {'time': '18분',
#   'distance': '7.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,900원',
#   'oil': '주유비 약 1,125원'},
#  '제주특별자치도 제주시 연동 261-25': {'time': '9분',
#   'distance': '3.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 482원'},
#  '제주특별자치도 제주시 연동 306-14': {'time': '12분',
#   'distance': '3.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 541원'},
#  '제주특별자치도 제주시 삼도일동 535-10': {'time': '11분',
#   'distance': '4.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,600원',
#   'oil': '주유비 약 628원'},
#  '제주특별자치도 제주시 건입동 658-1': {'time': '18분',
#   'distance': '7.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,700원',
#   'oil': '주유비 약 1,023원'},
#  '제주특별자치도 제주시 연동 251-79': {'time': '10분',
#   'distance': '3.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 497원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2735-1': {'time': '35분',
#   'distance': '15.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,700원',
#   'oil': '주유비 약 2,221원'},
#  '제주특별자치도 제주시 애월읍 구엄리 1216': {'time': '34분',
#   'distance': '14.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 13,900원',
#   'oil': '주유비 약 2,075원'},
#  '제주특별자치도 제주시 삼도일동 559-10': {'time': '14분',
#   'distance': '5.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,700원',
#   'oil': '주유비 약 774원'},
#  '제주특별자치도 제주시 연동 274-16': {'time': '11분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,200원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 용담일동 183-2': {'time': '10분',
#   'distance': '3.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 541원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2736-1': {'time': '35분',
#   'distance': '15.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,700원',
#   'oil': '주유비 약 2,221원'},
#  '제주특별자치도 제주시 연동 261-3': {'time': '9분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 468원'},
#  '제주특별자치도 제주시 도두일동 2272-2': {'time': '10분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 614원'},
#  '제주특별자치도 제주시 연동 279-3': {'time': '13분',
#   'distance': '4.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,800원',
#   'oil': '주유비 약 584원'},
#  '제주특별자치도 제주시 내도동 277-1': {'time': '13분',
#   'distance': '4.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,800원',
#   'oil': '주유비 약 584원'},
#  '제주특별자치도 제주시 건입동 1037-1': {'time': '22분',
#   'distance': '7.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,200원',
#   'oil': '주유비 약 1,023원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2732': {'time': '28분',
#   'distance': '11.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 11,900원',
#   'oil': '주유비 약 1,709원'},
#  '제주특별자치도 제주시 연동 272-26': {'time': '10분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 468원'},
#  '제주특별자치도 제주시 연동 292-27': {'time': '10분',
#   'distance': '3.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,200원',
#   'oil': '주유비 약 497원'},
#  '제주특별자치도 제주시 애월읍 하귀1리 544-2': {'time': '25분',
#   'distance': '9.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 10,300원',
#   'oil': '주유비 약 1,417원'},
#  '경기 남양주시 별내동 2184-11': {'time': '25분',
#   'distance': '9.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 10,300원',
#   'oil': '주유비 약 1,417원'},
#  '제주특별자치도 제주시 조천읍 함덕리 3230-1': {'time': '43분',
#   'distance': '20.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 19,500원',
#   'oil': '주유비 약 2,966원'},
#  '제주특별자치도 제주시 오등동 10-1': {'time': '25분',
#   'distance': '11.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 11,500원',
#   'oil': '주유비 약 1,680원'},
#  '제주특별자치도 제주시 이도이동 1174-1': {'time': '14분',
#   'distance': '4.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,400원',
#   'oil': '주유비 약 701원'},
#  '제주특별자치도 제주시 노형동 2488-1': {'time': '15분',
#   'distance': '4.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,000원',
#   'oil': '주유비 약 716원'},
#  '제주특별자치도 제주시 용담이동 2761': {'time': '6분',
#   'distance': '2.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 3,500원',
#   'oil': '주유비 약 307원'},
#  '제주특별자치도 제주시 연동 2334-4': {'time': '7분',
#   'distance': '2.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,400원',
#   'oil': '주유비 약 380원'},
#  '제주특별자치도 제주시 애월읍 고내리 84': {'time': '38분',
#   'distance': '17.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 16,400원',
#   'oil': '주유비 약 2,528원'},
#  '제주특별자치도 제주시 노형동 925': {'time': '11분',
#   'distance': '4.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,900원',
#   'oil': '주유비 약 599원'},
#  '제주특별자치도 제주시 한림읍 옹포리 393': {'time': '1시간 3분',
#   'distance': '28.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 25,500원',
#   'oil': '주유비 약 4,120원'},
#  '제주특별자치도 제주시 조천읍 교래리 385-1': {'time': '47분',
#   'distance': '28.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 25,000원',
#   'oil': '주유비 약 4,106원'},
#  '제주특별자치도 서귀포시 색달동 3039-3': {'time': '57분',
#   'distance': '39.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,500원',
#   'oil': '주유비 약 5,815원'},
#  '제주특별자치도 서귀포시 색달동 2812-4': {'time': '57분',
#   'distance': '39.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,400원',
#   'oil': '주유비 약 5,786원'},
#  '제주특별자치도 서귀포시 색달동 3039-1': {'time': '58분',
#   'distance': '40.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,800원',
#   'oil': '주유비 약 5,874원'},
#  '제주특별자치도 서귀포시 토평동 486-3': {'time': '1시간 9분',
#   'distance': '42.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,900원',
#   'oil': '주유비 약 6,195원'},
#  '제주특별자치도 서귀포시 표선면 표선리 40-69': {'time': '1시간 12분',
#   'distance': '49.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,600원',
#   'oil': '주유비 약 7,159원'},
#  '제주특별자치도 서귀포시 회수동 30': {'time': '57분',
#   'distance': '39.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,000원',
#   'oil': '주유비 약 5,786원'},
#  '제주특별자치도 서귀포시 서귀동 314-2': {'time': '1시간 11분',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,341원'},
#  '제주특별자치도 서귀포시 서귀동 820-1': {'time': '1시간 12분',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,800원',
#   'oil': '주유비 약 6,341원'},
#  '제주특별자치도 서귀포시 서귀동 316-4': {'time': '1시간 11분',
#   'distance': '43.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,327원'},
#  '제주특별자치도 서귀포시 서귀동 411-13': {'time': '1시간 11분',
#   'distance': '42.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,400원',
#   'oil': '주유비 약 6,268원'},
#  '제주특별자치도 서귀포시 안덕면 상창리 2893': {'time': '1시간 11분',
#   'distance': '42.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,400원',
#   'oil': '주유비 약 6,268원'},
#  '제주특별자치도 서귀포시 남원읍 수망리 628-8': {'time': '58분',
#   'distance': '35.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 30,400원',
#   'oil': '주유비 약 5,187원'},
#  '제주특별자치도 서귀포시 서귀동 776-1': {'time': '1시간 12분',
#   'distance': '43.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,312원'},
#  '제주특별자치도 서귀포시 강정동 160-2': {'time': '1시간 4분',
#   'distance': '48.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,600원',
#   'oil': '주유비 약 7,013원'},
#  '제주특별자치도 서귀포시 강정동 173': {'time': '1시간 4분',
#   'distance': '48.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,600원',
#   'oil': '주유비 약 7,013원'},
#  '제주특별자치도 서귀포시 하예동 1793': {'time': '1시간 1분',
#   'distance': '40.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,300원',
#   'oil': '주유비 약 5,844원'},
#  '제주특별자치도 서귀포시 색달동 2508': {'time': '1시간 1분',
#   'distance': '40.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,300원',
#   'oil': '주유비 약 5,844원'},
#  '경기 김포시 구래동 6883-8': {'time': '49분',
#   'distance': '33.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 29,400원',
#   'oil': '주유비 약 4,953원'},
#  '제주특별자치도 서귀포시 서홍동 586': {'time': '1시간 14분',
#   'distance': '44.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,600원',
#   'oil': '주유비 약 6,487원'},
#  '제주특별자치도 서귀포시 서귀동 782-3': {'time': '1시간 12분',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,800원',
#   'oil': '주유비 약 6,341원'},
#  '제주특별자치도 서귀포시 중문동 2115-1': {'time': '1시간 12분',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,800원',
#   'oil': '주유비 약 6,341원'},
#  '제주특별자치도 서귀포시 중문동 2700-2': {'time': '57분',
#   'distance': '42.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,000원',
#   'oil': '주유비 약 6,151원'},
#  '제주특별자치도 서귀포시 서귀동 777-1': {'time': '1시간 12분',
#   'distance': '43.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,327원'},
#  '제주특별자치도 서귀포시 대포동 2538': {'time': '58분',
#   'distance': '42.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,500원',
#   'oil': '주유비 약 6,239원'},
#  '제주특별자치도 서귀포시 표선면 표선리 591-1': {'time': '1시간 9분',
#   'distance': '44.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 38,300원',
#   'oil': '주유비 약 6,458원'},
#  '제주특별자치도 서귀포시 중문동 2129-2': {'time': '54분',
#   'distance': '40.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,800원',
#   'oil': '주유비 약 5,947원'},
#  '제주특별자치도 서귀포시 하예동 460-1': {'time': '58분',
#   'distance': '40.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,400원',
#   'oil': '주유비 약 5,976원'},
#  '제주특별자치도 제주시 삼도이동 1053-15': {'time': '12분',
#   'distance': '4.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 584원'},
#  '제주특별자치도 서귀포시 상예동 625': {'time': '56분',
#   'distance': '39.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,500원',
#   'oil': '주유비 약 5,801원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 169-16': {'time': '1시간 22분',
#   'distance': '51.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 43,600원',
#   'oil': '주유비 약 7,452원'},
#  '제주특별자치도 서귀포시 색달동 2138': {'time': '53분',
#   'distance': '37.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,900원',
#   'oil': '주유비 약 5,508원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 297-1': {'time': '1시간 20분',
#   'distance': '49.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,300원',
#   'oil': '주유비 약 7,203원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 437-1': {'time': '1시간 20분',
#   'distance': '49.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,400원',
#   'oil': '주유비 약 7,218원'},
#  '제주특별자치도 서귀포시 안덕면 서광리 산 24': {'time': '46분',
#   'distance': '31.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 27,200원',
#   'oil': '주유비 약 4,544원'},
#  '제주특별자치도 서귀포시 색달동 2284-1': {'time': '51분',
#   'distance': '38.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,900원',
#   'oil': '주유비 약 5,611원'},
#  '제주특별자치도 제주시 구좌읍 동복리 827': {'time': '50분',
#   'distance': '25.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 23,200원',
#   'oil': '주유비 약 3,711원'},
#  '제주특별자치도 제주시 용담삼동 1020-4': {'time': '9분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,500원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 애월읍 고내리 79-8': {'time': '38분',
#   'distance': '17.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 16,200원',
#   'oil': '주유비 약 2,528원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2867-3': {'time': '38분',
#   'distance': '16.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,700원',
#   'oil': '주유비 약 2,425원'},
#  '제주특별자치도 제주시 노형동 1295-16': {'time': '10분',
#   'distance': '3.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,300원',
#   'oil': '주유비 약 526원'},
#  '제주특별자치도 제주시 도두일동 1742': {'time': '13분',
#   'distance': '5.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,300원',
#   'oil': '주유비 약 833원'},
#  '제주특별자치도 제주시 해안동 2109': {'time': '23분',
#   'distance': '8.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,900원',
#   'oil': '주유비 약 1,169원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2768-7': {'time': '36분',
#   'distance': '15.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,000원',
#   'oil': '주유비 약 2,309원'},
#  '제주특별자치도 제주시 한림읍 금능리 2005': {'time': '1시간 7분',
#   'distance': '34.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 29,900원',
#   'oil': '주유비 약 4,997원'},
#  '제주특별자치도 제주시 해안동 2101-3': {'time': '23분',
#   'distance': '8.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 9,000원',
#   'oil': '주유비 약 1,198원'},
#  '제주특별자치도 제주시 용담이동 1783-1': {'time': '6분',
#   'distance': '2.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,000원',
#   'oil': '주유비 약 351원'},
#  '제주특별자치도 제주시 한림읍 협재리 876-3': {'time': '6분',
#   'distance': '2.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,000원',
#   'oil': '주유비 약 351원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2946-4': {'time': '1시간 3분',
#   'distance': '31.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 27,500원',
#   'oil': '주유비 약 4,559원'},
#  '제주특별자치도 제주시 애월읍 고내리 332-1': {'time': '37분',
#   'distance': '16.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,800원',
#   'oil': '주유비 약 2,455원'},
#  '제주특별자치도 제주시 도두일동 1798-6': {'time': '13분',
#   'distance': '5.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,200원',
#   'oil': '주유비 약 818원'},
#  '제주특별자치도 제주시 애월읍 하가리 1256-2': {'time': '37분',
#   'distance': '16.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,900원',
#   'oil': '주유비 약 2,469원'},
#  '제주특별자치도 제주시 한림읍 협재리 1398': {'time': '1시간 4분',
#   'distance': '31.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 27,400원',
#   'oil': '주유비 약 4,544원'},
#  '제주특별자치도 제주시 한림읍 귀덕리 3646': {'time': '53분',
#   'distance': '24.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 22,000원',
#   'oil': '주유비 약 3,536원'},
#  '제주특별자치도 제주시 한림읍 협재리 2514-2': {'time': '1시간 4분',
#   'distance': '31.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 27,400원',
#   'oil': '주유비 약 4,529원'},
#  '제주특별자치도 서귀포시 대정읍 상모리 74': {'time': '1시간 3분',
#   'distance': '44.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,500원',
#   'oil': '주유비 약 6,531원'},
#  '제주특별자치도 서귀포시 대포동 1181': {'time': '59분',
#   'distance': '42.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,500원',
#   'oil': '주유비 약 6,151원'},
#  '제주특별자치도 서귀포시 대포동 1266-1': {'time': '1시간 2분',
#   'distance': '44.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,200원',
#   'oil': '주유비 약 6,458원'},
#  '제주특별자치도 서귀포시 색달동 1821-3': {'time': '51분',
#   'distance': '38.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,700원',
#   'oil': '주유비 약 5,640원'},
#  '제주특별자치도 서귀포시 대포동 342-2': {'time': '51분',
#   'distance': '38.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,700원',
#   'oil': '주유비 약 5,640원'},
#  '제주특별자치도 서귀포시 안덕면 화순리 1888': {'time': '53분',
#   'distance': '36.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,000원',
#   'oil': '주유비 약 5,348원'},
#  '제주특별자치도 서귀포시 성산읍 오조리 941-1': {'time': '1시간 25분',
#   'distance': '47.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,900원',
#   'oil': '주유비 약 6,984원'},
#  '제주특별자치도 서귀포시 성산읍 시흥리 5': {'time': '1시간 28분',
#   'distance': '49.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,400원',
#   'oil': '주유비 약 7,262원'},
#  '제주특별자치도 서귀포시 성산읍 수산리 2576': {'time': '1시간 10분',
#   'distance': '46.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,400원',
#   'oil': '주유비 약 6,765원'},
#  '제주특별자치도 서귀포시 성산읍 시흥리 208': {'time': '1시간 10분',
#   'distance': '46.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,400원',
#   'oil': '주유비 약 6,765원'},
#  '제주특별자치도 서귀포시 법환동 1498': {'time': '1시간 28분',
#   'distance': '49.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,300원',
#   'oil': '주유비 약 7,232원'},
#  '제주특별자치도 서귀포시 강정동 3702-1': {'time': '1시간 1분',
#   'distance': '44.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,500원',
#   'oil': '주유비 약 6,531원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 1090-16': {'time': '1시간 1분',
#   'distance': '44.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,500원',
#   'oil': '주유비 약 6,531원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 382-31': {'time': '1시간 23분',
#   'distance': '50.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 43,200원',
#   'oil': '주유비 약 7,364원'},
#  '제주특별자치도 서귀포시 성산읍 시흥리 200': {'time': '1시간 28분',
#   'distance': '49.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,700원',
#   'oil': '주유비 약 7,232원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 382-6': {'time': '1시간 23분',
#   'distance': '50.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 43,200원',
#   'oil': '주유비 약 7,379원'},
#  '제주특별자치도 서귀포시 색달동 1622-2': {'time': '54분',
#   'distance': '39.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,500원',
#   'oil': '주유비 약 5,801원'},
#  '제주특별자치도 서귀포시 서귀동 308-2': {'time': '54분',
#   'distance': '39.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,500원',
#   'oil': '주유비 약 5,801원'},
#  '제주특별자치도 서귀포시 성산읍 오조리 990-1': {'time': '1시간 25분',
#   'distance': '48.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,700원',
#   'oil': '주유비 약 7,072원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 510-6': {'time': '1시간 23분',
#   'distance': '53.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 45,000원',
#   'oil': '주유비 약 7,788원'},
#  '제주특별자치도 서귀포시 토평동 237-2': {'time': '1시간 8분',
#   'distance': '42.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,200원',
#   'oil': '주유비 약 6,166원'},
#  '제주특별자치도 서귀포시 대정읍 안성리 214': {'time': '54분',
#   'distance': '38.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,500원',
#   'oil': '주유비 약 5,581원'},
#  '제주특별자치도 제주시 외도이동 338-1': {'time': '20분',
#   'distance': '7.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,300원',
#   'oil': '주유비 약 1,067원'},
#  '제주특별자치도 제주시 용담삼동 1181-3': {'time': '12분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 614원'},
#  '제주특별자치도 제주시 이호일동 295-1': {'time': '14분',
#   'distance': '5.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,400원',
#   'oil': '주유비 약 774원'},
#  '제주특별자치도 제주시 이호일동 365': {'time': '15분',
#   'distance': '6.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,200원',
#   'oil': '주유비 약 935원'},
#  '제주특별자치도 제주시 애월읍 곽지리 1565-18': {'time': '47분',
#   'distance': '21.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 20,100원',
#   'oil': '주유비 약 3,083원'},
#  '제주특별자치도 제주시 연동 261-67': {'time': '10분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,700원',
#   'oil': '주유비 약 468원'},
#  '제주특별자치도 제주시 용담삼동 2382': {'time': '12분',
#   'distance': '5.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,600원',
#   'oil': '주유비 약 731원'},
#  '제주특별자치도 제주시 연동 292-17': {'time': '8분',
#   'distance': '3.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 453원'},
#  '제주특별자치도 제주시 한림읍 협재리 964-1': {'time': '8분',
#   'distance': '3.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 453원'},
#  '경기 과천시 별양동 14': {'time': '1시간 4분',
#   'distance': '31.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 28,100원',
#   'oil': '주유비 약 4,544원'},
#  '서울 강남구 역삼동 633-31': {'time': '1시간 4분',
#   'distance': '31.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 28,100원',
#   'oil': '주유비 약 4,544원'},
#  '제주특별자치도 제주시 애월읍 유수암리 617-1': {'time': '34분',
#   'distance': '13.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,900원',
#   'oil': '주유비 약 1,987원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2869-10': {'time': '29분',
#   'distance': '11.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 12,200원',
#   'oil': '주유비 약 1,666원'},
#  '제주특별자치도 제주시 용담삼동 2342-2': {'time': '13분',
#   'distance': '5.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,000원',
#   'oil': '주유비 약 789원'},
#  '제주특별자치도 제주시 이호일동 363': {'time': '15분',
#   'distance': '6.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,100원',
#   'oil': '주유비 약 906원'},
#  '제주특별자치도 제주시 이도1동 1782-1': {'time': '14분',
#   'distance': '4.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 672원'},
#  '제주특별자치도 제주시 연동 284-6': {'time': '9분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 노형동 310-2': {'time': '9분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2707-2': {'time': '30분',
#   'distance': '12.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 12,900원',
#   'oil': '주유비 약 1,797원'},
#  '충남 태안군 안면읍 승언리 1944-27': {'time': '5시간 50분',
#   'distance': '426.2km',
#   'toll': '통행료 약 10,900원',
#   'taxi': '택시비 약 396,000원',
#   'oil': '주유비 약 48,071원'},
#  '제주특별자치도 제주시 도두일동 2614-5': {'time': '14분',
#   'distance': '6.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,100원',
#   'oil': '주유비 약 906원'},
#  '제주특별자치도 제주시 애월읍 애월리 1229-3': {'time': '42분',
#   'distance': '19.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 18,600원',
#   'oil': '주유비 약 2,849원'},
#  '제주특별자치도 제주시 애월읍 하가리 120-50': {'time': '40분',
#   'distance': '16.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 17,300원',
#   'oil': '주유비 약 2,425원'},
#  '제주특별자치도 제주시 이호일동 325': {'time': '16분',
#   'distance': '7.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,200원',
#   'oil': '주유비 약 1,110원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2615-8': {'time': '30분',
#   'distance': '11.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 12,600원',
#   'oil': '주유비 약 1,739원'},
#  '제주특별자치도 제주시 이호일동 328-4': {'time': '15분',
#   'distance': '6.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,100원',
#   'oil': '주유비 약 906원'},
#  '제주특별자치도 제주시 애월읍 고내리 1105-1': {'time': '41분',
#   'distance': '19.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 18,300원',
#   'oil': '주유비 약 2,791원'},
#  '제주특별자치도 제주시 애월읍 구엄리 941': {'time': '32분',
#   'distance': '13.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,100원',
#   'oil': '주유비 약 2,016원'},
#  '제주특별자치도 제주시 삼도일동 558-5': {'time': '32분',
#   'distance': '13.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,100원',
#   'oil': '주유비 약 2,016원'},
#  '제주특별자치도 제주시 용담삼동 2383-1': {'time': '12분',
#   'distance': '5.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,600원',
#   'oil': '주유비 약 731원'},
#  '제주특별자치도 제주시 노형동 1288-4': {'time': '13분',
#   'distance': '4.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,100원',
#   'oil': '주유비 약 599원'},
#  '제주특별자치도 제주시 한림읍 귀덕리 721-1': {'time': '52분',
#   'distance': '24.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 22,200원',
#   'oil': '주유비 약 3,521원'},
#  '제주특별자치도 제주시 연동 273-54': {'time': '9분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,700원',
#   'oil': '주유비 약 511원'},
#  '서울 중구 을지로2가 199-13': {'time': '9분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,700원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 이도이동 1010': {'time': '14분',
#   'distance': '4.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,700원',
#   'oil': '주유비 약 687원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2749-3': {'time': '30분',
#   'distance': '12.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 13,000원',
#   'oil': '주유비 약 1,826원'},
#  '제주특별자치도 제주시 한림읍 금능리 1803-2': {'time': '1시간 8분',
#   'distance': '34.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 30,300원',
#   'oil': '주유비 약 4,997원'},
#  '제주특별자치도 제주시 용담삼동 2572': {'time': '17분',
#   'distance': '8.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,600원',
#   'oil': '주유비 약 1,183원'},
#  '제주특별자치도 제주시 용담2동 2678-10': {'time': '8분',
#   'distance': '2.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 3,800원',
#   'oil': '주유비 약 395원'},
#  '제주특별자치도 제주시 애월읍 고내리 1159': {'time': '40분',
#   'distance': '18.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 17,800원',
#   'oil': '주유비 약 2,718원'},
#  '제주특별자치도 제주시 도두이동 680': {'time': '17분',
#   'distance': '7.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,400원',
#   'oil': '주유비 약 1,154원'},
#  '제주특별자치도 제주시 일도일동 1331-1': {'time': '18분',
#   'distance': '4.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,400원',
#   'oil': '주유비 약 716원'},
#  '제주특별자치도 제주시 구좌읍 평대리 3350-13': {'time': '1시간 12분',
#   'distance': '38.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,300원',
#   'oil': '주유비 약 5,625원'},
#  '경기 평택시 청룡동 397-36': {'time': '6시간 11분',
#   'distance': '489.2km',
#   'toll': '통행료 약 16,900원',
#   'taxi': '택시비 약 455,600원',
#   'oil': '주유비 약 57,276원'},
#  '제주특별자치도 서귀포시 보목동 1569': {'time': '1시간 12분',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,100원',
#   'oil': '주유비 약 6,341원'}}

# %%
with open("일단저장2.txt","w",encoding="utf-8") as f:
    f.write(str(hotel_distance))

# %%
# 원본유지!
# hotel_distance = KAKAO('제주공항',df['address_name'])
# hotel_distance
# Out:
# 준비완료
# {'제주특별자치도 제주시 이도일동 1315': {'time': '6시간 37분',
#   'distance': '535.5km',
#   'toll': '통행료 약 16,700원',
#   'taxi': '택시비 약 557,900원',
#   'oil': '주유비 약 64,000원'},
#  '제주특별자치도 제주시 연동 291-30': {'time': '7분',
#   'distance': '3.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,200원',
#   'oil': '주유비 약 438원'},
#  '제주특별자치도 제주시 연동 272-34': {'time': '10분',
#   'distance': '3.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,800원',
#   'oil': '주유비 약 482원'},
#  '제주특별자치도 제주시 삼도2동 1192-18': {'time': '10분',
#   'distance': '4.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,200원',
#   'oil': '주유비 약 628원'},
#  '제주특별자치도 제주시 연동 277-1': {'time': '12분',
#   'distance': '4.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 584원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 1201': {'time': '1시간 4분',
#   'distance': '47.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,900원',
#   'oil': '주유비 약 6,980원'},
#  '제주특별자치도 제주시 삼도이동 1197': {'time': '10분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 613원'},
#  '제주특별자치도 제주시 연동 260-9': {'time': '8분',
#   'distance': '2.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,400원',
#   'oil': '주유비 약 423원'},
#  '제주특별자치도 제주시 연동 272-29': {'time': '9분',
#   'distance': '3.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,700원',
#   'oil': '주유비 약 453원'},
#  '제주특별자치도 제주시 용담일동 159-1': {'time': '8분',
#   'distance': '3.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 526원'},
#  '제주특별자치도 제주시 삼도이동 57-2': {'time': '9분',
#   'distance': '3.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,800원',
#   'oil': '주유비 약 555원'},
#  '제주특별자치도 제주시 구좌읍 동복리 1652-2': {'time': '39분',
#   'distance': '23.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 20,300원',
#   'oil': '주유비 약 3,373원'},
#  '제주특별자치도 제주시 연동 291-41': {'time': '8분',
#   'distance': '2.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,200원',
#   'oil': '주유비 약 409원'},
#  '제주특별자치도 제주시 애월읍 신엄리 920': {'time': '25분',
#   'distance': '13.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 12,700원',
#   'oil': '주유비 약 2,015원'},
#  '제주특별자치도 제주시 삼도2동 1254': {'time': '9분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 613원'},
#  '제주특별자치도 제주시 조천읍 함덕리 1252-55': {'time': '35분',
#   'distance': '19.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 17,400원',
#   'oil': '주유비 약 2,833원'},
#  '충북 증평군 도안면 연촌리 산 58': {'time': '6시간 14분',
#   'distance': '463.7km',
#   'toll': '통행료 약 10,600원',
#   'taxi': '택시비 약 481,400원',
#   'oil': '주유비 약 53,516원'},
#  '제주특별자치도 제주시 한림읍 협재리 2838': {'time': '50분',
#   'distance': '32.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 27,800원',
#   'oil': '주유비 약 4,789원'},
#  '제주특별자치도 제주시 연동 270-1': {'time': '7분',
#   'distance': '2.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,000원',
#   'oil': '주유비 약 394원'},
#  '제주특별자치도 제주시 이도일동 1244-7': {'time': '14분',
#   'distance': '5.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,300원',
#   'oil': '주유비 약 803원'},
#  '제주특별자치도 제주시 이도이동 1176-11': {'time': '12분',
#   'distance': '4.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,700원',
#   'oil': '주유비 약 686원'},
#  '제주특별자치도 제주시 노형동 912-3': {'time': '10분',
#   'distance': '4.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 599원'},
#  '제주특별자치도 제주시 연동 301-3': {'time': '7분',
#   'distance': '2.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,000원',
#   'oil': '주유비 약 380원'},
#  '제주특별자치도 제주시 삼도일동 580-31': {'time': '9분',
#   'distance': '3.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,800원',
#   'oil': '주유비 약 555원'},
#  '제주특별자치도 제주시 용담삼동 2389': {'time': '11분',
#   'distance': '5.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,200원',
#   'oil': '주유비 약 789원'},
#  '제주특별자치도 제주시 연동 251-1': {'time': '8분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 467원'},
#  '제주특별자치도 제주시 용담삼동 1161': {'time': '9분',
#   'distance': '4.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,200원',
#   'oil': '주유비 약 642원'},
#  '제주특별자치도 제주시 연동 2324-6': {'time': '6분',
#   'distance': '3.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,100원',
#   'oil': '주유비 약 438원'},
#  '제주특별자치도 제주시 노형동 928-1': {'time': '10분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 613원'},
#  '제주특별자치도 제주시 이도이동 1776-14': {'time': '10분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 613원'},
#  '제주특별자치도 제주시 연동 300-4': {'time': '7분',
#   'distance': '2.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 3,900원',
#   'oil': '주유비 약 350원'},
#  '서울 종로구 낙원동 142': {'time': '7분',
#   'distance': '2.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 3,900원',
#   'oil': '주유비 약 350원'},
#  '제주특별자치도 서귀포시 안덕면 서광리 산 41': {'time': '40분',
#   'distance': '35.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 30,500원',
#   'oil': '주유비 약 5,213원'},
#  '제주특별자치도 제주시 내도동 15-1': {'time': '12분',
#   'distance': '6.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,800원',
#   'oil': '주유비 약 920원'},
#  '제주특별자치도 제주시 용담삼동 2555': {'time': '13분',
#   'distance': '7.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,500원',
#   'oil': '주유비 약 1,051원'},
#  '제주특별자치도 제주시 애월읍 고내리 77-4': {'time': '29분',
#   'distance': '16.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,000원',
#   'oil': '주유비 약 2,424원'},
#  '제주특별자치도 제주시 외도일동 401-8': {'time': '15분',
#   'distance': '7.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,900원',
#   'oil': '주유비 약 1,124원'},
#  '제주특별자치도 제주시 연동 261-25': {'time': '9분',
#   'distance': '3.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 453원'},
#  '제주특별자치도 제주시 연동 306-14': {'time': '12분',
#   'distance': '3.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,600원',
#   'oil': '주유비 약 540원'},
#  '제주특별자치도 제주시 삼도일동 535-10': {'time': '9분',
#   'distance': '3.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,900원',
#   'oil': '주유비 약 540원'},
#  '제주특별자치도 제주시 건입동 658-1': {'time': '16분',
#   'distance': '5.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,700원',
#   'oil': '주유비 약 862원'},
#  '제주특별자치도 제주시 연동 251-79': {'time': '10분',
#   'distance': '3.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,300원',
#   'oil': '주유비 약 496원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2735-1': {'time': '27분',
#   'distance': '15.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 13,900원',
#   'oil': '주유비 약 2,219원'},
#  '제주특별자치도 제주시 애월읍 구엄리 1216': {'time': '26분',
#   'distance': '14.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 13,100원',
#   'oil': '주유비 약 2,073원'},
#  '제주특별자치도 제주시 삼도일동 559-10': {'time': '12분',
#   'distance': '4.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,900원',
#   'oil': '주유비 약 701원'},
#  '제주특별자치도 제주시 연동 274-16': {'time': '11분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,300원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 용담일동 183-2': {'time': '8분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,300원',
#   'oil': '주유비 약 467원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2736-1': {'time': '27분',
#   'distance': '15.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 13,800원',
#   'oil': '주유비 약 2,219원'},
#  '제주특별자치도 제주시 연동 261-3': {'time': '11분',
#   'distance': '3.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 496원'},
#  '제주특별자치도 제주시 도두일동 2272-2': {'time': '8분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 613원'},
#  '제주특별자치도 제주시 연동 279-3': {'time': '12분',
#   'distance': '4.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,800원',
#   'oil': '주유비 약 584원'},
#  '제주특별자치도 제주시 내도동 277-1': {'time': '12분',
#   'distance': '6.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,800원',
#   'oil': '주유비 약 920원'},
#  '제주특별자치도 제주시 건입동 1037-1': {'time': '15분',
#   'distance': '6.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,200원',
#   'oil': '주유비 약 993원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2732': {'time': '21분',
#   'distance': '11.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 11,100원',
#   'oil': '주유비 약 1,708원'},
#  '제주특별자치도 제주시 연동 272-26': {'time': '9분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,800원',
#   'oil': '주유비 약 467원'},
#  '제주특별자치도 제주시 연동 292-27': {'time': '9분',
#   'distance': '3.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 496원'},
#  '제주특별자치도 제주시 애월읍 하귀1리 544-2': {'time': '18분',
#   'distance': '9.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 9,500원',
#   'oil': '주유비 약 1,416원'},
#  '경기 남양주시 별내동 2184-11': {'time': '18분',
#   'distance': '9.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 9,500원',
#   'oil': '주유비 약 1,416원'},
#  '제주특별자치도 제주시 조천읍 함덕리 3230-1': {'time': '36분',
#   'distance': '19.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 17,600원',
#   'oil': '주유비 약 2,847원'},
#  '제주특별자치도 제주시 오등동 10-1': {'time': '23분',
#   'distance': '12.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 11,400원',
#   'oil': '주유비 약 1,767원'},
#  '제주특별자치도 제주시 이도이동 1174-1': {'time': '12분',
#   'distance': '4.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,000원',
#   'oil': '주유비 약 701원'},
#  '제주특별자치도 제주시 노형동 2488-1': {'time': '12분',
#   'distance': '4.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,300원',
#   'oil': '주유비 약 715원'},
#  '제주특별자치도 제주시 용담이동 2761': {'time': '5분',
#   'distance': '2.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 3,500원',
#   'oil': '주유비 약 307원'},
#  '제주특별자치도 제주시 연동 2334-4': {'time': '7분',
#   'distance': '2.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,300원',
#   'oil': '주유비 약 380원'},
#  '제주특별자치도 제주시 애월읍 고내리 84': {'time': '30분',
#   'distance': '17.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,600원',
#   'oil': '주유비 약 2,526원'},
#  '제주특별자치도 제주시 노형동 925': {'time': '10분',
#   'distance': '4.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 599원'},
#  '제주특별자치도 제주시 한림읍 옹포리 393': {'time': '44분',
#   'distance': '28.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 24,200원',
#   'oil': '주유비 약 4,118원'},
#  '제주특별자치도 제주시 조천읍 교래리 385-1': {'time': '41분',
#   'distance': '24.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 21,500원',
#   'oil': '주유비 약 3,563원'},
#  '제주특별자치도 서귀포시 색달동 3039-3': {'time': '46분',
#   'distance': '39.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,700원',
#   'oil': '주유비 약 5,768원'},
#  '제주특별자치도 서귀포시 색달동 2812-4': {'time': '46분',
#   'distance': '39.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,600원',
#   'oil': '주유비 약 5,753원'},
#  '제주특별자치도 서귀포시 색달동 3039-1': {'time': '47분',
#   'distance': '39.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,000원',
#   'oil': '주유비 약 5,826원'},
#  '제주특별자치도 서귀포시 토평동 486-3': {'time': '59분',
#   'distance': '42.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,900원',
#   'oil': '주유비 약 6,264원'},
#  '제주특별자치도 서귀포시 표선면 표선리 40-69': {'time': '1시간 ',
#   'distance': '44.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,500원',
#   'oil': '주유비 약 6,556원'},
#  '제주특별자치도 서귀포시 회수동 30': {'time': '46분',
#   'distance': '39.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,600원',
#   'oil': '주유비 약 5,753원'},
#  '제주특별자치도 서귀포시 서귀동 314-2': {'time': '59분',
#   'distance': '43.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,500원',
#   'oil': '주유비 약 6,381원'},
#  '제주특별자치도 서귀포시 서귀동 820-1': {'time': '58분',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,300원',
#   'oil': '주유비 약 6,337원'},
#  '제주특별자치도 서귀포시 서귀동 316-4': {'time': '1시간 1분',
#   'distance': '43.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,410원'},
#  '제주특별자치도 서귀포시 서귀동 411-13': {'time': '1시간 ',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,300원',
#   'oil': '주유비 약 6,337원'},
#  '제주특별자치도 서귀포시 안덕면 상창리 2893': {'time': '35분',
#   'distance': '30.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 26,500원',
#   'oil': '주유비 약 4,454원'},
#  '제주특별자치도 서귀포시 남원읍 수망리 628-8': {'time': '50분',
#   'distance': '34.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 29,200원',
#   'oil': '주유비 약 4,994원'},
#  '제주특별자치도 서귀포시 서귀동 776-1': {'time': '1시간 1분',
#   'distance': '43.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,396원'},
#  '제주특별자치도 서귀포시 강정동 160-2': {'time': '54분',
#   'distance': '47.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,100원',
#   'oil': '주유비 약 6,965원'},
#  '제주특별자치도 서귀포시 강정동 173': {'time': '54분',
#   'distance': '47.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,100원',
#   'oil': '주유비 약 6,980원'},
#  '제주특별자치도 서귀포시 하예동 1793': {'time': '50분',
#   'distance': '39.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,800원',
#   'oil': '주유비 약 5,812원'},
#  '제주특별자치도 서귀포시 색달동 2508': {'time': '44분',
#   'distance': '38.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,700원',
#   'oil': '주유비 약 5,607원'},
#  '경기 김포시 구래동 6883-8': {'time': '40분',
#   'distance': '35.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 30,500원',
#   'oil': '주유비 약 5,213원'},
#  '제주특별자치도 서귀포시 서홍동 586': {'time': '1시간 3분',
#   'distance': '44.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,400원',
#   'oil': '주유비 약 6,542원'},
#  '제주특별자치도 서귀포시 서귀동 782-3': {'time': '1시간 1분',
#   'distance': '43.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,410원'},
#  '제주특별자치도 서귀포시 중문동 2115-1': {'time': '45분',
#   'distance': '39.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,200원',
#   'oil': '주유비 약 5,709원'},
#  '제주특별자치도 서귀포시 중문동 2700-2': {'time': '46분',
#   'distance': '41.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,400원',
#   'oil': '주유비 약 6,104원'},
#  '제주특별자치도 서귀포시 서귀동 777-1': {'time': '1시간 1분',
#   'distance': '43.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,396원'},
#  '제주특별자치도 서귀포시 대포동 2538': {'time': '49분',
#   'distance': '41.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,800원',
#   'oil': '주유비 약 6,016원'},
#  '제주특별자치도 서귀포시 표선면 표선리 591-1': {'time': '59분',
#   'distance': '43.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,352원'},
#  '제주특별자치도 서귀포시 중문동 2129-2': {'time': '47분',
#   'distance': '39.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,600원',
#   'oil': '주유비 약 5,797원'},
#  '제주특별자치도 서귀포시 하예동 460-1': {'time': '48분',
#   'distance': '40.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,300원',
#   'oil': '주유비 약 5,928원'},
#  '제주특별자치도 제주시 삼도이동 1053-15': {'time': '10분',
#   'distance': '4.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,200원',
#   'oil': '주유비 약 628원'},
#  '제주특별자치도 서귀포시 상예동 625': {'time': '44분',
#   'distance': '39.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,100원',
#   'oil': '주유비 약 5,753원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 169-16': {'time': '1시간 9분',
#   'distance': '50.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,900원',
#   'oil': '주유비 약 7,330원'},
#  '제주특별자치도 서귀포시 색달동 2138': {'time': '42분',
#   'distance': '37.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 31,800원',
#   'oil': '주유비 약 5,476원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 297-1': {'time': '1시간 7분',
#   'distance': '48.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,600원',
#   'oil': '주유비 약 7,082원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 437-1': {'time': '1시간 7분',
#   'distance': '48.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,700원',
#   'oil': '주유비 약 7,097원'},
#  '제주특별자치도 서귀포시 안덕면 서광리 산 24': {'time': '36분',
#   'distance': '30.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 26,700원',
#   'oil': '주유비 약 4,512원'},
#  '제주특별자치도 서귀포시 색달동 2284-1': {'time': '42분',
#   'distance': '38.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,300원',
#   'oil': '주유비 약 5,563원'},
#  '제주특별자치도 제주시 구좌읍 동복리 827': {'time': '40분',
#   'distance': '23.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 21,100원',
#   'oil': '주유비 약 3,490원'},
#  '제주특별자치도 제주시 용담삼동 1020-4': {'time': '7분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 애월읍 고내리 79-8': {'time': '30분',
#   'distance': '17.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,500원',
#   'oil': '주유비 약 2,526원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2867-3': {'time': '29분',
#   'distance': '15.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,400원',
#   'oil': '주유비 약 2,307원'},
#  '제주특별자치도 제주시 노형동 1295-16': {'time': '9분',
#   'distance': '3.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,900원',
#   'oil': '주유비 약 526원'},
#  '제주특별자치도 제주시 도두일동 1742': {'time': '11분',
#   'distance': '5.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,300원',
#   'oil': '주유비 약 832원'},
#  '제주특별자치도 제주시 해안동 2109': {'time': '17분',
#   'distance': '7.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,500원',
#   'oil': '주유비 약 1,139원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2768-7': {'time': '29분',
#   'distance': '15.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,400원',
#   'oil': '주유비 약 2,307원'},
#  '제주특별자치도 제주시 한림읍 금능리 2005': {'time': '51분',
#   'distance': '34.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 29,100원',
#   'oil': '주유비 약 4,994원'},
#  '제주특별자치도 제주시 해안동 2101-3': {'time': '18분',
#   'distance': '7.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,600원',
#   'oil': '주유비 약 1,154원'},
#  '제주특별자치도 제주시 용담이동 1783-1': {'time': '6분',
#   'distance': '2.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,000원',
#   'oil': '주유비 약 350원'},
#  '제주특별자치도 제주시 한림읍 협재리 876-3': {'time': '48분',
#   'distance': '31.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 26,700원',
#   'oil': '주유비 약 4,556원'},
#  '제주특별자치도 제주시 애월읍 신엄리 2946-4': {'time': '30분',
#   'distance': '16.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,600원',
#   'oil': '주유비 약 2,336원'},
#  '제주특별자치도 제주시 애월읍 고내리 332-1': {'time': '30분',
#   'distance': '16.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,300원',
#   'oil': '주유비 약 2,453원'},
#  '제주특별자치도 제주시 도두일동 1798-6': {'time': '12분',
#   'distance': '5.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,300원',
#   'oil': '주유비 약 818원'},
#  '제주특별자치도 제주시 애월읍 하가리 1256-2': {'time': '29분',
#   'distance': '16.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,300원',
#   'oil': '주유비 약 2,468원'},
#  '제주특별자치도 제주시 한림읍 협재리 1398': {'time': '48분',
#   'distance': '29.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 25,500원',
#   'oil': '주유비 약 4,337원'},
#  '제주특별자치도 제주시 한림읍 귀덕리 3646': {'time': '39분',
#   'distance': '24.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 21,100원',
#   'oil': '주유비 약 3,534원'},
#  '제주특별자치도 제주시 한림읍 협재리 2514-2': {'time': '48분',
#   'distance': '30.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 25,900원',
#   'oil': '주유비 약 4,410원'},
#  '제주특별자치도 서귀포시 대정읍 상모리 74': {'time': '52분',
#   'distance': '44.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,700원',
#   'oil': '주유비 약 6,527원'},
#  '제주특별자치도 서귀포시 대포동 1181': {'time': '49분',
#   'distance': '42.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,700원',
#   'oil': '주유비 약 6,147원'},
#  '제주특별자치도 서귀포시 대포동 1266-1': {'time': '52분',
#   'distance': '42.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,300원',
#   'oil': '주유비 약 6,264원'},
#  '제주특별자치도 서귀포시 색달동 1821-3': {'time': '42분',
#   'distance': '38.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,900원',
#   'oil': '주유비 약 5,636원'},
#  '제주특별자치도 서귀포시 대포동 342-2': {'time': '46분',
#   'distance': '41.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,100원',
#   'oil': '주유비 약 6,045원'},
#  '제주특별자치도 서귀포시 안덕면 화순리 1888': {'time': '44분',
#   'distance': '36.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 31,300원',
#   'oil': '주유비 약 5,344원'},
#  '제주특별자치도 서귀포시 성산읍 오조리 941-1': {'time': '1시간 7분',
#   'distance': '48.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,800원',
#   'oil': '주유비 약 7,067원'},
#  '제주특별자치도 서귀포시 성산읍 시흥리 5': {'time': '1시간 10분',
#   'distance': '51.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 43,200원',
#   'oil': '주유비 약 7,520원'},
#  '제주특별자치도 서귀포시 성산읍 수산리 2576': {'time': '58분',
#   'distance': '41.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,600원',
#   'oil': '주유비 약 6,118원'},
#  '제주특별자치도 서귀포시 성산읍 시흥리 208': {'time': '1시간 10분',
#   'distance': '51.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 43,100원',
#   'oil': '주유비 약 7,491원'},
#  '제주특별자치도 서귀포시 법환동 1498': {'time': '59분',
#   'distance': '51.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,500원',
#   'oil': '주유비 약 7,447원'},
#  '제주특별자치도 서귀포시 강정동 3702-1': {'time': '51분',
#   'distance': '44.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,700원',
#   'oil': '주유비 약 6,527원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 1090-16': {'time': '1시간 4분',
#   'distance': '46.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,600원',
#   'oil': '주유비 약 6,848원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 382-31': {'time': '1시간 8분',
#   'distance': '50.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,000원',
#   'oil': '주유비 약 7,301원'},
#  '제주특별자치도 서귀포시 성산읍 시흥리 200': {'time': '1시간 10분',
#   'distance': '51.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 43,100원',
#   'oil': '주유비 약 7,491원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 382-6': {'time': '1시간 8분',
#   'distance': '50.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,000원',
#   'oil': '주유비 약 7,301원'},
#  '제주특별자치도 서귀포시 색달동 1622-2': {'time': '44분',
#   'distance': '39.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,700원',
#   'oil': '주유비 약 5,797원'},
#  '제주특별자치도 서귀포시 서귀동 308-2': {'time': '1시간 1분',
#   'distance': '43.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,100원',
#   'oil': '주유비 약 6,308원'},
#  '제주특별자치도 서귀포시 성산읍 오조리 990-1': {'time': '1시간 7분',
#   'distance': '49.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,200원',
#   'oil': '주유비 약 7,155원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 510-6': {'time': '1시간 7분',
#   'distance': '48.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,900원',
#   'oil': '주유비 약 7,097원'},
#  '제주특별자치도 서귀포시 토평동 237-2': {'time': '57분',
#   'distance': '40.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,300원',
#   'oil': '주유비 약 5,972원'},
#  '제주특별자치도 서귀포시 대정읍 안성리 214': {'time': '43분',
#   'distance': '38.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,600원',
#   'oil': '주유비 약 5,578원'},
#  '제주특별자치도 제주시 외도이동 338-1': {'time': '16분',
#   'distance': '7.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,700원',
#   'oil': '주유비 약 1,066원'},
#  '제주특별자치도 제주시 용담삼동 1181-3': {'time': '10분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,200원',
#   'oil': '주유비 약 613원'},
#  '제주특별자치도 제주시 이호일동 295-1': {'time': '12분',
#   'distance': '5.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,100원',
#   'oil': '주유비 약 774원'},
#  '제주특별자치도 제주시 이호일동 365': {'time': '13분',
#   'distance': '6.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,000원',
#   'oil': '주유비 약 935원'},
#  '제주특별자치도 제주시 애월읍 곽지리 1565-18': {'time': '34분',
#   'distance': '21.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 18,700원',
#   'oil': '주유비 약 3,081원'},
#  '제주특별자치도 제주시 연동 261-67': {'time': '9분',
#   'distance': '3.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,700원',
#   'oil': '주유비 약 467원'},
#  '제주특별자치도 제주시 용담삼동 2382': {'time': '10분',
#   'distance': '5.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,800원',
#   'oil': '주유비 약 730원'},
#  '제주특별자치도 제주시 연동 292-17': {'time': '8분',
#   'distance': '3.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,600원',
#   'oil': '주유비 약 453원'},
#  '제주특별자치도 제주시 한림읍 협재리 964-1': {'time': '47분',
#   'distance': '37.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,000원',
#   'oil': '주유비 약 5,476원'},
#  '경기 과천시 별양동 14': {'time': '47분',
#   'distance': '37.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,000원',
#   'oil': '주유비 약 5,476원'},
#  '서울 강남구 역삼동 633-31': {'time': '6시간 30분',
#   'distance': '542.6km',
#   'toll': '통행료 약 17,400원',
#   'taxi': '택시비 약 565,200원',
#   'oil': '주유비 약 65,037원'},
#  '제주특별자치도 제주시 애월읍 유수암리 617-1': {'time': '25분',
#   'distance': '13.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 13,000원',
#   'oil': '주유비 약 1,986원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2869-10': {'time': '22분',
#   'distance': '11.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 10,900원',
#   'oil': '주유비 약 1,665원'},
#  '제주특별자치도 제주시 용담삼동 2342-2': {'time': '11분',
#   'distance': '5.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,200원',
#   'oil': '주유비 약 789원'},
#  '제주특별자치도 제주시 이호일동 363': {'time': '13분',
#   'distance': '6.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,800원',
#   'oil': '주유비 약 905원'},
#  '제주특별자치도 제주시 이도1동 1782-1': {'time': '13분',
#   'distance': '4.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,900원',
#   'oil': '주유비 약 672원'},
#  '제주특별자치도 제주시 연동 284-6': {'time': '9분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,900원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 노형동 310-2': {'time': '24분',
#   'distance': '11.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 11,200원',
#   'oil': '주유비 약 1,708원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2707-2': {'time': '22분',
#   'distance': '11.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 11,000원',
#   'oil': '주유비 약 1,679원'},
#  '충남 태안군 안면읍 승언리 1944-27': {'time': '5시간 28분',
#   'distance': '424.2km',
#   'toll': '통행료 약 8,700원',
#   'taxi': '택시비 약 446,700원',
#   'oil': '주유비 약 47,763원'},
#  '제주특별자치도 제주시 도두일동 2614-5': {'time': '12분',
#   'distance': '5.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,200원',
#   'oil': '주유비 약 789원'},
#  '제주특별자치도 제주시 애월읍 애월리 1229-3': {'time': '31분',
#   'distance': '18.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 16,800원',
#   'oil': '주유비 약 2,731원'},
#  '제주특별자치도 제주시 애월읍 하가리 120-50': {'time': '28분',
#   'distance': '16.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 15,400원',
#   'oil': '주유비 약 2,424원'},
#  '제주특별자치도 제주시 이호일동 325': {'time': '14분',
#   'distance': '6.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,300원',
#   'oil': '주유비 약 978원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2615-8': {'time': '23분',
#   'distance': '11.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 11,600원',
#   'oil': '주유비 약 1,738원'},
#  '제주특별자치도 제주시 이호일동 328-4': {'time': '12분',
#   'distance': '5.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,200원',
#   'oil': '주유비 약 789원'},
#  '제주특별자치도 제주시 애월읍 고내리 1105-1': {'time': '31분',
#   'distance': '18.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 16,400원',
#   'oil': '주유비 약 2,672원'},
#  '제주특별자치도 제주시 애월읍 구엄리 941': {'time': '24분',
#   'distance': '15.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 14,100원',
#   'oil': '주유비 약 2,190원'},
#  '제주특별자치도 제주시 삼도일동 558-5': {'time': '10분',
#   'distance': '4.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,300원',
#   'oil': '주유비 약 599원'},
#  '제주특별자치도 제주시 용담삼동 2383-1': {'time': '10분',
#   'distance': '5.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,900원',
#   'oil': '주유비 약 730원'},
#  '제주특별자치도 제주시 노형동 1288-4': {'time': '11분',
#   'distance': '4.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 599원'},
#  '제주특별자치도 제주시 한림읍 귀덕리 721-1': {'time': '40분',
#   'distance': '26.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 23,600원',
#   'oil': '주유비 약 3,913원'},
#  '제주특별자치도 제주시 연동 273-54': {'time': '10분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 511원'},
#  '서울 중구 을지로2가 199-13': {'time': '10분',
#   'distance': '3.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 511원'},
#  '제주특별자치도 제주시 이도이동 1010': {'time': '14분',
#   'distance': '4.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 6,300원',
#   'oil': '주유비 약 686원'},
#  '제주특별자치도 제주시 애월읍 하귀2리 2749-3': {'time': '25분',
#   'distance': '12.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 12,300원',
#   'oil': '주유비 약 1,825원'},
#  '제주특별자치도 제주시 한림읍 금능리 1803-2': {'time': '51분',
#   'distance': '39.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,100원',
#   'oil': '주유비 약 5,812원'},
#  '제주특별자치도 제주시 용담삼동 2572': {'time': '18분',
#   'distance': '8.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 8,800원',
#   'oil': '주유비 약 1,183원'},
#  '제주특별자치도 제주시 용담2동 2678-10': {'time': '7분',
#   'distance': '2.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,200원',
#   'oil': '주유비 약 394원'},
#  '제주특별자치도 제주시 애월읍 고내리 1159': {'time': '33분',
#   'distance': '19.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 18,200원',
#   'oil': '주유비 약 2,891원'},
#  '제주특별자치도 제주시 도두이동 680': {'time': '16분',
#   'distance': '7.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,600원',
#   'oil': '주유비 약 1,037원'},
#  '제주특별자치도 제주시 일도일동 1331-1': {'time': '14분',
#   'distance': '4.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,900원',
#   'oil': '주유비 약 715원'},
#  '제주특별자치도 제주시 구좌읍 평대리 3350-13': {'time': '57분',
#   'distance': '38.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,700원',
#   'oil': '주유비 약 5,593원'},
#  '경기 평택시 청룡동 397-36': {'time': '6시간 15분',
#   'distance': '470.6km',
#   'toll': '통행료 약 13,700원',
#   'taxi': '택시비 약 492,100원',
#   'oil': '주유비 약 54,523원'},
#  '제주특별자치도 서귀포시 보목동 1569': {'time': '1시간 3분',
#   'distance': '44.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,900원',
#   'oil': '주유비 약 6,425원'},
#  '제주특별자치도 서귀포시 강정동 702-2': {'time': '59분',
#   'distance': '48.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,200원',
#   'oil': '주유비 약 7,111원'},
#  '제주특별자치도 서귀포시 강정동 2498-3': {'time': '58분',
#   'distance': '47.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,900원',
#   'oil': '주유비 약 6,877원'},
#  '제주특별자치도 서귀포시 중문동 2165-2': {'time': '47분',
#   'distance': '39.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,500원',
#   'oil': '주유비 약 5,695원'},
#  '제주특별자치도 서귀포시 성산읍 시흥리 12-98': {'time': '1시간 7분',
#   'distance': '46.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 38,900원',
#   'oil': '주유비 약 6,731원'},
#  '인천 남동구 구월동 1466-1': {'time': '6시간 42분',
#   'distance': '546.7km',
#   'toll': '통행료 약 17,300원',
#   'taxi': '택시비 약 568,700원',
#   'oil': '주유비 약 65,635원'},
#  '제주특별자치도 서귀포시 호근동 1638-2': {'time': '1시간 1분',
#   'distance': '50.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,500원',
#   'oil': '주유비 약 7,359원'},
#  '제주특별자치도 서귀포시 서귀동 317-7': {'time': '1시간 3분',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,400원',
#   'oil': '주유비 약 6,337원'},
#  '강원특별자치도 춘천시 남산면 방하리 197': {'time': '7시간 36분',
#   'distance': '582.5km',
#   'toll': '통행료 약 19,900원',
#   'taxi': '택시비 약 597,500원',
#   'oil': '주유비 약 70,863원'},
#  '제주특별자치도 서귀포시 대포동 2118': {'time': '51분',
#   'distance': '43.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,800원',
#   'oil': '주유비 약 6,308원'},
#  '제주특별자치도 서귀포시 호근동 1591': {'time': '1시간 1분',
#   'distance': '50.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,700원',
#   'oil': '주유비 약 7,389원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 234-19': {'time': '1시간 8분',
#   'distance': '50.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,000원',
#   'oil': '주유비 약 7,301원'},
#  '제주특별자치도 서귀포시 서귀동 654-5': {'time': '1시간 3분',
#   'distance': '43.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,300원',
#   'oil': '주유비 약 6,323원'},
#  '전남 여수시 종화동 746-1': {'time': '3시간 36분',
#   'distance': '214.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 205,900원',
#   'oil': '주유비 약 1,197원'},
#  '제주특별자치도 서귀포시 영남동 224': {'time': '50분',
#   'distance': '41.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,500원',
#   'oil': '주유비 약 6,074원'},
#  '제주특별자치도 서귀포시 하원동 1496-1': {'time': '50분',
#   'distance': '42.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,500원',
#   'oil': '주유비 약 6,250원'},
#  '제주특별자치도 서귀포시 호근동 1616-1': {'time': '1시간 1분',
#   'distance': '50.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,700원',
#   'oil': '주유비 약 7,403원'},
#  '제주특별자치도 서귀포시 보목동 1252-1': {'time': '1시간 3분',
#   'distance': '43.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,700원',
#   'oil': '주유비 약 6,396원'},
#  '제주특별자치도 서귀포시 서귀동 626-2': {'time': '1시간 2분',
#   'distance': '43.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,100원',
#   'oil': '주유비 약 6,293원'},
#  '제주특별자치도 서귀포시 신효동 506-9': {'time': '56분',
#   'distance': '39.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,200원',
#   'oil': '주유비 약 5,739원'},
#  '제주특별자치도 서귀포시 상효동 2205': {'time': '51분',
#   'distance': '38.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,500원',
#   'oil': '주유비 약 5,563원'},
#  '제주특별자치도 서귀포시 성산읍 온평리 1832-1': {'time': '1시간 3분',
#   'distance': '45.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 38,200원',
#   'oil': '주유비 약 6,600원'},
#  '제주특별자치도 서귀포시 대정읍 무릉리 3869-4': {'time': '58분',
#   'distance': '49.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,900원',
#   'oil': '주유비 약 7,243원'},
#  '경남 창원시 성산구 용호동 73-2': {'time': '5시간 8분',
#   'distance': '369.6km',
#   'toll': '통행료 약 9,800원',
#   'taxi': '택시비 약 387,000원',
#   'oil': '주유비 약 39,775원'},
#  '부산 금정구 부곡동 890-14': {'time': '5시간 39분',
#   'distance': '340.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 360,700원',
#   'oil': '주유비 약 4,249원'},
#  '제주특별자치도 서귀포시 하예동 558-4': {'time': '48분',
#   'distance': '40.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,500원',
#   'oil': '주유비 약 5,885원'},
#  '제주특별자치도 서귀포시 대정읍 하모리 1502-1': {'time': '49분',
#   'distance': '41.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,600원',
#   'oil': '주유비 약 6,089원'},
#  '제주특별자치도 서귀포시 색달동 2534-1': {'time': '44분',
#   'distance': '38.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,900원',
#   'oil': '주유비 약 5,593원'},
#  '대전 서구 둔산동 1357': {'time': '5시간 31분',
#   'distance': '398.0km',
#   'toll': '통행료 약 8,000원',
#   'taxi': '택시비 약 420,400원',
#   'oil': '주유비 약 43,922원'},
#  '제주특별자치도 서귀포시 하효동 1028-2': {'time': '1시간 3분',
#   'distance': '43.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,300원',
#   'oil': '주유비 약 6,308원'},
#  '제주특별자치도 서귀포시 서귀동 433-2': {'time': '1시간 2분',
#   'distance': '44.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,900원',
#   'oil': '주유비 약 6,425원'},
#  '제주특별자치도 서귀포시 안덕면 사계리 204': {'time': '46분',
#   'distance': '38.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,800원',
#   'oil': '주유비 약 5,578원'},
#  '제주특별자치도 서귀포시 강정동 2483-3': {'time': '58분',
#   'distance': '47.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,100원',
#   'oil': '주유비 약 6,921원'},
#  '경북 문경시 문경읍 하초리 179-1': {'time': '6시간 47분',
#   'distance': '508.9km',
#   'toll': '통행료 약 10,600원',
#   'taxi': '택시비 약 526,700원',
#   'oil': '주유비 약 60,116원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 444-7': {'time': '1시간 6분',
#   'distance': '48.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,500원',
#   'oil': '주유비 약 7,009원'},
#  '제주특별자치도 서귀포시 중문동 2050-5': {'time': '43분',
#   'distance': '40.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,800원',
#   'oil': '주유비 약 5,870원'},
#  '제주특별자치도 서귀포시 표선면 하천리 1606': {'time': '54분',
#   'distance': '39.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,000원',
#   'oil': '주유비 약 5,812원'},
#  '제주특별자치도 서귀포시 서홍동 1777-3': {'time': '58분',
#   'distance': '49.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,100원',
#   'oil': '주유비 약 7,286원'},
#  '제주특별자치도 서귀포시 서귀동 753-3': {'time': '1시간 3분',
#   'distance': '44.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,800원',
#   'oil': '주유비 약 6,483원'},
#  '제주특별자치도 서귀포시 대포동 1813': {'time': '49분',
#   'distance': '41.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,600원',
#   'oil': '주유비 약 6,089원'},
#  '제주특별자치도 서귀포시 하예동 463-1': {'time': '49분',
#   'distance': '40.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,700원',
#   'oil': '주유비 약 5,914원'},
#  '제주특별자치도 서귀포시 강정동 3447-1': {'time': '48분',
#   'distance': '44.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,500원',
#   'oil': '주유비 약 6,556원'},
#  '제주특별자치도 서귀포시 서귀동 315-2': {'time': '1시간 ',
#   'distance': '44.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,000원',
#   'oil': '주유비 약 6,483원'},
#  '제주특별자치도 서귀포시 서귀동 536-2': {'time': '59분',
#   'distance': '44.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,425원'},
#  '제주특별자치도 서귀포시 서귀동 644-1': {'time': '1시간 ',
#   'distance': '44.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,900원',
#   'oil': '주유비 약 6,469원'},
#  '제주특별자치도 서귀포시 서귀동 256-33': {'time': '59분',
#   'distance': '43.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,500원',
#   'oil': '주유비 약 6,381원'},
#  '제주특별자치도 서귀포시 서귀동 162-7': {'time': '1시간 ',
#   'distance': '44.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,800원',
#   'oil': '주유비 약 6,439원'},
#  '제주특별자치도 서귀포시 서귀동 258-2': {'time': '59분',
#   'distance': '42.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,400원',
#   'oil': '주유비 약 6,250원'},
#  '제주특별자치도 서귀포시 대정읍 하모리 934': {'time': '46분',
#   'distance': '41.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,900원',
#   'oil': '주유비 약 6,074원'},
#  '서울 동작구 대방동 395-18': {'time': '7시간 1분',
#   'distance': '527.9km',
#   'toll': '통행료 약 17,700원',
#   'taxi': '택시비 약 545,900원',
#   'oil': '주유비 약 62,890원'},
#  '제주특별자치도 서귀포시 상예동 185-1': {'time': '38분',
#   'distance': '35.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 30,000원',
#   'oil': '주유비 약 5,184원'},
#  '제주특별자치도 서귀포시 법환동 17': {'time': '54분',
#   'distance': '48.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,600원',
#   'oil': '주유비 약 7,140원'},
#  '제주특별자치도 서귀포시 안덕면 사계리 1586-1': {'time': '44분',
#   'distance': '38.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,300원',
#   'oil': '주유비 약 5,607원'},
#  '제주특별자치도 서귀포시 대포동 2229-1': {'time': '49분',
#   'distance': '43.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,396원'},
#  '제주특별자치도 서귀포시 서귀동 323-19': {'time': '1시간 ',
#   'distance': '44.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,900원',
#   'oil': '주유비 약 6,469원'},
#  '제주특별자치도 서귀포시 서귀동 587-43': {'time': '1시간 ',
#   'distance': '43.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,500원',
#   'oil': '주유비 약 6,381원'},
#  '제주특별자치도 서귀포시 서홍동 1289': {'time': '57분',
#   'distance': '51.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,500원',
#   'oil': '주유비 약 7,491원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 180-5': {'time': '1시간 6분',
#   'distance': '49.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,600원',
#   'oil': '주유비 약 7,257원'},
#  '제주특별자치도 서귀포시 서귀동 685': {'time': '1시간 ',
#   'distance': '43.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,410원'},
#  '제주특별자치도 서귀포시 대정읍 하모리 2133-5': {'time': '48분',
#   'distance': '42.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,500원',
#   'oil': '주유비 약 6,206원'},
#  '제주특별자치도 제주시 삼도2동 1255': {'time': '11분',
#   'distance': '4.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,100원',
#   'oil': '주유비 약 599원'},
#  '제주특별자치도 서귀포시 강정동 925-2': {'time': '57분',
#   'distance': '50.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,900원',
#   'oil': '주유비 약 7,374원'},
#  '제주특별자치도 서귀포시 중문동 2167-16': {'time': '44분',
#   'distance': '39.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,700원',
#   'oil': '주유비 약 5,695원'},
#  '제주특별자치도 서귀포시 서홍동 754-3': {'time': '1시간 3분',
#   'distance': '44.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,900원',
#   'oil': '주유비 약 6,527원'},
#  '제주특별자치도 서귀포시 서귀동 650-1': {'time': '1시간 ',
#   'distance': '43.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,323원'},
#  '제주특별자치도 서귀포시 서귀동 432-3': {'time': '1시간 ',
#   'distance': '43.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,293원'},
#  '제주특별자치도 서귀포시 대포동 1695': {'time': '46분',
#   'distance': '42.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,300원',
#   'oil': '주유비 약 6,162원'},
#  '제주특별자치도 제주시 이도이동 2022-6': {'time': '16분',
#   'distance': '6.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 7,400원',
#   'oil': '주유비 약 949원'},
#  '제주특별자치도 서귀포시 호근동 479-4': {'time': '57분',
#   'distance': '50.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,900원',
#   'oil': '주유비 약 7,389원'},
#  '제주특별자치도 서귀포시 서귀동 289-13': {'time': '1시간 ',
#   'distance': '43.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,308원'},
#  '제주특별자치도 서귀포시 서귀동 697-1': {'time': '1시간 ',
#   'distance': '43.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,600원',
#   'oil': '주유비 약 6,323원'},
#  '제주특별자치도 서귀포시 서귀동 310-10': {'time': '1시간 1분',
#   'distance': '43.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,900원',
#   'oil': '주유비 약 6,381원'},
#  '경기 고양시 덕양구 행주외동 212-10': {'time': '6시간 55분',
#   'distance': '561.2km',
#   'toll': '통행료 약 18,600원',
#   'taxi': '택시비 약 581,100원',
#   'oil': '주유비 약 67,753원'},
#  '제주특별자치도 서귀포시 안덕면 덕수리 1513-1': {'time': '37분',
#   'distance': '33.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 28,600원',
#   'oil': '주유비 약 4,935원'},
#  '제주특별자치도 서귀포시 서귀동 313-3': {'time': '1시간 ',
#   'distance': '43.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,400원',
#   'oil': '주유비 약 6,293원'},
#  '제주특별자치도 서귀포시 토평동 581-1': {'time': '1시간 1분',
#   'distance': '43.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,900원',
#   'oil': '주유비 약 6,366원'},
#  '제주특별자치도 서귀포시 서귀동 411-1': {'time': '59분',
#   'distance': '42.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,400원',
#   'oil': '주유비 약 6,264원'},
#  '제주특별자치도 서귀포시 남원읍 태흥리 373': {'time': '58분',
#   'distance': '45.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 38,200원',
#   'oil': '주유비 약 6,585원'},
#  '제주특별자치도 서귀포시 서귀동 310-41': {'time': '1시간 1분',
#   'distance': '43.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 37,000원',
#   'oil': '주유비 약 6,381원'},
#  '제주특별자치도 서귀포시 하예동 1795-1': {'time': '48분',
#   'distance': '39.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,500원',
#   'oil': '주유비 약 5,797원'},
#  '제주특별자치도 서귀포시 성산읍 오조리 398-10': {'time': '1시간 9분',
#   'distance': '47.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,200원',
#   'oil': '주유비 약 6,877원'},
#  '제주특별자치도 서귀포시 보목동 1453': {'time': '1시간 ',
#   'distance': '43.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,352원'},
#  '제주특별자치도 서귀포시 대포동 2122': {'time': '48분',
#   'distance': '43.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,200원',
#   'oil': '주유비 약 6,308원'},
#  '제주특별자치도 서귀포시 성산읍 성산리 308': {'time': '1시간 10분',
#   'distance': '51.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,700원',
#   'oil': '주유비 약 7,491원'},
#  '제주특별자치도 서귀포시 서귀동 485-1': {'time': '59분',
#   'distance': '43.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,400원',
#   'oil': '주유비 약 6,293원'},
#  '제주특별자치도 서귀포시 대정읍 하모리 2129-1': {'time': '48분',
#   'distance': '42.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,600원',
#   'oil': '주유비 약 6,206원'},
#  '제주특별자치도 서귀포시 대정읍 하모리 2129-2': {'time': '48분',
#   'distance': '42.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,600원',
#   'oil': '주유비 약 6,206원'},
#  '제주특별자치도 서귀포시 대정읍 하모리 2129-3': {'time': '48분',
#   'distance': '42.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,700원',
#   'oil': '주유비 약 6,206원'},
#  '제주특별자치도 서귀포시 대정읍 하모리 1089-23': {'time': '48분',
#   'distance': '42.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 35,500원',
#   'oil': '주유비 약 6,177원'},
#  '제주특별자치도 서귀포시 표선면 가시리 997-1': {'time': '55분',
#   'distance': '42.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,100원',
#   'oil': '주유비 약 6,250원'},
#  '제주특별자치도 제주시 한림읍 금능리 1625': {'time': '52분',
#   'distance': '34.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 29,300원',
#   'oil': '주유비 약 5,052원'},
#  '제주특별자치도 제주시 한림읍 귀덕리 3861': {'time': '41분',
#   'distance': '25.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 22,000원',
#   'oil': '주유비 약 3,709원'},
#  '제주특별자치도 제주시 한경면 판포리 2872': {'time': '53분',
#   'distance': '35.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 30,000원',
#   'oil': '주유비 약 5,184원'},
#  '충북 보은군 산외면 동화리 3-1': {'time': '6시간 4분',
#   'distance': '456.9km',
#   'toll': '통행료 약 8,400원',
#   'taxi': '택시비 약 474,700원',
#   'oil': '주유비 약 52,523원'},
#  '제주특별자치도 제주시 애월읍 애월리 2505': {'time': '33분',
#   'distance': '19.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 17,500원',
#   'oil': '주유비 약 2,891원'},
#  '제주특별자치도 제주시 회천동 3-16': {'time': '37분',
#   'distance': '24.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 21,400원',
#   'oil': '주유비 약 3,534원'},
#  '제주특별자치도 제주시 한경면 저지리 산 19-1': {'time': '41분',
#   'distance': '33.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 28,700원',
#   'oil': '주유비 약 4,921원'},
#  '강원특별자치도 춘천시 남산면 백양리 29-1': {'time': '7시간 43분',
#   'distance': '594.0km',
#   'toll': '통행료 약 20,500원',
#   'taxi': '택시비 약 605,600원',
#   'oil': '주유비 약 72,542원'},
#  '제주특별자치도 제주시 애월읍 고성리 980': {'time': '23분',
#   'distance': '12.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 12,100원',
#   'oil': '주유비 약 1,869원'},
#  '제주특별자치도 제주시 애월읍 봉성리 52-5': {'time': '33분',
#   'distance': '26.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 22,700원',
#   'oil': '주유비 약 3,826원'},
#  '제주특별자치도 제주시 한림읍 금능리 1885-1': {'time': '51분',
#   'distance': '33.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 28,500원',
#   'oil': '주유비 약 4,906원'},
#  '제주특별자치도 제주시 애월읍 어음리 523-22': {'time': '27분',
#   'distance': '21.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 18,700원',
#   'oil': '주유비 약 3,081원'},
#  '제주특별자치도 제주시 봉개동 237-12': {'time': '32분',
#   'distance': '20.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 18,400원',
#   'oil': '주유비 약 3,052원'},
#  '제주특별자치도 제주시 조천읍 북촌리 산 65': {'time': '37분',
#   'distance': '22.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 19,700원',
#   'oil': '주유비 약 3,256원'},
#  '제주특별자치도 제주시 한림읍 금악리 산 32-1': {'time': '31분',
#   'distance': '24.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 21,500원',
#   'oil': '주유비 약 3,592원'},
#  '제주특별자치도 제주시 해안동 2499-2': {'time': '19분',
#   'distance': '9.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 9,800원',
#   'oil': '주유비 약 1,446원'},
#  '제주특별자치도 제주시 애월읍 납읍리 102': {'time': '30분',
#   'distance': '19.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 17,300원',
#   'oil': '주유비 약 2,833원'},
#  '제주특별자치도 제주시 우도면 연평리 1707': {'time': '1시간 14분',
#   'distance': '53.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 44,500원',
#   'oil': '주유비 약 7,447원'},
#  '제주특별자치도 서귀포시 강정동 2677': {'time': '56분',
#   'distance': '46.9km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,400원',
#   'oil': '주유비 약 6,848원'},
#  '제주특별자치도 서귀포시 남원읍 남원리 2390': {'time': '58분',
#   'distance': '45.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 38,000원',
#   'oil': '주유비 약 6,644원'},
#  '제주특별자치도 서귀포시 성산읍 고성리 127-2': {'time': '1시간 8분',
#   'distance': '50.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,000원',
#   'oil': '주유비 약 7,389원'},
#  '제주특별자치도 서귀포시 법환동 87-1': {'time': '56분',
#   'distance': '49.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 41,600원',
#   'oil': '주유비 약 7,243원'},
#  '제주특별자치도 서귀포시 법환동 978': {'time': '55분',
#   'distance': '48.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 40,900원',
#   'oil': '주유비 약 7,111원'},
#  '제주특별자치도 서귀포시 색달동 301': {'time': '41분',
#   'distance': '34.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 29,700원',
#   'oil': '주유비 약 5,052원'},
#  '제주특별자치도 서귀포시 남원읍 위미리 4625': {'time': '54분',
#   'distance': '39.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,800원',
#   'oil': '주유비 약 5,812원'},
#  '제주특별자치도 서귀포시 하예동 1888': {'time': '50분',
#   'distance': '40.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,000원',
#   'oil': '주유비 약 5,855원'},
#  '제주특별자치도 서귀포시 안덕면 상천리 산 78-1': {'time': '35분',
#   'distance': '29.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 25,600원',
#   'oil': '주유비 약 4,308원'},
#  '제주특별자치도 서귀포시 남원읍 위미리 4627': {'time': '51분',
#   'distance': '38.5km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,800원',
#   'oil': '주유비 약 5,622원'},
#  '제주특별자치도 서귀포시 호근동 285-1': {'time': '58분',
#   'distance': '51.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 42,700원',
#   'oil': '주유비 약 7,447원'},
#  '제주특별자치도 서귀포시 안덕면 서광리 2518': {'time': '38분',
#   'distance': '31.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 27,200원',
#   'oil': '주유비 약 4,614원'},
#  '제주특별자치도 서귀포시 토평동 산 30-13': {'time': '54분',
#   'distance': '40.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 34,000원',
#   'oil': '주유비 약 5,841원'},
#  '제주특별자치도 서귀포시 하원동 1885': {'time': '43분',
#   'distance': '38.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 32,500원',
#   'oil': '주유비 약 5,578원'},
#  '제주특별자치도 서귀포시 색달동 2864-32': {'time': '46분',
#   'distance': '39.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,200원',
#   'oil': '주유비 약 5,709원'},
#  '제주특별자치도 서귀포시 상예동 3713-1': {'time': '39분',
#   'distance': '35.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 30,000원',
#   'oil': '주유비 약 5,111원'},
#  '제주특별자치도 제주시 연동 270-2': {'time': '9분',
#   'distance': '3.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,700원',
#   'oil': '주유비 약 482원'},
#  '제주특별자치도 서귀포시 서귀동 182': {'time': '59분',
#   'distance': '43.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,400원',
#   'oil': '주유비 약 6,279원'},
#  '제주특별자치도 제주시 연동 263-2': {'time': '11분',
#   'distance': '4.2km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 613원'},
#  '제주특별자치도 서귀포시 서귀동 318-17': {'time': '1시간 ',
#   'distance': '43.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,700원',
#   'oil': '주유비 약 6,337원'},
#  '제주특별자치도 제주시 노형동 930-5': {'time': '11분',
#   'distance': '4.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,600원',
#   'oil': '주유비 약 628원'},
#  '제주특별자치도 서귀포시 색달동 2785': {'time': '44분',
#   'distance': '39.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 33,000원',
#   'oil': '주유비 약 5,753원'},
#  '제주특별자치도 서귀포시 서귀동 325-1': {'time': '58분',
#   'distance': '43.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,200원',
#   'oil': '주유비 약 6,323원'},
#  '제주특별자치도 서귀포시 서귀동 255-1': {'time': '57분',
#   'distance': '43.3km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,100원',
#   'oil': '주유비 약 6,323원'},
#  '제주특별자치도 서귀포시 서귀동 486-1': {'time': '59분',
#   'distance': '43.7km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 36,500원',
#   'oil': '주유비 약 6,381원'},
#  '제주특별자치도 서귀포시 법환동 745-2': {'time': '52분',
#   'distance': '48.1km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,900원',
#   'oil': '주유비 약 7,023원'},
#  '제주특별자치도 제주시 연동 263-15': {'time': '10분',
#   'distance': '3.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,000원',
#   'oil': '주유비 약 526원'},
#  '제주특별자치도 제주시 노형동 산 13': {'time': '21분',
#   'distance': '11.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 11,000원',
#   'oil': '주유비 약 1,665원'},
#  '제주특별자치도 서귀포시 법환동 745-1': {'time': '52분',
#   'distance': '48.0km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 39,900원',
#   'oil': '주유비 약 7,009원'},
#  '제주특별자치도 서귀포시 안덕면 서광리 산 24-15': {'time': '36분',
#   'distance': '31.4km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 26,700원',
#   'oil': '주유비 약 4,585원'},
#  '제주특별자치도 제주시 연동 284-8': {'time': '8분',
#   'distance': '3.6km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 4,500원',
#   'oil': '주유비 약 526원'},
#  '제주특별자치도 제주시 건입동 1443-2': {'time': '12분',
#   'distance': '4.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 701원'},
#  '제주특별자치도 서귀포시 서호동 1524-7': {'time': '12분',
#   'distance': '4.8km',
#   'toll': '통행료 약 0원',
#   'taxi': '택시비 약 5,500원',
#   'oil': '주유비 약 701원'}}
