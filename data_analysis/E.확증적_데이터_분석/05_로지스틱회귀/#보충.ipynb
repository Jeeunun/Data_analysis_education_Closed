# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # boolean series

# %%
D=pd.read_excel("https://data.hossam.kr/E05/titanic.xlsx")
data=pd.DataFrame(D)

# %%
idx=data["Sex"]=="female"

# %%
idx
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %% [markdown]
# - recall!!

# %%
x=10>5

# %%
idx2=data["Embarked"]=="C"

# %%
idx3=data["Age"].isna()

# %% [markdown]
# ##### 너넨 merge를 똑바로 못한다..

# %%
import random as rd

# %%
indx=rd.sample(population=list(data.columns),k=7)

# %%
indx2=rd.sample(population=list(data.columns),k=7)

# %%
data1=data[indx]
data2=data[data.columns.difference(indx)]

# %%
data1.head(3)
# Out:
#    Survived            Ticket     Fare Embarked  SibSp  Parch   Age
# 0         0         A/5 21171   7.2500        S      1      0  22.0
# 1         1          PC 17599  71.2833        C      1      0  38.0
# 2         1  STON/O2. 3101282   7.9250        S      0      0  26.0

# %%
data2.head(3)
# Out:
#   Cabin                                               Name  PassengerId  \
# 0   NaN                            Braund, Mr. Owen Harris            1
# 1   C85  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2   NaN                             Heikkinen, Miss. Laina            3
#
#    Pclass     Sex
# 0       3    male
# 1       1  female
# 2       3  female

# %%
data3 = pd.merge(data1, data2, left_index=True,right_index=True)
cols1=data3.columns[:8]
cols2=data3.columns[7:]

# %%
data1=data[cols1]
data2=data[cols2]

# %%
data2.rename(columns={data2.columns[0]:"캐빈~"},inplace=True)
# Out:
# C:\Users\hanjieun_2\AppData\Local\Temp\ipykernel_15308\2576203105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.rename(columns={data2.columns[0]:"캐빈~"},inplace=True)

# %%
data2=data2.loc[:len(data):2]

# %%
data2
# Out:
#      캐빈~                                               Name  PassengerId  \
# 0    NaN                            Braund, Mr. Owen Harris            1
# 2    NaN                             Heikkinen, Miss. Laina            3
# 4    NaN                           Allen, Mr. William Henry            5
# 6    E46                            McCarthy, Mr. Timothy J            7
# 8    NaN  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9
# ..   ...                                                ...          ...
# 882  NaN                       Dahlberg, Miss. Gerda Ulrika          883
# 884  NaN                             Sutehall, Mr. Henry Jr          885
# 886  NaN                              Montvila, Rev. Juozas          887
# 888  NaN           Johnston, Miss. Catherine Helen "Carrie"          889
# 890  NaN                                Dooley, Mr. Patrick          891
#
#      Pclass     Sex
# 0         3    male
# 2         3  female
# 4         3    male
# ...

# %%
data3 = pd.merge(data1, data2,left_on="Cabin",right_on="캐빈~")

# %%
data3
# Out:
#         Survived     Ticket     Fare Embarked  SibSp  Parch   Age Cabin  캐빈~  \
# 0              0  A/5 21171   7.2500        S      1      0  22.0   NaN  NaN
# 1              0  A/5 21171   7.2500        S      1      0  22.0   NaN  NaN
# 2              0  A/5 21171   7.2500        S      1      0  22.0   NaN  NaN
# 3              0  A/5 21171   7.2500        S      1      0  22.0   NaN  NaN
# 4              0  A/5 21171   7.2500        S      1      0  22.0   NaN  NaN
# ...          ...        ...      ...      ...    ...    ...   ...   ...  ...
# 246092         1      17465  25.9292        S      0      0  49.0   D17  D17
# 246093         1      17466  25.9292        S      0      0  48.0   D17  D17
# 246094         1      17466  25.9292        S      0      0  48.0   D17  D17
# 246095         0     112050   0.0000        S      0      0  39.0   A36  A36
# 246096         1      12749  93.5000        S      1      1  52.0   B69  B69
#
# ...
