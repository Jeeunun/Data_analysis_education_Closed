# %% [markdown]
# # *데이터 수집 미니 프로젝트*

# %% [markdown]
# ### 1. 연구주제
# >  2023년 음원 차트 순위 및 아티스트 기본정보 수집

# %% [markdown]
# ### 2. 연구방법
# >  데이터 수집 사이트 : Bugs,Genie <br>
# <a href="#">
# 	<img src="https://www.geniemusic.co.kr/assets/images/pc/bg_main_genie.png" width="300px" alt="Genie">
# </a>
# <a href="#">
# 	<img src="https://blog.kakaocdn.net/dn/0RVHq/btrbhZjXIC9/5peXUNCKSxIcpJkLTDerKK/img.jpg" width="350px" alt="Bugs">
# </a> <br>
#
# > 수집 범위 : 2023년 주 단위 100위 내 음원 데이터 수집<br>
# > 수집 방법 : Requests 객체 크롤링 <br>
# > 수집 계획 :<br>
# >> 1.데이터 수집 사이트(음원 스트리밍)내 2023년 주간별 음원 데이터 크롤링 <br>
# >> 2.수집된 주간별 음원 차트 내 아티스트 기본정보 크롤링(활동유형 분류,활동인원) <br>
# >> 3.아티스트 유형이 그룹일 경우, 멤버 이름 수집<br>

# %% [markdown]
# ### 3. 수집 프로그램 구현
# #### (1) 기본 패키지 설치 및 기타 준비 <br>
# > 기본 패키지 설치<br>
# ![](imgs/img1.jpg)
#
# #### (2) 함수 설정<br>
# > transtime() 정의<br>
# ![](imgs/img2.jpg) <br>
# ###### datetime형식을 문자열 형식으로 바꿈

# %% [markdown]
# #### (3) Bugs <br>
# #### -1. 음원 차트 크롤링
# > step 1. Requests 객체 크롤링 준비<br><br>
# > step 2. url의 변수값<br><br>
# ![](imgs/bugs2.jpg)<br>
# > step 3. 음원 차트 크롤링 <br><br>
# ![](imgs/bugs1.jpg)<br>
# ***html*** <br>
# ![image.png](attachment:image.png)
# #### -2. 아티스트 크롤링
# > step 4. <br><br>
# ![](imgs/bugs3.jpg)<br>
# ***table class="info" > tr 중 th 내의 text값이 "유형"이면서 td.text값 안에 "그룹"이 있으면 그룹활동으로 인식한 후 멤버 수집***
#
#
#
# #### -3. DB저장
# > step 5. <br><br>
# ![](imgs/bugs4.jpg)<br>
#
# > step 6. <br><br>
# ![](imgs/bugs5.jpg)<br>
#
# #### -4. 결과
# > step 6. <br><br>
# ![](imgs/bugsresult.png)<br>
# ***ranking, title, artist, day 결과값 출력***

# %% [markdown]
# #### (4) Genie<br>
# #### -1. 음원 차트 크롤링
# > step 1. Requests 객체 크롤링 준비<br><br>
# > step 2. url의 변수값<br><br>
# ![](imgs/genie1.jpg)<br>
# > step 3. 음원 차트 크롤링 <br><br>
# ![](imgs/genie2.jpg)<br>
# ***url의 pg={}***<br><br>
# ![](imgs/genie5.jpg)<br>
#
# #### -2. 아티스트 크롤링
# > step 4. <br><br>
# ![](imgs/genie3.jpg)<br>
#
# > step 5. 데이터프레임 만들기<br><br>
# ![](imgs/geniedataframe.jpg)<br>
#
# #### -3. DB저장
# > step 6. <br><br>
# ![](imgs/genie4.jpg)<br>
#
#
# #### -4. 결과
# > step 7. <br><br>
# ![](imgs/genieresult.png)<br>
# ***ranking, title, artist, day 결과값 출력***
