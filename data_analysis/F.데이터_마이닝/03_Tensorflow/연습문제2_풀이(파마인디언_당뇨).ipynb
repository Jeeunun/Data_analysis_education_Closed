# %% [markdown]
# # 연습문제 02 풀이
#
# ## #01. 패키지 준비하기

# %%
import sys
sys.path.append('../../')
import helper

from pandas import read_excel, DataFrame
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## #02. 데이터셋 준비하기

# %%
origin = read_excel("https://data.hossam.kr/F03/pima-indians.xlsx")

print(origin.info())

origin.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### 결측치 확인

# %%
origin.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### 명목형 변수 형변환

# %%
origin['Outcome'] = origin['Outcome'].astype('category')
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    category
# dtypes: category(1), float64(2), int64(6)
# memory usage: 49.0 KB

# %% [markdown]
# ## #04. 탐색적 데이터 분석
#
# ### 기본통계 확인

# %%
origin.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# 25%     27.300000                  0.243750   24.000000
# 50%     32.000000                  0.372500   29.000000
# 75%     36.600000                  0.626250   41.000000
# max     67.100000                  2.420000   81.000000

# %% [markdown]
# ### 상자그림

# %%
plt.figure(figsize=(20, 5))
sb.boxplot(data=origin)
plt.show()
plt.close()

# %% [markdown]
# > 데이터 분포가 서로 상이하므로 표준화가 필요하다고 판단

# %% [markdown]
# ## #05. 데이터셋 분할하기
#
# ### 랜덤시드 고정

# %%
np.random.seed(777)

# %% [markdown]
# ### 훈련 데이터(독립변수)와 레이블(종속변수) 구분하기

# %%
x = origin.drop('Outcome', axis=1)
y = origin[['Outcome']]
print(x.shape, y.shape)
y
# Out:
# (768, 8) (768, 1)
#     Outcome
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
# ..      ...
# 763       0
# 764       0
# 765       0
# 766       1
# 767       0
#
# [768 rows x 1 columns]

# %% [markdown]
# ### 데이터 표준화

# %%
x_scaller = StandardScaler()
x_scale = x_scaller.fit_transform(x)
x_scale_df = DataFrame(x_scale, columns=x.columns, index=x.index)
x_scale_df.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1    -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2     1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3    -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4    -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.425995
# 1                 -0.365061 -0.190672
# 2                  0.604397 -0.105584
# 3                 -0.920763 -1.041549
# 4                  5.484909 -0.020496

# %% [markdown]
# ### 훈련 데이터와 검증 데이터로 분할

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scale_df, y, test_size=0.3, random_state=777)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
x_train
# Out:
# (537, 8) (231, 8) (537, 1) (231, 1)
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 335    -1.141852  1.380375       0.356432       1.409094  1.521248  2.018958
# 130     0.046014  1.630752       0.046245      -0.410019  0.765836 -0.290972
# 255    -0.844885 -0.247076      -0.263941       0.907270 -0.692891  0.204013
# 573    -0.547919 -0.716533      -0.470732      -0.221835  0.349057  0.343624
# 764    -0.547919  0.034598       0.046245       0.405445 -0.692891  0.610154
# ..           ...       ...            ...            ...       ...       ...
# 669     1.530847  1.036107       0.459827       0.593630  0.175399 -0.138669
# 71      0.342981  0.566649      -0.263941       0.907270  0.522715 -0.430583
# 599    -0.844885 -0.372265      -1.608083      -0.159107  0.349057 -1.128639
# 571    -0.547919  0.284975       1.390387      -1.288212 -0.692891 -1.192099
# 103    -0.844885 -1.248585       0.149641      -0.159107 -0.345575 -0.684422
#
#      DiabetesPedigreeFunction       Age
# 335                 -0.642912 -0.616111
# 130                 -0.334860 -0.020496
# 255                  0.214802 -1.041549
# 573                 -0.827139 -0.956462
# 764                 -0.398282 -0.531023
# ..                        ...       ...
# 669                 -0.929823  1.000557
# 71                  -0.183854 -0.616111
# 599                 -0.195934 -0.616111
# 571                 -0.615731 -1.041549
# 103                 -0.570429 -0.786286
#
# [537 rows x 8 columns]

# %% [markdown]
# ## #06. 모델 개발
#
# ### 모델 정의

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(len(x_train.columns), )))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss = 'binary_crossentropy', metrics = ['acc'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 32)                288
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 321 (1.25 KB)
# Trainable params: 321 (1.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 학습하기

# %%
result = model.fit(x_train, y_train, epochs = 500, validation_data = (x_test, y_test), callbacks = [
    EarlyStopping(monitor = 'val_loss', patience=5, verbose = 1),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.5, min_lr=0.0001, verbose=1)
])
# Out:
# Epoch 1/500
# 17/17 [==============================] - 1s 15ms/step - loss: 0.7432 - acc: 0.3966 - val_loss: 0.7164 - val_acc: 0.3983 - lr: 0.0010
# Epoch 2/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6797 - acc: 0.5754 - val_loss: 0.6641 - val_acc: 0.6840 - lr: 0.0010
# Epoch 3/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6338 - acc: 0.7300 - val_loss: 0.6229 - val_acc: 0.7489 - lr: 0.0010
# Epoch 4/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5969 - acc: 0.7598 - val_loss: 0.5896 - val_acc: 0.7403 - lr: 0.0010
# Epoch 5/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5669 - acc: 0.7635 - val_loss: 0.5619 - val_acc: 0.7619 - lr: 0.0010
# Epoch 6/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5430 - acc: 0.7765 - val_loss: 0.5411 - val_acc: 0.7662 - lr: 0.0010
# Epoch 7/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5234 - acc: 0.7672 - val_loss: 0.5253 - val_acc: 0.7662 - lr: 0.0010
# Epoch 8/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5078 - acc: 0.7747 - val_loss: 0.5126 - val_acc: 0.7706 - lr: 0.0010
# Epoch 9/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4944 - acc: 0.7840 - val_loss: 0.5013 - val_acc: 0.7662 - lr: 0.0010
# Epoch 10/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4840 - acc: 0.7896 - val_loss: 0.4941 - val_acc: 0.7662 - lr: 0.0010
# Epoch 11/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4752 - acc: 0.7933 - val_loss: 0.4892 - val_acc: 0.7662 - lr: 0.0010
# Epoch 12/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4687 - acc: 0.7858 - val_loss: 0.4847 - val_acc: 0.7662 - lr: 0.0010
# Epoch 13/500
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4626 - acc: 0.7914 - val_loss: 0.4813 - val_acc: 0.7706 - lr: 0.0010
# Epoch 14/500
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4580 - acc: 0.7989 - val_loss: 0.4790 - val_acc: 0.7706 - lr: 0.0010
# Epoch 15/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.4541 - acc: 0.7896 - val_loss: 0.4782 - val_acc: 0.7706 - lr: 0.0010
# Epoch 16/500
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4510 - acc: 0.7896 - val_loss: 0.4773 - val_acc: 0.7706 - lr: 0.0010
# Epoch 17/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4482 - acc: 0.7877 - val_loss: 0.4762 - val_acc: 0.7706 - lr: 0.0010
# Epoch 18/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4453 - acc: 0.7933 - val_loss: 0.4754 - val_acc: 0.7749 - lr: 0.0010
# Epoch 19/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4428 - acc: 0.7933 - val_loss: 0.4735 - val_acc: 0.7749 - lr: 0.0010
# Epoch 20/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4409 - acc: 0.7952 - val_loss: 0.4735 - val_acc: 0.7749 - lr: 0.0010
# Epoch 21/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4391 - acc: 0.7933 - val_loss: 0.4729 - val_acc: 0.7749 - lr: 0.0010
# Epoch 22/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4378 - acc: 0.7914 - val_loss: 0.4726 - val_acc: 0.7749 - lr: 0.0010
# Epoch 23/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4360 - acc: 0.7952 - val_loss: 0.4718 - val_acc: 0.7792 - lr: 0.0010
# Epoch 24/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4348 - acc: 0.7952 - val_loss: 0.4712 - val_acc: 0.7749 - lr: 0.0010
# Epoch 25/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4334 - acc: 0.7952 - val_loss: 0.4721 - val_acc: 0.7706 - lr: 0.0010
# Epoch 26/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4326 - acc: 0.7989 - val_loss: 0.4718 - val_acc: 0.7706 - lr: 0.0010
# Epoch 27/500
#  1/17 [>.............................] - ETA: 0s - loss: 0.3760 - acc: 0.8125
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4315 - acc: 0.7989 - val_loss: 0.4718 - val_acc: 0.7706 - lr: 0.0010
# Epoch 28/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4297 - acc: 0.7989 - val_loss: 0.4717 - val_acc: 0.7706 - lr: 5.0000e-04
# Epoch 29/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4292 - acc: 0.7970 - val_loss: 0.4719 - val_acc: 0.7706 - lr: 5.0000e-04
# Epoch 29: early stopping

# %% [markdown]
# ## #07. 학습 결과 평가

# %%
helper.tf_result_plot(result)

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 정확도: %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 정확도: %f" % (evaluate2[0], evaluate2[1]))
# Out:
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4278 - acc: 0.8007
# 최종 훈련 손실률: 0.427754, 최종 훈련 정확도: 0.800745
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4719 - acc: 0.7706
# 최종 검증 손실률: 0.471875, 최종 검증 정확도: 0.770563

# %% [markdown]
# ## #08. 학습 결과 적용

# %% [markdown]
# ### 테스트 데이터에 대한 예측 결과 산정

# %%
train_pred = model.predict(x_train)
data_count, case_count = train_pred.shape
print("%d개의 훈련 데이터가 %d개의 경우의 수를 갖는다." % (data_count, case_count))
print(train_pred)
# Out:
# 17/17 [==============================] - 0s 1ms/step
# 537개의 훈련 데이터가 1개의 경우의 수를 갖는다.
# [[0.7587165 ]
#  [0.70539224]
#  [0.16036218]
#  [0.0883249 ]
#  [0.28318506]
#  [0.0529904 ]
#  [0.18908793]
#  [0.38575438]
#  [0.55694205]
#  [0.25656968]
#  [0.43835095]
#  [0.2753174 ]
#  [0.4150651 ]
#  [0.00763284]
#  [0.66676295]
#  [0.38881266]
#  [0.10510867]
#  [0.58478636]
#  [0.04948221]
#  [0.07094605]
#  [0.09466459]
#  [0.17840336]
#  [0.2675588 ]
#  [0.22994368]
#  [0.18313839]
#  [0.09531978]
#  [0.25791004]
#  [0.01923078]
#  [0.44163767]
#  [0.04374368]
#  [0.18298158]
#  [0.12506723]
#  [0.18480983]
#  [0.68217427]
#  [0.7936663 ]
#  [0.66630363]
#  [0.0282752 ]
#  [0.30591697]
#  [0.42475626]
#  [0.17112947]
#  [0.23881261]
#  [0.10008575]
#  [0.0295562 ]
#  [0.32169443]
#  [0.03359554]
#  [0.518792  ]
#  [0.6025914 ]
#  [0.6660797 ]
#  [0.12654004]
#  [0.51788014]
#  [0.04864885]
#  [0.03332975]
#  [0.18661995]
#  [0.62752795]
#  [0.18289332]
#  [0.7393103 ]
#  [0.17970489]
#  [0.89373386]
#  [0.29245257]
#  [0.28312427]
#  [0.06122546]
#  [0.8594213 ]
#  [0.15211305]
#  [0.79719055]
#  [0.10917949]
#  [0.4595032 ]
#  [0.86349404]
#  [0.57419544]
#  [0.94415927]
#  [0.20659679]
#  [0.49587065]
#  [0.50445575]
#  [0.66781837]
#  [0.15009652]
#  [0.6082756 ]
#  [0.0160597 ]
#  [0.74598795]
#  [0.94710696]
#  [0.0429165 ]
#  [0.8377354 ]
#  [0.03315138]
#  [0.30472842]
#  [0.27477545]
#  [0.83936125]
#  [0.18500824]
#  [0.53579235]
#  [0.46390054]
#  [0.4873932 ]
#  [0.8536961 ]
#  [0.52430046]
#  [0.6874594 ]
#  [0.14170046]
#  [0.52815247]
#  [0.10579969]
#  [0.00612644]
#  [0.04325331]
#  [0.05605607]
#  [0.24954127]
#  [0.03002212]
#  [0.92734426]
#  [0.22453654]
#  [0.15843329]
#  [0.7850143 ]
#  [0.24148281]
#  [0.7781542 ]
#  [0.08377173]
#  [0.36933887]
#  [0.8172908 ]
#  [0.2029866 ]
#  [0.3683092 ]
#  [0.7312801 ]
#  [0.10126181]
#  [0.60875034]
#  [0.2719627 ]
#  [0.5996228 ]
#  [0.12089305]
#  [0.9149113 ]
#  [0.12301771]
#  [0.74412525]
#  [0.5699465 ]
#  [0.3919466 ]
#  [0.11852282]
#  [0.800352  ]
#  [0.5176531 ]
#  [0.37372148]
#  [0.19884576]
#  [0.10686828]
#  [0.04924026]
#  [0.15690003]
#  [0.22571792]
#  [0.0506065 ]
#  [0.2159959 ]
#  [0.47431326]
#  [0.04841202]
#  [0.12570746]
#  [0.6342818 ]
#  [0.13496913]
#  [0.4101032 ]
#  [0.4363044 ]
#  [0.33330405]
#  [0.07451016]
#  [0.2709178 ]
#  [0.0949328 ]
#  [0.71917874]
#  [0.558051  ]
#  [0.04869578]
#  [0.27423447]
#  [0.14919522]
#  [0.05533098]
#  [0.8264936 ]
#  [0.9187522 ]
#  [0.69591856]
#  [0.06454846]
#  [0.14204723]
#  [0.28117728]
#  [0.0319531 ]
#  [0.09286577]
#  [0.16484313]
#  [0.01574749]
#  [0.03312977]
#  [0.69958085]
#  [0.03475251]
#  [0.3591892 ]
#  [0.22112966]
#  [0.16969784]
#  [0.27458528]
#  [0.14943503]
#  [0.02589089]
#  [0.48997873]
#  [0.6132857 ]
#  [0.79461765]
#  [0.02730273]
#  [0.11624055]
#  [0.96265197]
#  [0.31512517]
#  [0.03150691]
#  [0.06870836]
#  [0.8058412 ]
#  [0.0488797 ]
#  [0.27114275]
#  [0.36731195]
#  [0.35681838]
#  [0.16252437]
#  [0.57045805]
#  [0.9514001 ]
#  [0.7148418 ]
#  [0.6304125 ]
#  [0.37710163]
#  [0.0711057 ]
#  [0.37354952]
#  [0.12578562]
#  [0.04064661]
#  [0.23840494]
#  [0.8782319 ]
#  [0.2432091 ]
#  [0.8055384 ]
#  [0.07510301]
#  [0.05611612]
#  [0.05770599]
#  [0.05867403]
#  [0.3089178 ]
#  [0.15885232]
#  [0.16311596]
#  [0.8537121 ]
#  [0.6172771 ]
#  [0.2890707 ]
#  [0.09021933]
#  [0.79414535]
#  [0.19619994]
#  [0.3806105 ]
#  [0.9002137 ]
#  [0.10304538]
#  [0.45564407]
#  [0.22760512]
#  [0.8169541 ]
#  [0.20287693]
#  [0.93345696]
#  [0.32839227]
#  [0.10859555]
#  [0.2522688 ]
#  [0.09741387]
#  [0.43471724]
#  [0.7987653 ]
#  [0.10735333]
#  [0.8748221 ]
#  [0.58051306]
#  [0.7967809 ]
#  [0.7171843 ]
#  [0.0469209 ]
#  [0.09098488]
#  [0.53648627]
#  [0.08834422]
#  [0.19668546]
#  [0.06203164]
#  [0.9059195 ]
#  [0.3471732 ]
#  [0.2503399 ]
#  [0.7966032 ]
#  [0.84952646]
#  [0.89506817]
#  [0.19191833]
#  [0.1099045 ]
#  [0.6545799 ]
#  [0.84761894]
#  [0.80532753]
#  [0.8797653 ]
#  [0.01044235]
#  [0.26738477]
#  [0.12364991]
#  [0.9339071 ]
#  [0.7794427 ]
#  [0.32082775]
#  [0.9194984 ]
#  [0.5063868 ]
#  [0.10828413]
#  [0.34128752]
#  [0.80477196]
#  [0.5252069 ]
#  [0.27443546]
#  [0.32614422]
#  [0.2332156 ]
#  [0.01837796]
#  [0.3220947 ]
#  [0.7110082 ]
#  [0.0766068 ]
#  [0.12233142]
#  [0.18705182]
#  [0.04930414]
#  [0.33044645]
#  [0.79553336]
#  [0.31766766]
#  [0.02805883]
#  [0.0724415 ]
#  [0.7174373 ]
#  [0.12880816]
#  [0.1022689 ]
#  [0.11201207]
#  [0.32444265]
#  [0.8732064 ]
#  [0.5162957 ]
#  [0.48386696]
#  [0.02833557]
#  [0.02034675]
#  [0.02143191]
#  [0.00383193]
#  [0.4467759 ]
#  [0.02853873]
#  [0.00771359]
#  [0.57310015]
#  [0.03324496]
#  [0.17241493]
#  [0.02779993]
#  [0.4548903 ]
#  [0.86296856]
#  [0.3350108 ]
#  [0.1532775 ]
#  [0.45450774]
#  [0.4624916 ]
#  [0.18699159]
#  [0.7351114 ]
#  [0.13750048]
#  [0.45569947]
#  [0.5312713 ]
#  [0.27493525]
#  [0.9609009 ]
#  [0.45253167]
#  [0.812545  ]
#  [0.20930153]
#  [0.79746455]
#  [0.5889064 ]
#  [0.23245372]
#  [0.31364107]
#  [0.12691529]
#  [0.14089857]
#  [0.11064986]
#  [0.9201802 ]
#  [0.2699117 ]
#  [0.4944384 ]
#  [0.03975894]
#  [0.05419945]
#  [0.03258674]
#  [0.6166429 ]
#  [0.14948604]
#  [0.0866315 ]
#  [0.4612911 ]
#  [0.19945769]
#  [0.02551255]
#  [0.25437626]
#  [0.02634061]
#  [0.23898527]
#  [0.8549571 ]
#  [0.01061325]
#  [0.547373  ]
#  [0.9569354 ]
#  [0.15879315]
#  [0.5355996 ]
#  [0.7335177 ]
#  [0.02391529]
#  [0.7853515 ]
#  [0.08820853]
#  [0.41007733]
#  [0.44094357]
#  [0.5817154 ]
#  [0.08821416]
#  [0.17642781]
#  [0.05961201]
#  [0.94592905]
#  [0.0289944 ]
#  [0.6514886 ]
#  [0.71954423]
#  [0.09987383]
#  [0.06328106]
#  [0.76232964]
#  [0.8841965 ]
#  [0.32954815]
#  [0.13050951]
#  [0.03544946]
#  [0.09418252]
#  [0.08237167]
#  [0.40196675]
#  [0.6900612 ]
#  [0.2595498 ]
#  [0.02110472]
#  [0.17242806]
#  [0.78298986]
#  [0.06282078]
#  [0.22609073]
#  [0.40145433]
#  [0.18973136]
#  [0.34330413]
#  [0.12115309]
#  [0.27445602]
#  [0.26358724]
#  [0.12474932]
#  [0.0638745 ]
#  [0.33786836]
#  [0.8936446 ]
#  [0.17270298]
#  [0.43650663]
#  [0.9289049 ]
#  [0.6055491 ]
#  [0.82779574]
#  [0.10191363]
#  [0.2768963 ]
#  [0.556654  ]
#  [0.57926935]
#  [0.0232717 ]
#  [0.00164647]
#  [0.40522793]
#  [0.03625995]
#  [0.5706342 ]
#  [0.29228592]
#  [0.04240547]
#  [0.9232058 ]
#  [0.55244875]
#  [0.09285725]
#  [0.08263063]
#  [0.35193303]
#  [0.02564434]
#  [0.61391765]
#  [0.81382555]
#  [0.54690653]
#  [0.5586444 ]
#  [0.59957093]
#  [0.7405243 ]
#  [0.05164888]
#  [0.5366817 ]
#  [0.33805963]
#  [0.02176429]
#  [0.14549941]
#  [0.56884134]
#  [0.5071512 ]
#  [0.17178018]
#  [0.20615599]
#  [0.18927974]
#  [0.05561021]
#  [0.09951659]
#  [0.80219275]
#  [0.82152635]
#  [0.83652693]
#  [0.17203486]
#  [0.53498584]
#  [0.3747872 ]
#  [0.54410297]
#  [0.26585737]
#  [0.78727806]
#  [0.5016414 ]
#  [0.25002432]
#  [0.5956548 ]
#  [0.68848586]
#  [0.47780097]
#  [0.7873531 ]
#  [0.04380273]
#  [0.0889516 ]
#  [0.15916435]
#  [0.39471805]
#  [0.60662687]
#  [0.85241145]
#  [0.11428159]
#  [0.34327242]
#  [0.08449806]
#  [0.28979224]
#  [0.7520465 ]
#  [0.09948173]
#  [0.5501994 ]
#  [0.47046205]
#  [0.00315867]
#  [0.9057972 ]
#  [0.67778295]
#  [0.41098785]
#  [0.3002392 ]
#  [0.45554122]
#  [0.26424026]
#  [0.80218387]
#  [0.2100387 ]
#  [0.06491998]
#  [0.36273137]
#  [0.6936563 ]
#  [0.36518654]
#  [0.79586834]
#  [0.7827967 ]
#  [0.6490817 ]
#  [0.7338492 ]
#  [0.39679986]
#  [0.4359709 ]
#  [0.03079531]
#  [0.02880163]
#  [0.05478185]
#  [0.20725857]
#  [0.14019415]
#  [0.06494445]
#  [0.44006985]
#  [0.40056062]
#  [0.25127047]
#  [0.43246332]
#  [0.35768753]
#  [0.5868904 ]
#  [0.39794236]
#  [0.73260033]
#  [0.80930775]
#  [0.11090091]
#  [0.0736419 ]
#  [0.18333541]
#  [0.47865173]
#  [0.39534605]
#  [0.06385649]
#  [0.71426874]
#  [0.88556117]
#  [0.22737503]
#  [0.03358121]
#  [0.16598429]
#  [0.03505025]
#  [0.62945753]
#  [0.2945614 ]
#  [0.93908507]
#  [0.42308587]
#  [0.79453   ]
#  [0.0764405 ]
#  [0.0568717 ]
#  [0.07243766]
#  [0.09431274]
#  [0.64604557]
#  [0.17699233]
#  [0.8056839 ]
#  [0.7469496 ]
#  [0.59663093]
#  [0.45499954]
#  [0.8115968 ]
#  [0.07878362]
#  [0.00657362]
#  [0.15780006]
#  [0.14073302]
#  [0.3892274 ]
#  [0.24398465]
#  [0.23431507]
#  [0.07834937]
#  [0.03312511]
#  [0.04212271]
#  [0.5380894 ]
#  [0.07869293]
#  [0.42837772]
#  [0.21990345]
#  [0.11437577]
#  [0.10268927]
#  [0.03459816]
#  [0.08067876]
#  [0.16779807]
#  [0.7817648 ]
#  [0.7705299 ]
#  [0.12940736]
#  [0.47452337]
#  [0.02911916]
#  [0.5934445 ]
#  [0.37395257]
#  [0.07580031]
#  [0.05579599]
#  [0.02257666]]

# %%
train_df = DataFrame({
    '관측치': y_train['Outcome'],
    '예측치': np.round(train_pred.flatten())
})

train_df
# Out:
#     관측치  예측치
# 335   0  1.0
# 130   1  1.0
# 255   1  0.0
# 573   0  0.0
# 764   0  0.0
# ..   ..  ...
# 669   0  1.0
# 71    0  0.0
# 599   0  0.0
# 571   0  0.0
# 103   0  0.0
#
# [537 rows x 2 columns]

# %% [markdown]
# ### 검증 데이터에 대한 예측 결과 산정

# %%
test_pred = model.predict(x_test)
data_count, case_count = test_pred.shape
print("%d개의 검증 데이터가 %d개의 경우의 수를 갖는다." % (data_count, case_count))
print(test_pred)
# Out:
# 8/8 [==============================] - 0s 2ms/step
# 231개의 검증 데이터가 1개의 경우의 수를 갖는다.
# [[0.4095466 ]
#  [0.9278718 ]
#  [0.9121094 ]
#  [0.14674103]
#  [0.2590143 ]
#  [0.6648184 ]
#  [0.53557104]
#  [0.10411903]
#  [0.9552404 ]
#  [0.17364475]
#  [0.06052623]
#  [0.13850431]
#  [0.02816506]
#  [0.10023766]
#  [0.21097653]
#  [0.0697668 ]
#  [0.0703441 ]
#  [0.3388656 ]
#  [0.7034608 ]
#  [0.11953558]
#  [0.05604772]
#  [0.4417996 ]
#  [0.8906528 ]
#  [0.7929298 ]
#  [0.1490157 ]
#  [0.17224483]
#  [0.06915471]
#  [0.8273966 ]
#  [0.06560282]
#  [0.5743799 ]
#  [0.11923461]
#  [0.08716055]
#  [0.25010318]
#  [0.04611822]
#  [0.16521448]
#  [0.03512973]
#  [0.2148886 ]
#  [0.14833507]
#  [0.68232965]
#  [0.01271112]
#  [0.12908304]
#  [0.25298277]
#  [0.06936684]
#  [0.8933828 ]
#  [0.621965  ]
#  [0.01570312]
#  [0.17361629]
#  [0.14617655]
#  [0.04048602]
#  [0.09264685]
#  [0.7203303 ]
#  [0.07552185]
#  [0.06696414]
#  [0.25550756]
#  [0.27822933]
#  [0.06338464]
#  [0.06100713]
#  [0.9652028 ]
#  [0.5511132 ]
#  [0.7737991 ]
#  [0.34211767]
#  [0.7965873 ]
#  [0.8774713 ]
#  [0.7648445 ]
#  [0.37582123]
#  [0.0665177 ]
#  [0.0415625 ]
#  [0.13172896]
#  [0.00134934]
#  [0.13226323]
#  [0.53172153]
#  [0.2291824 ]
#  [0.11706731]
#  [0.8146609 ]
#  [0.17593469]
#  [0.6098592 ]
#  [0.7661167 ]
#  [0.0279557 ]
#  [0.4455556 ]
#  [0.04795656]
#  [0.09694757]
#  [0.12133667]
#  [0.21166305]
#  [0.6950058 ]
#  [0.7835544 ]
#  [0.02755445]
#  [0.77241313]
#  [0.36129966]
#  [0.37488356]
#  [0.6758793 ]
#  [0.10259803]
#  [0.41079152]
#  [0.91714275]
#  [0.3770753 ]
#  [0.44347903]
#  [0.16300252]
#  [0.3487026 ]
#  [0.21088481]
#  [0.24120417]
#  [0.1814257 ]
#  [0.2824564 ]
#  [0.02903904]
#  [0.05697596]
#  [0.92473507]
#  [0.09007146]
#  [0.6298298 ]
#  [0.857173  ]
#  [0.22185206]
#  [0.2763393 ]
#  [0.44679132]
#  [0.03907516]
#  [0.35820347]
#  [0.27547854]
#  [0.43061298]
#  [0.5315072 ]
#  [0.40358427]
#  [0.11351942]
#  [0.8709083 ]
#  [0.80073893]
#  [0.7472385 ]
#  [0.33290035]
#  [0.14154609]
#  [0.5092741 ]
#  [0.04027192]
#  [0.5728201 ]
#  [0.9951441 ]
#  [0.34728965]
#  [0.03790627]
#  [0.15553309]
#  [0.34799147]
#  [0.26183304]
#  [0.34856576]
#  [0.10316905]
#  [0.17536062]
#  [0.24496529]
#  [0.13221744]
#  [0.7534436 ]
#  [0.05527855]
#  [0.254505  ]
#  [0.91338074]
#  [0.06934121]
#  [0.28201514]
#  [0.17173526]
#  [0.03015175]
#  [0.866301  ]
#  [0.7519852 ]
#  [0.929847  ]
#  [0.06541529]
#  [0.4791765 ]
#  [0.48426193]
#  [0.04224055]
#  [0.679227  ]
#  [0.06423344]
#  [0.48481774]
#  [0.18574397]
#  [0.84541327]
#  [0.07434555]
#  [0.87880826]
#  [0.05065788]
#  [0.45410994]
#  [0.06350464]
#  [0.04550446]
#  [0.40648478]
#  [0.10785916]
#  [0.28600577]
#  [0.05588634]
#  [0.91463125]
#  [0.28007776]
#  [0.914993  ]
#  [0.10127506]
#  [0.15614437]
#  [0.0300189 ]
#  [0.19862005]
#  [0.20588967]
#  [0.2156855 ]
#  [0.89954364]
#  [0.01270634]
#  [0.05861798]
#  [0.27347955]
#  [0.6491032 ]
#  [0.06710102]
#  [0.5145653 ]
#  [0.22166285]
#  [0.12516221]
#  [0.55770123]
#  [0.04640659]
#  [0.09432893]
#  [0.11838339]
#  [0.27083996]
#  [0.30118614]
#  [0.17544787]
#  [0.23100823]
#  [0.15467234]
#  [0.81485623]
#  [0.13938646]
#  [0.1040563 ]
#  [0.28149322]
#  [0.21745442]
#  [0.5332497 ]
#  [0.3225931 ]
#  [0.28152293]
#  [0.05422556]
#  [0.9180681 ]
#  [0.2784073 ]
#  [0.97117764]
#  [0.0614558 ]
#  [0.28810856]
#  [0.14020452]
#  [0.24104871]
#  [0.20258167]
#  [0.40879652]
#  [0.04542334]
#  [0.37260956]
#  [0.5959862 ]
#  [0.01238369]
#  [0.26817843]
#  [0.91196704]
#  [0.1917884 ]
#  [0.4127213 ]
#  [0.11693692]
#  [0.12535729]
#  [0.7467666 ]
#  [0.9383196 ]
#  [0.6143868 ]
#  [0.09158134]
#  [0.10162505]
#  [0.48515505]
#  [0.03588285]
#  [0.02139728]
#  [0.13716438]
#  [0.72651   ]]

# %% [markdown]
# > 50% 보다 작으면 0 , 50% 보다 크면 1

# %% [markdown]
# ### 결과 데이터 셋 구성

# %%
test_df = DataFrame({
    '관측치': y_test['Outcome'],
    '예측치': np.round(test_pred.flatten())
})

test_df
# Out:
#     관측치  예측치
# 387   1  0.0
# 43    1  1.0
# 408   1  1.0
# 262   0  0.0
# 533   0  0.0
# ..   ..  ...
# 46    0  0.0
# 290   0  0.0
# 418   0  0.0
# 434   0  0.0
# 267   0  1.0
#
# [231 rows x 2 columns]

# %% [markdown]
# ### 결과 확인

# %%
logit = helper.tf_logit_result(model, result, x_train, y_train)
logit
# Out:
# 17/17 [==============================] - 0s 1ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 32)                288
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 321 (1.25 KB)
# Trainable params: 321 (1.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
logit.cmdf
# Out:
#        Negative  Positive
# True        299        65
# False        42       131

# %%
logit.result_df.T
# Out:
#                               0
# 정확도(Accuracy)          0.800745
# 정밀도(Precision)         0.757225
# 재현율(Recall, TPR)       0.668367
# 위양성율(Fallout, FPR)     0.123167
# 특이성(Specificity, TNR)  0.876833
# RAS                    0.772600
# f1_score               0.710027

# %%
logit.odds_rate_df
# Out:
# array([1.1625139], dtype=float32)
