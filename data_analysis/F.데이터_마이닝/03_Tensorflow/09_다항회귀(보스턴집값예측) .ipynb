# %% [markdown]
# # 보스턴 집값 예측하기 - 다항회귀
#
# ## #01. 패키지 설치

# %%
import sys
sys.path.append('../../')
import helper

from pandas import read_excel, DataFrame, merge
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %% [markdown]
# ## #02. 데이터셋 준비

# %%
origin = read_excel("https://data.hossam.kr/E04/boston.xlsx")
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   INDUS      506 non-null    float64
#  3   CHAS       506 non-null    int64
#  4   NOX        506 non-null    float64
#  5   RM         506 non-null    float64
#  6   AGE        506 non-null    float64
#  7   DIS        506 non-null    float64
#  8   RAD        506 non-null    int64
#  9   TAX        506 non-null    int64
#  10  PTRATIO    506 non-null    float64
#  11  B          506 non-null    float64
#  12  LSTAT      506 non-null    float64
#  13  MEDV       506 non-null    float64
#  14  CAT. MEDV  506 non-null    int64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### 결측치 확인

# %%
origin.isnull().sum()
# Out:
# CRIM         0
# ZN           0
# INDUS        0
# CHAS         0
# NOX          0
# RM           0
# AGE          0
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# B            0
# LSTAT        0
# MEDV         0
# CAT. MEDV    0
# dtype: int64

# %% [markdown]
# ## #04. 탐색적 데이터 분석
#
# ### 명목형 처리

# %%
origin['CHAS'] = origin['CHAS'].astype('category')
origin['CAT. MEDV'] = origin['CAT. MEDV'].astype('category')
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   INDUS      506 non-null    float64
#  3   CHAS       506 non-null    category
#  4   NOX        506 non-null    float64
#  5   RM         506 non-null    float64
#  6   AGE        506 non-null    float64
#  7   DIS        506 non-null    float64
#  8   RAD        506 non-null    int64
#  9   TAX        506 non-null    int64
#  10  PTRATIO    506 non-null    float64
#  11  B          506 non-null    float64
#  12  LSTAT      506 non-null    float64
#  13  MEDV       506 non-null    float64
#  14  CAT. MEDV  506 non-null    category
# dtypes: category(2), float64(11), int64(2)
# memory usage: 52.7 KB

# %% [markdown]
# ### 기본통계 확인

# %%
origin.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         RAD         TAX     PTRATIO           B       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043    9.549407  408.237154   18.455534  356.674032   12.653063
# std      2.105710    8.707259  168.537116    2.164946   91.294864    7.141062
# min      1.129600    1.000000  187.000000   12.600000    0.320000    1.730000
# 25%      2.100175    4.000000  279.000000   17.400000  375.377500    6.950000
# 50%      3.207450    5.000000  330.000000   19.050000  391.440000   11.360000
# 75%      5.188425   24.000000  666.000000   20.200000  396.225000   16.955000
# max     12.126500   24.000000  711.000000   22.000000  396.900000   37.970000
#
#              MEDV
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %% [markdown]
# ### 상자그림

# %%
plt.figure(figsize=(10,5))
sb.boxplot(data=origin)
plt.show()
plt.close()

# %% [markdown]
# ### 산점도 그래프와 추세선 확인

# %%
# plt.figure(figsize=(30,30))
# sb.pairplot(data=origin)
# plt.show()
# plt.close()

# %% [markdown]
# ### 상관계수 확인

# %%
corr = origin.drop('MEDV', axis=1).corr()
corr
# Out:
#                CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM       1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN        -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS      0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS      -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX        0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM        -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE        0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS       -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD        0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX        0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO    0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B         -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# LSTAT      0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808
# CAT. MEDV -0.151987  0.365296 -0.366276  0.108631 -0.232502  0.641265
#
#                 AGE       DIS       RAD       TAX   PTRATIO         B  \
# CRIM       0.352734 -0.379670  0.625505  0.582764  0.289946 -0.385064
# ZN        -0.569537  0.664408 -0.311948 -0.314563 -0.391679  0.175520
# INDUS      0.644779 -0.708027  0.595129  0.720760  0.383248 -0.356977
# CHAS       0.086518 -0.099176 -0.007368 -0.035587 -0.121515  0.048788
# NOX        0.731470 -0.769230  0.611441  0.668023  0.188933 -0.380051
# RM        -0.240265  0.205246 -0.209847 -0.292048 -0.355501  0.128069
# AGE        1.000000 -0.747881  0.456022  0.506456  0.261515 -0.273534
# DIS       -0.747881  1.000000 -0.494588 -0.534432 -0.232471  0.291512
# RAD        0.456022 -0.494588  1.000000  0.910228  0.464741 -0.444413
# TAX        0.506456 -0.534432  0.910228  1.000000  0.460853 -0.441808
# PTRATIO    0.261515 -0.232471  0.464741  0.460853  1.000000 -0.177383
# B         -0.273534  0.291512 -0.444413 -0.441808 -0.177383  1.000000
# LSTAT      0.602339 -0.496996  0.488676  0.543993  0.374044 -0.366087
# CAT. MEDV -0.191196  0.118887 -0.197924 -0.273687 -0.443425  0.155137
#
#               LSTAT  CAT. MEDV
# CRIM       0.455621  -0.151987
# ZN        -0.412995   0.365296
# INDUS      0.603800  -0.366276
# CHAS      -0.053929   0.108631
# NOX        0.590879  -0.232502
# RM        -0.613808   0.641265
# AGE        0.602339  -0.191196
# DIS       -0.496996   0.118887
# RAD        0.488676  -0.197924
# TAX        0.543993  -0.273687
# PTRATIO    0.374044  -0.443425
# B         -0.366087   0.155137
# LSTAT      1.000000  -0.469911
# CAT. MEDV -0.469911   1.000000

# %% [markdown]
# ### 상관계수 히트맵

# %%
plt.figure(figsize=(15,10))
sb.heatmap(corr, annot=True, cmap='PuBu', vmin=-1, vmax=1, linewidths=0.5)
plt.show()
plt.close()

# %% [markdown]
# ### 제외하기로 한 독립변수 제거
# > 상관계수의 절대값이 0.7이상인 항목을 순차적으로 제거하여 회귀분석에 사용할 요인을 선정

# %%
x = origin.drop(['TAX','DIS','NOX','INDUS'], axis=1)
x
# Out:
#         CRIM    ZN CHAS     RM   AGE  RAD  PTRATIO       B  LSTAT  MEDV  \
# 0    0.00632  18.0    0  6.575  65.2    1     15.3  396.90   4.98  24.0
# 1    0.02731   0.0    0  6.421  78.9    2     17.8  396.90   9.14  21.6
# 2    0.02729   0.0    0  7.185  61.1    2     17.8  392.83   4.03  34.7
# 3    0.03237   0.0    0  6.998  45.8    3     18.7  394.63   2.94  33.4
# 4    0.06905   0.0    0  7.147  54.2    3     18.7  396.90   5.33  36.2
# ..       ...   ...  ...    ...   ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0    0  6.593  69.1    1     21.0  391.99   9.67  22.4
# 502  0.04527   0.0    0  6.120  76.7    1     21.0  396.90   9.08  20.6
# 503  0.06076   0.0    0  6.976  91.0    1     21.0  396.90   5.64  23.9
# 504  0.10959   0.0    0  6.794  89.3    1     21.0  393.45   6.48  22.0
# 505  0.04741   0.0    0  6.030  80.8    1     21.0  396.90   7.88  11.9
#
#     CAT. MEDV
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# ..        ...
# 501         0
# 502         0
# 503         0
# 504         0
# 505         0
#
# [506 rows x 11 columns]

# %%
plt.figure(figsize=(15,10))
sb.heatmap(x.corr(), annot=True, cmap='PuBu', vmin=-1, vmax=1, linewidths=0.5)
plt.show()
plt.close()

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   CHAS       506 non-null    category
#  3   RM         506 non-null    float64
#  4   AGE        506 non-null    float64
#  5   RAD        506 non-null    int64
#  6   PTRATIO    506 non-null    float64
#  7   B          506 non-null    float64
#  8   LSTAT      506 non-null    float64
#  9   MEDV       506 non-null    float64
#  10  CAT. MEDV  506 non-null    category
# dtypes: category(2), float64(8), int64(1)
# memory usage: 36.9 KB

# %% [markdown]
# ### 명목형 변수만 추출

# %%
categorical_df = x.filter(['CHAS','CAT','MEDV'])
categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CHAS    506 non-null    category
#  1   MEDV    506 non-null    float64
# dtypes: category(1), float64(1)
# memory usage: 4.7 KB

# %% [markdown]
# ### 종속변수만 추출

# %%
y = x['MEDV']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# ### 데이터프레임에서 추출한 필드를 제거

# %%
x.drop(['CHAS','CAT. MEDV', 'MEDV'], axis=1, inplace=True)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   RM       506 non-null    float64
#  3   AGE      506 non-null    float64
#  4   RAD      506 non-null    int64
#  5   PTRATIO  506 non-null    float64
#  6   B        506 non-null    float64
#  7   LSTAT    506 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 31.8 KB

# %% [markdown]
# ### 최종 산점도 행렬 확인

# %%
plt.figure(figsize=(30,30))
sb.pairplot(x)
plt.show()
plt.savefig("pairplot.png")
plt.close()
# Out:
# c:\Users\hanjieun_2\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## #05. 데이터 분리
#
# ### 랜덤시드 고정

# %%
np.random.seed(777)

# %% [markdown]
# ### 데이터 표준화

# %%
scaler = StandardScaler()
x_scale = scaler.fit_transform(x)
x_scale
# Out:
# array([[-0.41978194,  0.28482986,  0.41367189, ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236,  0.19427445, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236,  1.28271368, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.98496002, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.72567214, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236, -0.36276709, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %% [markdown]
# ### 표준화 결과를 다항식으로 변환

# %%
x_scale_df = DataFrame(x_scale, columns=x.columns)
x_scale_df
# Out:
#          CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 0   -0.419782  0.284830  0.413672 -0.120013 -0.982843 -1.459000  0.441052
# 1   -0.417339 -0.487722  0.194274  0.367166 -0.867883 -0.303094  0.441052
# 2   -0.417342 -0.487722  1.282714 -0.265812 -0.867883 -0.303094  0.396427
# 3   -0.416750 -0.487722  1.016303 -0.809889 -0.752922  0.113032  0.416163
# 4   -0.412482 -0.487722  1.228577 -0.511180 -0.752922  0.113032  0.441052
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.439316  0.018673 -0.982843  1.176466  0.387217
# 502 -0.415249 -0.487722 -0.234548  0.288933 -0.982843  1.176466  0.441052
# 503 -0.413447 -0.487722  0.984960  0.797449 -0.982843  1.176466  0.441052
# 504 -0.407764 -0.487722  0.725672  0.736996 -0.982843  1.176466  0.403225
# 505 -0.415000 -0.487722 -0.362767  0.434732 -0.982843  1.176466  0.441052
#
#         LSTAT
# 0   -1.075562
# 1   -0.492439
# 2   -1.208727
# 3   -1.361517
# 4   -1.026501
# ..        ...
# 501 -0.418147
# 502 -0.500850
# 503 -0.983048
# 504 -0.865302
# 505 -0.669058
#
# [506 rows x 8 columns]

# %% [markdown]
# ### 독립변수를 다항식으로 변환

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)
fit = poly.fit_transform(x_scale_df)
x2 = DataFrame(fit, columns=poly.get_feature_names_out())
x2.head()
# Out:
#        CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 0 -0.419782  0.284830  0.413672 -0.120013 -0.982843 -1.459000  0.441052
# 1 -0.417339 -0.487722  0.194274  0.367166 -0.867883 -0.303094  0.441052
# 2 -0.417342 -0.487722  1.282714 -0.265812 -0.867883 -0.303094  0.396427
# 3 -0.416750 -0.487722  1.016303 -0.809889 -0.752922  0.113032  0.416163
# 4 -0.412482 -0.487722  1.228577 -0.511180 -0.752922  0.113032  0.441052
#
#       LSTAT    CRIM^2   CRIM ZN  ...     RAD^2  RAD PTRATIO     RAD B  \
# 0 -1.075562  0.176217 -0.119566  ...  0.965980     1.433968 -0.433485
# 1 -0.492439  0.174172  0.203546  ...  0.753220     0.263050 -0.382781
# 2 -1.208727  0.174174  0.203547  ...  0.753220     0.263050 -0.344052
# 3 -1.361517  0.173681  0.203258  ...  0.566892    -0.085104 -0.313338
# 4 -1.026501  0.170141  0.201177  ...  0.566892    -0.085104 -0.332078
#
#    RAD LSTAT  PTRATIO^2  PTRATIO B  PTRATIO LSTAT       B^2   B LSTAT  \
# 0   1.057109   2.128682  -0.643495       1.569246  0.194527 -0.474379
# 1   0.427380   0.091866  -0.133680       0.149255  0.194527 -0.217191
# 2   1.049033   0.091866  -0.120155       0.366358  0.157154 -0.479172
# 3   1.025116   0.012776   0.047040      -0.153895  0.173192 -0.566613
# 4   0.772876   0.012776   0.049853      -0.116028  0.194527 -0.452740
#
#     LSTAT^2
# 0  1.156834
# 1  0.242497
# 2  1.461022
# 3  1.853728
# 4  1.053705
#
# [5 rows x 44 columns]

# %% [markdown]
# ### 분리해 놓은 명목형 데이터와 결합
# 1. 명목형 변수의 값이 0,1  두 종류 밖에 없기 때문에 별도로 더미변수 처리는 필요없다.
# 2. 표준화의 결과와 병합이 필요하지만 표준화 함수는 리턴타입이 numpy array이므로 이를 다시 DataFrame으로 변환해야만 명목형과 결합이 가능하다.

# %%
x_df = merge(x2, categorical_df, left_index=True, right_index=True)
x_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 46 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CRIM           506 non-null    float64
#  1   ZN             506 non-null    float64
#  2   RM             506 non-null    float64
#  3   AGE            506 non-null    float64
#  4   RAD            506 non-null    float64
#  5   PTRATIO        506 non-null    float64
#  6   B              506 non-null    float64
#  7   LSTAT          506 non-null    float64
#  8   CRIM^2         506 non-null    float64
#  9   CRIM ZN        506 non-null    float64
#  10  CRIM RM        506 non-null    float64
#  11  CRIM AGE       506 non-null    float64
#  12  CRIM RAD       506 non-null    float64
#  13  CRIM PTRATIO   506 non-null    float64
#  14  CRIM B         506 non-null    float64
#  15  CRIM LSTAT     506 non-null    float64
#  16  ZN^2           506 non-null    float64
#  17  ZN RM          506 non-null    float64
#  18  ZN AGE         506 non-null    float64
#  19  ZN RAD         506 non-null    float64
#  20  ZN PTRATIO     506 non-null    float64
#  21  ZN B           506 non-null    float64
#  22  ZN LSTAT       506 non-null    float64
#  23  RM^2           506 non-null    float64
#  24  RM AGE         506 non-null    float64
#  25  RM RAD         506 non-null    float64
#  26  RM PTRATIO     506 non-null    float64
#  27  RM B           506 non-null    float64
#  28  RM LSTAT       506 non-null    float64
#  29  AGE^2          506 non-null    float64
#  30  AGE RAD        506 non-null    float64
#  31  AGE PTRATIO    506 non-null    float64
#  32  AGE B          506 non-null    float64
#  33  AGE LSTAT      506 non-null    float64
#  34  RAD^2          506 non-null    float64
#  35  RAD PTRATIO    506 non-null    float64
#  36  RAD B          506 non-null    float64
#  37  RAD LSTAT      506 non-null    float64
#  38  PTRATIO^2      506 non-null    float64
#  39  PTRATIO B      506 non-null    float64
#  40  PTRATIO LSTAT  506 non-null    float64
#  41  B^2            506 non-null    float64
#  42  B LSTAT        506 non-null    float64
#  43  LSTAT^2        506 non-null    float64
#  44  CHAS           506 non-null    category
#  45  MEDV           506 non-null    float64
# dtypes: category(1), float64(45)
# memory usage: 178.6 KB

# %% [markdown]
# ### 훈련데이터와 검증데이터로 분할

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y, test_size=0.3, random_state=777)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 46), (152, 46), (354,), (152,))

# %% [markdown]
# ## #06. 모델생성

# %%
# 모델 객체 생성
model = Sequential()

# 첫번째 층
model.add(Dense(64, activation='relu', input_shape=(len(x_train.columns), )))

# 은닉층
model.add(Dense(32, activation='relu'))
# model.add(Dense(16, activation='relu'))
# model.add(Dense(8, activation='relu'))
# model.add(Dense(4, activation='relu'))
# model.add(Dense(2, activation='relu'))

# 마지막 층
model.add(Dense(1, activation='linear'))

# 함수적용
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                3008
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5121 (20.00 KB)
# Trainable params: 5121 (20.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 학습하기

# %%
result = model.fit(x_train, y_train, epochs=500, validation_data=(x_test, y_test), callbacks=[
    EarlyStopping(monitor='val_loss', patience=10, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.5, min_lr=0.001, verbose=1)
])
# Out:
# Epoch 1/500
# 12/12 [==============================] - 1s 15ms/step - loss: 514.5918 - mae: 20.8547 - val_loss: 351.7382 - val_mae: 17.2579 - lr: 0.0010
# Epoch 2/500
# 12/12 [==============================] - 0s 4ms/step - loss: 275.0520 - mae: 15.3172 - val_loss: 181.1855 - val_mae: 12.3470 - lr: 0.0010
# Epoch 3/500
# 12/12 [==============================] - 0s 4ms/step - loss: 128.9520 - mae: 10.3928 - val_loss: 63.9519 - val_mae: 7.3265 - lr: 0.0010
# Epoch 4/500
# 12/12 [==============================] - 0s 4ms/step - loss: 37.3909 - mae: 5.4196 - val_loss: 11.2125 - val_mae: 2.9364 - lr: 0.0010
# Epoch 5/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.5477 - mae: 2.1511 - val_loss: 4.1492 - val_mae: 1.5288 - lr: 0.0010
# Epoch 6/500
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3194 - mae: 1.3930 - val_loss: 1.5683 - val_mae: 1.0278 - lr: 0.0010
# Epoch 7/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4443 - mae: 0.9623 - val_loss: 1.3716 - val_mae: 0.9484 - lr: 0.0010
# Epoch 8/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3031 - mae: 0.8842 - val_loss: 1.2025 - val_mae: 0.8666 - lr: 0.0010
# Epoch 9/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9133 - mae: 0.7268 - val_loss: 0.8358 - val_mae: 0.7116 - lr: 0.0010
# Epoch 10/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7039 - mae: 0.6365 - val_loss: 0.7039 - val_mae: 0.6547 - lr: 0.0010
# Epoch 11/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6322 - mae: 0.6108 - val_loss: 0.6313 - val_mae: 0.6256 - lr: 0.0010
# Epoch 12/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5502 - mae: 0.5624 - val_loss: 0.5654 - val_mae: 0.5892 - lr: 0.0010
# Epoch 13/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5058 - mae: 0.5339 - val_loss: 0.5151 - val_mae: 0.5637 - lr: 0.0010
# Epoch 14/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4545 - mae: 0.5057 - val_loss: 0.4812 - val_mae: 0.5442 - lr: 0.0010
# Epoch 15/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4166 - mae: 0.4859 - val_loss: 0.4420 - val_mae: 0.5221 - lr: 0.0010
# Epoch 16/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3850 - mae: 0.4659 - val_loss: 0.4111 - val_mae: 0.5029 - lr: 0.0010
# Epoch 17/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3534 - mae: 0.4462 - val_loss: 0.3834 - val_mae: 0.4825 - lr: 0.0010
# Epoch 18/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3276 - mae: 0.4301 - val_loss: 0.3573 - val_mae: 0.4673 - lr: 0.0010
# Epoch 19/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2997 - mae: 0.4110 - val_loss: 0.3327 - val_mae: 0.4492 - lr: 0.0010
# Epoch 20/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2741 - mae: 0.3917 - val_loss: 0.3177 - val_mae: 0.4347 - lr: 0.0010
# Epoch 21/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2619 - mae: 0.3816 - val_loss: 0.2962 - val_mae: 0.4152 - lr: 0.0010
# Epoch 22/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2517 - mae: 0.3778 - val_loss: 0.2818 - val_mae: 0.3991 - lr: 0.0010
# Epoch 23/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2251 - mae: 0.3511 - val_loss: 0.2737 - val_mae: 0.3872 - lr: 0.0010
# Epoch 24/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2027 - mae: 0.3343 - val_loss: 0.2523 - val_mae: 0.3712 - lr: 0.0010
# Epoch 25/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1913 - mae: 0.3237 - val_loss: 0.2422 - val_mae: 0.3599 - lr: 0.0010
# Epoch 26/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1798 - mae: 0.3151 - val_loss: 0.2233 - val_mae: 0.3446 - lr: 0.0010
# Epoch 27/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1655 - mae: 0.2975 - val_loss: 0.2174 - val_mae: 0.3342 - lr: 0.0010
# Epoch 28/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1541 - mae: 0.2862 - val_loss: 0.2040 - val_mae: 0.3224 - lr: 0.0010
# Epoch 29/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1427 - mae: 0.2759 - val_loss: 0.1976 - val_mae: 0.3154 - lr: 0.0010
# Epoch 30/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1341 - mae: 0.2674 - val_loss: 0.1885 - val_mae: 0.3073 - lr: 0.0010
# Epoch 31/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1255 - mae: 0.2582 - val_loss: 0.1867 - val_mae: 0.3025 - lr: 0.0010
# Epoch 32/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1207 - mae: 0.2546 - val_loss: 0.1796 - val_mae: 0.2960 - lr: 0.0010
# Epoch 33/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1181 - mae: 0.2486 - val_loss: 0.1979 - val_mae: 0.3018 - lr: 0.0010
# Epoch 34/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1183 - mae: 0.2520 - val_loss: 0.1726 - val_mae: 0.2891 - lr: 0.0010
# Epoch 35/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1013 - mae: 0.2315 - val_loss: 0.1603 - val_mae: 0.2796 - lr: 0.0010
# Epoch 36/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1037 - mae: 0.2318 - val_loss: 0.1548 - val_mae: 0.2750 - lr: 0.0010
# Epoch 37/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0981 - mae: 0.2257 - val_loss: 0.1582 - val_mae: 0.2758 - lr: 0.0010
# Epoch 38/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0852 - mae: 0.2120 - val_loss: 0.1480 - val_mae: 0.2665 - lr: 0.0010
# Epoch 39/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0807 - mae: 0.2066 - val_loss: 0.1410 - val_mae: 0.2586 - lr: 0.0010
# Epoch 40/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0786 - mae: 0.2060 - val_loss: 0.1363 - val_mae: 0.2553 - lr: 0.0010
# Epoch 41/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0740 - mae: 0.1996 - val_loss: 0.1417 - val_mae: 0.2552 - lr: 0.0010
# Epoch 42/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0710 - mae: 0.1963 - val_loss: 0.1491 - val_mae: 0.2630 - lr: 0.0010
# Epoch 43/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0660 - mae: 0.1875 - val_loss: 0.1273 - val_mae: 0.2446 - lr: 0.0010
# Epoch 44/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0638 - mae: 0.1852 - val_loss: 0.1254 - val_mae: 0.2422 - lr: 0.0010
# Epoch 45/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0604 - mae: 0.1802 - val_loss: 0.1262 - val_mae: 0.2397 - lr: 0.0010
# Epoch 46/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0587 - mae: 0.1768 - val_loss: 0.1260 - val_mae: 0.2387 - lr: 0.0010
# Epoch 47/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0565 - mae: 0.1731 - val_loss: 0.1213 - val_mae: 0.2344 - lr: 0.0010
# Epoch 48/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0532 - mae: 0.1687 - val_loss: 0.1209 - val_mae: 0.2337 - lr: 0.0010
# Epoch 49/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0517 - mae: 0.1657 - val_loss: 0.1160 - val_mae: 0.2294 - lr: 0.0010
# Epoch 50/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0504 - mae: 0.1659 - val_loss: 0.1181 - val_mae: 0.2290 - lr: 0.0010
# Epoch 51/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0509 - mae: 0.1653 - val_loss: 0.1106 - val_mae: 0.2245 - lr: 0.0010
# Epoch 52/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0466 - mae: 0.1586 - val_loss: 0.1128 - val_mae: 0.2239 - lr: 0.0010
# Epoch 53/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0443 - mae: 0.1546 - val_loss: 0.1115 - val_mae: 0.2230 - lr: 0.0010
# Epoch 54/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0428 - mae: 0.1524 - val_loss: 0.1077 - val_mae: 0.2199 - lr: 0.0010
# Epoch 55/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0421 - mae: 0.1529 - val_loss: 0.1047 - val_mae: 0.2178 - lr: 0.0010
# Epoch 56/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0402 - mae: 0.1497 - val_loss: 0.1059 - val_mae: 0.2169 - lr: 0.0010
# Epoch 57/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0386 - mae: 0.1456 - val_loss: 0.1059 - val_mae: 0.2161 - lr: 0.0010
# Epoch 58/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0373 - mae: 0.1437 - val_loss: 0.1031 - val_mae: 0.2138 - lr: 0.0010
# Epoch 59/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0359 - mae: 0.1410 - val_loss: 0.1018 - val_mae: 0.2124 - lr: 0.0010
# Epoch 60/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0360 - mae: 0.1403 - val_loss: 0.1057 - val_mae: 0.2167 - lr: 0.0010
# Epoch 61/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0384 - mae: 0.1462 - val_loss: 0.0965 - val_mae: 0.2096 - lr: 0.0010
# Epoch 62/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0340 - mae: 0.1380 - val_loss: 0.1029 - val_mae: 0.2136 - lr: 0.0010
# Epoch 63/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0320 - mae: 0.1335 - val_loss: 0.0972 - val_mae: 0.2079 - lr: 0.0010
# Epoch 64/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0312 - mae: 0.1311 - val_loss: 0.0976 - val_mae: 0.2076 - lr: 0.0010
# Epoch 65/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0306 - mae: 0.1302 - val_loss: 0.1001 - val_mae: 0.2100 - lr: 0.0010
# Epoch 66/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0304 - mae: 0.1316 - val_loss: 0.0934 - val_mae: 0.2055 - lr: 0.0010
# Epoch 67/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0294 - mae: 0.1279 - val_loss: 0.0983 - val_mae: 0.2078 - lr: 0.0010
# Epoch 68/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0289 - mae: 0.1273 - val_loss: 0.0953 - val_mae: 0.2048 - lr: 0.0010
# Epoch 69/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0290 - mae: 0.1290 - val_loss: 0.1006 - val_mae: 0.2108 - lr: 0.0010
# Epoch 70/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0280 - mae: 0.1254 - val_loss: 0.0909 - val_mae: 0.2015 - lr: 0.0010
# Epoch 71/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0261 - mae: 0.1208 - val_loss: 0.0920 - val_mae: 0.2012 - lr: 0.0010
# Epoch 72/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0251 - mae: 0.1187 - val_loss: 0.0879 - val_mae: 0.1992 - lr: 0.0010
# Epoch 73/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0317 - mae: 0.1374 - val_loss: 0.1020 - val_mae: 0.2117 - lr: 0.0010
# Epoch 74/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0253 - mae: 0.1209 - val_loss: 0.0892 - val_mae: 0.2077 - lr: 0.0010
# Epoch 75/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0404 - mae: 0.1601 - val_loss: 0.1102 - val_mae: 0.2228 - lr: 0.0010
# Epoch 76/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0269 - mae: 0.1268 - val_loss: 0.0844 - val_mae: 0.1967 - lr: 0.0010
# Epoch 77/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0244 - mae: 0.1206 - val_loss: 0.0862 - val_mae: 0.1932 - lr: 0.0010
# Epoch 78/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0241 - mae: 0.1189 - val_loss: 0.0921 - val_mae: 0.2016 - lr: 0.0010
# Epoch 79/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0229 - mae: 0.1134 - val_loss: 0.0854 - val_mae: 0.1921 - lr: 0.0010
# Epoch 80/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0208 - mae: 0.1080 - val_loss: 0.0835 - val_mae: 0.1898 - lr: 0.0010
# Epoch 81/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0202 - mae: 0.1077 - val_loss: 0.0885 - val_mae: 0.1959 - lr: 0.0010
# Epoch 82/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0212 - mae: 0.1100 - val_loss: 0.0820 - val_mae: 0.1878 - lr: 0.0010
# Epoch 83/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0195 - mae: 0.1050 - val_loss: 0.0856 - val_mae: 0.1910 - lr: 0.0010
# Epoch 84/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0204 - mae: 0.1077 - val_loss: 0.0796 - val_mae: 0.1900 - lr: 0.0010
# Epoch 85/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0207 - mae: 0.1129 - val_loss: 0.0848 - val_mae: 0.1893 - lr: 0.0010
# Epoch 86/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0185 - mae: 0.1036 - val_loss: 0.0793 - val_mae: 0.1823 - lr: 0.0010
# Epoch 87/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0182 - mae: 0.1022 - val_loss: 0.0771 - val_mae: 0.1837 - lr: 0.0010
# Epoch 88/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0211 - mae: 0.1129 - val_loss: 0.0831 - val_mae: 0.1865 - lr: 0.0010
# Epoch 89/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0196 - mae: 0.1083 - val_loss: 0.0787 - val_mae: 0.1805 - lr: 0.0010
# Epoch 90/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0227 - mae: 0.1150 - val_loss: 0.0773 - val_mae: 0.1822 - lr: 0.0010
# Epoch 91/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0219 - mae: 0.1117 - val_loss: 0.0739 - val_mae: 0.1750 - lr: 0.0010
# Epoch 92/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0179 - mae: 0.1022 - val_loss: 0.0735 - val_mae: 0.1755 - lr: 0.0010
# Epoch 93/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0219 - mae: 0.1126 - val_loss: 0.0827 - val_mae: 0.1838 - lr: 0.0010
# Epoch 94/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0212 - mae: 0.1115 - val_loss: 0.0758 - val_mae: 0.1758 - lr: 0.0010
# Epoch 95/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0173 - mae: 0.1018 - val_loss: 0.0703 - val_mae: 0.1737 - lr: 0.0010
# Epoch 96/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0191 - mae: 0.1060 - val_loss: 0.0775 - val_mae: 0.1836 - lr: 0.0010
# Epoch 97/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0201 - mae: 0.1062 - val_loss: 0.0705 - val_mae: 0.1732 - lr: 0.0010
# Epoch 98/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0172 - mae: 0.1001 - val_loss: 0.0686 - val_mae: 0.1714 - lr: 0.0010
# Epoch 99/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0164 - mae: 0.1011 - val_loss: 0.0751 - val_mae: 0.1766 - lr: 0.0010
# Epoch 100/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0150 - mae: 0.0940 - val_loss: 0.0676 - val_mae: 0.1678 - lr: 0.0010
# Epoch 101/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0141 - mae: 0.0909 - val_loss: 0.0716 - val_mae: 0.1707 - lr: 0.0010
# Epoch 102/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0135 - mae: 0.0883 - val_loss: 0.0699 - val_mae: 0.1683 - lr: 0.0010
# Epoch 103/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0139 - mae: 0.0911 - val_loss: 0.0738 - val_mae: 0.1721 - lr: 0.0010
# Epoch 104/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0133 - mae: 0.0881 - val_loss: 0.0671 - val_mae: 0.1661 - lr: 0.0010
# Epoch 105/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0133 - mae: 0.0885 - val_loss: 0.0713 - val_mae: 0.1685 - lr: 0.0010
# Epoch 106/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0128 - mae: 0.0861 - val_loss: 0.0703 - val_mae: 0.1677 - lr: 0.0010
# Epoch 107/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0129 - mae: 0.0853 - val_loss: 0.0677 - val_mae: 0.1651 - lr: 0.0010
# Epoch 108/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - mae: 0.0851 - val_loss: 0.0676 - val_mae: 0.1648 - lr: 0.0010
# Epoch 109/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0120 - mae: 0.0838 - val_loss: 0.0666 - val_mae: 0.1634 - lr: 0.0010
# Epoch 110/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0119 - mae: 0.0831 - val_loss: 0.0658 - val_mae: 0.1619 - lr: 0.0010
# Epoch 111/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0119 - mae: 0.0831 - val_loss: 0.0701 - val_mae: 0.1659 - lr: 0.0010
# Epoch 112/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0166 - mae: 0.0998 - val_loss: 0.0657 - val_mae: 0.1645 - lr: 0.0010
# Epoch 113/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0143 - mae: 0.0913 - val_loss: 0.0662 - val_mae: 0.1748 - lr: 0.0010
# Epoch 114/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0147 - mae: 0.0975 - val_loss: 0.0729 - val_mae: 0.1683 - lr: 0.0010
# Epoch 115/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0122 - mae: 0.0838 - val_loss: 0.0670 - val_mae: 0.1610 - lr: 0.0010
# Epoch 116/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0107 - mae: 0.0792 - val_loss: 0.0643 - val_mae: 0.1587 - lr: 0.0010
# Epoch 117/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0107 - mae: 0.0792 - val_loss: 0.0650 - val_mae: 0.1584 - lr: 0.0010
# Epoch 118/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0103 - mae: 0.0780 - val_loss: 0.0663 - val_mae: 0.1584 - lr: 0.0010
# Epoch 119/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0103 - mae: 0.0780 - val_loss: 0.0648 - val_mae: 0.1559 - lr: 0.0010
# Epoch 120/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0101 - mae: 0.0775 - val_loss: 0.0662 - val_mae: 0.1565 - lr: 0.0010
# Epoch 121/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0098 - mae: 0.0757 - val_loss: 0.0633 - val_mae: 0.1542 - lr: 0.0010
# Epoch 122/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0099 - mae: 0.0768 - val_loss: 0.0629 - val_mae: 0.1555 - lr: 0.0010
# Epoch 123/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0098 - mae: 0.0750 - val_loss: 0.0616 - val_mae: 0.1522 - lr: 0.0010
# Epoch 124/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0103 - mae: 0.0791 - val_loss: 0.0617 - val_mae: 0.1504 - lr: 0.0010
# Epoch 125/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0097 - mae: 0.0759 - val_loss: 0.0684 - val_mae: 0.1555 - lr: 0.0010
# Epoch 126/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0101 - mae: 0.0761 - val_loss: 0.0609 - val_mae: 0.1496 - lr: 0.0010
# Epoch 127/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0091 - mae: 0.0728 - val_loss: 0.0588 - val_mae: 0.1520 - lr: 0.0010
# Epoch 128/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0103 - mae: 0.0778 - val_loss: 0.0626 - val_mae: 0.1489 - lr: 0.0010
# Epoch 129/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0100 - mae: 0.0782 - val_loss: 0.0650 - val_mae: 0.1531 - lr: 0.0010
# Epoch 130/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0099 - mae: 0.0762 - val_loss: 0.0594 - val_mae: 0.1457 - lr: 0.0010
# Epoch 131/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0086 - mae: 0.0717 - val_loss: 0.0597 - val_mae: 0.1457 - lr: 0.0010
# Epoch 132/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0083 - mae: 0.0702 - val_loss: 0.0593 - val_mae: 0.1455 - lr: 0.0010
# Epoch 133/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0081 - mae: 0.0690 - val_loss: 0.0598 - val_mae: 0.1449 - lr: 0.0010
# Epoch 134/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0080 - mae: 0.0684 - val_loss: 0.0597 - val_mae: 0.1453 - lr: 0.0010
# Epoch 135/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0080 - mae: 0.0679 - val_loss: 0.0603 - val_mae: 0.1456 - lr: 0.0010
# Epoch 136/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0674 - val_loss: 0.0580 - val_mae: 0.1435 - lr: 0.0010
# Epoch 137/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0079 - mae: 0.0683 - val_loss: 0.0628 - val_mae: 0.1489 - lr: 0.0010
# Epoch 138/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0076 - mae: 0.0669 - val_loss: 0.0578 - val_mae: 0.1445 - lr: 0.0010
# Epoch 139/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0076 - mae: 0.0665 - val_loss: 0.0593 - val_mae: 0.1439 - lr: 0.0010
# Epoch 140/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0073 - mae: 0.0658 - val_loss: 0.0565 - val_mae: 0.1408 - lr: 0.0010
# Epoch 141/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0074 - mae: 0.0648 - val_loss: 0.0571 - val_mae: 0.1409 - lr: 0.0010
# Epoch 142/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0073 - mae: 0.0662 - val_loss: 0.0561 - val_mae: 0.1395 - lr: 0.0010
# Epoch 143/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - mae: 0.0655 - val_loss: 0.0566 - val_mae: 0.1391 - lr: 0.0010
# Epoch 144/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0079 - mae: 0.0687 - val_loss: 0.0597 - val_mae: 0.1422 - lr: 0.0010
# Epoch 145/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0068 - mae: 0.0636 - val_loss: 0.0536 - val_mae: 0.1367 - lr: 0.0010
# Epoch 146/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0069 - mae: 0.0635 - val_loss: 0.0570 - val_mae: 0.1373 - lr: 0.0010
# Epoch 147/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0066 - mae: 0.0620 - val_loss: 0.0560 - val_mae: 0.1370 - lr: 0.0010
# Epoch 148/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0065 - mae: 0.0616 - val_loss: 0.0570 - val_mae: 0.1372 - lr: 0.0010
# Epoch 149/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0068 - mae: 0.0634 - val_loss: 0.0569 - val_mae: 0.1364 - lr: 0.0010
# Epoch 150/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0064 - mae: 0.0614 - val_loss: 0.0564 - val_mae: 0.1357 - lr: 0.0010
# Epoch 151/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0064 - mae: 0.0609 - val_loss: 0.0565 - val_mae: 0.1361 - lr: 0.0010
# Epoch 152/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0062 - mae: 0.0594 - val_loss: 0.0558 - val_mae: 0.1346 - lr: 0.0010
# Epoch 153/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0060 - mae: 0.0585 - val_loss: 0.0555 - val_mae: 0.1345 - lr: 0.0010
# Epoch 154/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0063 - mae: 0.0605 - val_loss: 0.0581 - val_mae: 0.1380 - lr: 0.0010
# Epoch 155/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0062 - mae: 0.0609 - val_loss: 0.0560 - val_mae: 0.1343 - lr: 0.0010
# Epoch 155: early stopping

# %% [markdown]
# ## #07. 학습모델 평가

# %%
helper.tf_result_plot(result)

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 절대오차: %f" % (evaluate1[0], evaluate1[1]))
evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 절대오차: %f" % (evaluate2[0], evaluate2[1]))
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0059 - mae: 0.0575
# 최종 훈련 손실률: 0.005857, 최종 훈련 절대오차: 0.057538
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0560 - mae: 0.1343
# 최종 검증 손실률: 0.055975, 최종 검증 절대오차: 0.134290

# %% [markdown]
# ## #08. 학습모델 적용
#
# ### 테스트 데이터에 대한 예측 결과 산정

# %%
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)
# Out:
# 12/12 [==============================] - 0s 860us/step
# 5/5 [==============================] - 0s 1ms/step

# %% [markdown]
# ### 결과 데이터 셋 구성

# %%
# 훈련데이터
train_df = DataFrame(x_train, columns=x_train.columns)
train_df['관측치'] = y_train.values
train_df['예측치'] = train_pred.flatten()

train_df['훈련오차'] = train_df['관측치'] - train_df['예측치']

train_df.head()
# Out:
#          CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 372  0.541569 -0.487722 -0.583589  0.747665  1.661245  0.806576 -0.096421
# 18  -0.327103 -0.487722 -1.180521 -1.137046 -0.637962  1.176466 -0.742112
# 185 -0.413480 -0.487722 -0.187534  0.008005 -0.752922 -0.303094  0.333711
# 57  -0.418851  3.804234  0.757015 -0.998360 -0.523001 -1.551473  0.397194
# 261 -0.358360  0.370669  1.759974  0.740552 -0.523001 -2.522434  0.347526
#
#         LSTAT    CRIM^2   CRIM ZN  ...  PTRATIO B  PTRATIO LSTAT       B^2  \
# 372 -0.528885  0.293297 -0.264135  ...  -0.077771      -0.426585  0.009297
# 18  -0.134996  0.106997  0.159536  ...  -0.873069      -0.158818  0.550730
# 185  0.069658  0.170966  0.201664  ...  -0.101146      -0.021113  0.111363
# 57  -1.219941  0.175436 -1.593407  ...  -0.616236       1.892706  0.157763
# 261 -0.755966  0.128422 -0.132833  ...  -0.876611       1.906875  0.120774
#
#       B LSTAT   LSTAT^2  CHAS  MEDV   관측치        예측치      훈련오차
# 372  0.050996  0.279719     1  50.0  50.0  49.754753  0.245247
# 18   0.100182  0.018224     0  20.2  20.2  20.097347  0.102653
# 185  0.023245  0.004852     0  29.6  29.6  29.393099  0.206901
# 57  -0.484554  1.488257     0  31.6  31.6  31.567299  0.032701
# 261 -0.262718  0.571485     0  43.1  43.1  42.999805  0.100195
#
# [5 rows x 49 columns]

# %%
# 검증데이터
test_df = DataFrame(x_test, columns=x_train.columns)
test_df['관측치'] = y_test.values
test_df['예측치'] = test_pred.flatten()

test_df['검증오차'] = test_df['관측치'] - test_df['예측치']

test_df.head()
# Out:
#          CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 207 -0.391193 -0.487722 -0.714658  0.146691 -0.637962  0.066796  0.359148
# 425  1.425197 -0.487722 -0.553671  0.953916  1.661245  0.806576 -3.826496
# 408  0.441097 -0.487722 -0.951151  1.042817  1.661245  0.806576 -0.460876
# 63  -0.405796  0.585267  0.680083 -0.895234 -0.178120  0.575395  0.426579
# 290 -0.416442  2.945843  0.821124 -1.446423 -0.637962  0.344213  0.441052
#
#         LSTAT    CRIM^2   CRIM ZN  ...  PTRATIO B  PTRATIO LSTAT        B^2  \
# 207  0.757911  0.153032  0.190793  ...   0.023990       0.050625   0.128987
# 425  1.645211  2.031186 -0.695100  ...  -3.086359       1.326987  14.642069
# 408  1.926960  0.194567 -0.215133  ...  -0.371732       1.554239   0.212407
# 63  -0.441977  0.164671 -0.237499  ...   0.245451      -0.254311   0.181970
# 290 -1.306849  0.173424 -1.226773  ...   0.151816      -0.449835   0.194527
#
#       B LSTAT   LSTAT^2  CHAS  MEDV   관측치        예측치      검증오차
# 207  0.272202  0.574429     0  22.5  22.5  22.421364  0.078636
# 425 -6.295392  2.706719     0   8.3   8.3   7.996889  0.303111
# 408 -0.888090  3.713175     0  17.2  17.2  16.889416  0.310584
# 63  -0.188538  0.195343     0  25.0  25.0  25.090935 -0.090935
# 290 -0.576388  1.707854     0  28.5  28.5  28.359711  0.140289
#
# [5 rows x 49 columns]

# %% [markdown]
# ### 실제 결과값과 머신러닝에 의한 예측값 비교

# %%
for key in ['CRIM','ZN', 'RM', 'AGE', 'RAD', 'PTRATIO',	'B', 'LSTAT']:
    helper.regplot(train_df[key], train_df['관측치'], train_df['예측치'], "훈련데이터",
                    test_df[key], test_df['관측치'], test_df['예측치'], "검증데이터",
                    figsize=(15,5))
