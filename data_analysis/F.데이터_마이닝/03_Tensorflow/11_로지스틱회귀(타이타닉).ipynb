# %% [markdown]
# # 로지스틱 회귀 - 타이타닉 생존률 예측
#
# ## #01. 패키지 준비하기

# %%
import sys
sys.path.append('../../')
import helper

import numpy as np
from pandas import read_excel, DataFrame, get_dummies
from matplotlib import pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ## #02. 데이터셋 준비하기

# %%
origin = read_excel("https://data.hossam.kr/E05/titanic.xlsx")
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### 결측치 확인

# %%
origin.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 결측치 정제
#
# 객실번호(Cabin)
#
# 선실이 부여되지 않은 경우 객실 등급에 따른 차이가 있는지 여부를 확인

# %%
df_tmp = origin.filter(['Pclass', 'Cabin']).query('Cabin.isnull()')
df_tmp.fillna(0, inplace=True)
df_tmp.groupby('Pclass').count()
# Out:
#         Cabin
# Pclass
# 1          40
# 2         168
# 3         479

# %% [markdown]
# > 객실 번호는 생존 여부에 영향이 없을 것으로 판단하고 변수 자체를 제거(열단위 제거)

# %%
df1 = origin.drop('Cabin', axis=1)
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# 탑승지('Embarked')
#
# 탑승지 데이터가 결측치인 경우는 2건 밖에 되지 않기 때문에 데이터 정제 과정에서 제거(행단위)

# %%
df2 = df1.query('Embarked.notnull()')
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# 나이(Age)
#
# 나이를 중앙값으로 대체
#
# 나이의 경우 탑승객의 생존 여부에 중요한 영향을 미치는 요인이라고 짐작하고 삭제하지 않기로 결정하였다.
#
# 연속형 데이터의 결측치를 대체하기에 가장 적합한 값은 중앙값이므로 중앙값으로 대체한다.

# %%
df3 = df2.copy()
df3['Age'].fillna(df3['Age'].median(), inplace=True)
df3.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### 불필요한 필드 제거
#
# 탑승객번호(PassengerId)
#
# 탑승객번호는 단순한 일련번호이므로 생존률에 영향을 주지 않는 값이라고 판단하고 이 값을 인덱스로 설정하였다.

# %%
df4 = df3.set_index('PassengerId')
df4.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S

# %% [markdown]
# 이름('Name')과 티켓번호(Ticket)
#
# 생존 여부에 영향을 주지 않는다고 판단하고 제거

# %%
df5 = df4.drop(['Name', 'Ticket'], axis=1)
df5.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500        S
# 2                   1       1  female  38.0      1      0  71.2833        C
# 3                   1       3  female  26.0      0      0   7.9250        S
# 4                   1       1  female  35.0      1      0  53.1000        S
# 5                   0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ### 더미변수 처리

# %%
cda_df = get_dummies(df5, columns=['Pclass','Sex','Embarked'], drop_first=True, dtype='int')
cda_df.head()
# Out:
#              Survived   Age  SibSp  Parch     Fare  Pclass_2  Pclass_3  \
# PassengerId
# 1                   0  22.0      1      0   7.2500         0         1
# 2                   1  38.0      1      0  71.2833         0         0
# 3                   1  26.0      0      0   7.9250         0         1
# 4                   1  35.0      1      0  53.1000         0         0
# 5                   0  35.0      0      0   8.0500         0         1
#
#              Sex_male  Embarked_Q  Embarked_S
# PassengerId
# 1                   1           0           1
# 2                   0           0           0
# 3                   0           0           1
# 4                   0           0           1
# 5                   1           0           1

# %% [markdown]
# ## #04. 탐색적 데이터 분석
#
# > `E05` 의 연습문제 2번으로 진행한 바 있으므로 생략

# %% [markdown]
# ## #05. 데이터셋 분할하기
#
# ### 랜덤시드 고정

# %%
np.random.seed(777)

# %% [markdown]
# ### 훈련데이터(독립변수)와 레이블(종속변수) 구분하기

# %%
x = cda_df.drop('Survived', axis=1)
x.head()
# Out:
#               Age  SibSp  Parch     Fare  Pclass_2  Pclass_3  Sex_male  \
# PassengerId
# 1            22.0      1      0   7.2500         0         1         1
# 2            38.0      1      0  71.2833         0         0         0
# 3            26.0      0      0   7.9250         0         1         0
# 4            35.0      1      0  53.1000         0         0         0
# 5            35.0      0      0   8.0500         0         1         1
#
#              Embarked_Q  Embarked_S
# PassengerId
# 1                     0           1
# 2                     0           0
# 3                     0           1
# 4                     0           1
# 5                     0           1

# %%
y = cda_df[['Survived']]
y.head()
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0

# %% [markdown]
# ### 데이터 표준화
#
# > 일단 생략해보기로 함

# %% [markdown]
# ### 훈련데이터와 검증데이터로 분할

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=777)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((622, 9), (267, 9), (622, 1), (267, 1))

# %% [markdown]
# ## #06. 모델 개발
# ### 모델정의

# %%
model = Sequential()

# 첫번째 층
model.add(Dense(9, activation='relu', input_shape=(9, )))
# 은닉층
model.add(Dense(4, activation='relu'))
# model.add(Dense(8, activation='relu'))
# model.add(Dense(4, activation='relu'))
# model.add(Dense(2, activation='relu'))

#마지막층
model.add(Dense(1, activation = 'sigmoid'))

#적용
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 9)                 90
#
#  dense_4 (Dense)             (None, 4)                 40
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 135 (540.00 Byte)
# Trainable params: 135 (540.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 학습하기

# %%
result = model.fit(x_train, y_train, epochs=500, validation_data=(x_test, y_test), callbacks=[
    EarlyStopping(monitor='val_loss', patience=5, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.5, min_lr=0.0001, verbose=1)
])
# Out:
# Epoch 1/500
# 20/20 [==============================] - 1s 8ms/step - loss: 1.3366 - acc: 0.6897 - val_loss: 0.9492 - val_acc: 0.6816 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1124 - acc: 0.6929 - val_loss: 0.8490 - val_acc: 0.6667 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9696 - acc: 0.6833 - val_loss: 0.7562 - val_acc: 0.6592 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8520 - acc: 0.6801 - val_loss: 0.6971 - val_acc: 0.6742 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7796 - acc: 0.6704 - val_loss: 0.6806 - val_acc: 0.6629 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7430 - acc: 0.6656 - val_loss: 0.6715 - val_acc: 0.6592 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7166 - acc: 0.6608 - val_loss: 0.6693 - val_acc: 0.6442 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6991 - acc: 0.6527 - val_loss: 0.6692 - val_acc: 0.6442 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6877 - acc: 0.6447 - val_loss: 0.6702 - val_acc: 0.6255 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6785 - acc: 0.6415 - val_loss: 0.6707 - val_acc: 0.6105 - lr: 0.0010
# Epoch 11/500
#  1/20 [>.............................] - ETA: 0s - loss: 0.6558 - acc: 0.6875
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6744 - acc: 0.6383 - val_loss: 0.6709 - val_acc: 0.6030 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6714 - acc: 0.6383 - val_loss: 0.6700 - val_acc: 0.6030 - lr: 5.0000e-04
# Epoch 13/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6702 - acc: 0.6447 - val_loss: 0.6687 - val_acc: 0.6105 - lr: 5.0000e-04
# Epoch 14/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6690 - acc: 0.6447 - val_loss: 0.6683 - val_acc: 0.6105 - lr: 5.0000e-04
# Epoch 15/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6680 - acc: 0.6447 - val_loss: 0.6675 - val_acc: 0.6142 - lr: 5.0000e-04
# Epoch 16/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6678 - acc: 0.6447 - val_loss: 0.6675 - val_acc: 0.6105 - lr: 5.0000e-04
# Epoch 17/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.
500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6574 - acc: 0.6463 - val_loss: 0.6634 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 54/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6573 - acc: 0.6463 - val_loss: 0.6634 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 55/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6572 - acc: 0.6463 - val_loss: 0.6633 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 56/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6571 - acc: 0.6463 - val_loss: 0.6634 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 57/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6571 - acc: 0.6463 - val_loss: 0.6634 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 58/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6570 - acc: 0.6463 - val_loss: 0.6633 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 59/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6570 - acc: 0.6463 - val_loss: 0.6633 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 60/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6569 - acc: 0.6463 - val_loss: 0.6633 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 61/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6568 - acc: 0.6463 - val_loss: 0.6632 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 62/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6567 - acc: 0.6463 - val_loss: 0.6632 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 63/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6567 - acc: 0.6463 - val_loss: 0.6633 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 64/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6566 - acc: 0.6463 - val_loss: 0.6633 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 65/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6566 - acc: 0.6463 - val_loss: 0.6632 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 66/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6565 - acc: 0.6463 - val_loss: 0.6632 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 67/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6564 - acc: 0.6463 - val_loss: 0.6632 - val_acc: 0.6142 - lr: 1.0000e-04
# Epoch 67: early stopping

# %% [markdown]
# ## #07. 학습결과 평가
#
# ### 기본적인 머신러닝 학습률 평가

# %%
helper.tf_result_plot(result)

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 정확도: %f" % (evaluate1[0], evaluate1[1]))
evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 정확도: %f" % (evaluate2[0], evaluate2[1]))
# Out:
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6563 - acc: 0.6463
# 최종 훈련 손실률: 0.656291, 최종 훈련 정확도: 0.646302
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6632 - acc: 0.6142
# 최종 검증 손실률: 0.663197, 최종 검증 정확도: 0.614232

# %% [markdown]
# ### 로지스틱 회귀 결과 검정

# %% [markdown]
# ## #08. 학습 결과 적용
# ### 실제 데이터로 예측해보기
#
# 예측을 위한 데이터프레임 준비

# %%
test_df = DataFrame({
    'dicaprio': [19, 0, 0, 0, 0, 1, 1, 0, 0],  # 영화속 남자 주인공 데이터
    'winslet': [17, 1, 2, 100, 0, 0, 0, 1, 0], # 영화속 여자 주인공 데이터
    'someone': [41, 1, 0, 50, 1, 0, 1, 0, 0]  # 임의의 데이터
}, index=['Age','SibSp','Parch','Fare','Pclass_2','Pclass_3','Sex_male','Embarked_Q','Embarked_S'])
test_df
# Out:
#             dicaprio  winslet  someone
# Age               19       17       41
# SibSp              0        1        1
# Parch              0        2        0
# Fare               0      100       50
# Pclass_2           0        0        1
# Pclass_3           1        0        0
# Sex_male           1        0        1
# Embarked_Q         0        1        0
# Embarked_S         0        0        0

# %% [markdown]
# > 행과 열을 바꿔야 표준화. 그대로 하면 한사람에 대한 값만 표준화 하는 것.

# %% [markdown]
# ### 결과 예측하기

# %%
results = model.predict(test_df.T)
data_count, case_count = results.shape
print("%d개의 임의의 데이터가 %d개의 경우의 수를 갖는다." % (data_count, case_count))
print(results)
# Out:
# 1/1 [==============================] - 0s 88ms/step
# 3개의 임의의 데이터가 1개의 경우의 수를 갖는다.
# [[0.09416334]
#  [0.5844289 ]
#  [0.4705831 ]]

# %%
for i, v in enumerate(results.flatten()):
    print("%s의 생존 확률은 %0.1f%% 입니다." % (test_df.columns[i], v*100))
# Out:
# dicaprio의 생존 확률은 9.4% 입니다.
# winslet의 생존 확률은 58.4% 입니다.
# someone의 생존 확률은 47.1% 입니다.
