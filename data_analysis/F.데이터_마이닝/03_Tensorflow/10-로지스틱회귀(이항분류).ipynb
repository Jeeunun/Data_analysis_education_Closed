# %% [markdown]
# # 로지스틱 회귀 - 이항분류
#
# ## #01. 패키지 준비하기

# %%
import sys
sys.path.append('../../')
import helper

from pandas import read_excel, DataFrame
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score, accuracy_score, recall_score, precision_score, f1_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## #02. 데이터셋 준비하기
#
# 방사선학 석사과정 대학원생 모집을 하였다. 이 때 지원한 방사선사의 대학원 합격 여부에 따른 주요 요인이 무엇인지 분석하라.
#
# 단, 독립변수는 정규분포를 따른다고 가정한다.
#
# | 변수 | 구분 | 설명 |
# |---|---|---
# | 합격여부 | 범주형 | 1=합격, 0=불합격 |
# | 필기점수 | 연속형 | 800점 만점 |
# | 학부성적 | 연속형 | 4.0 만점 |
# | 병원경력 | 범주형 | 1: 10년이상, 2: 2~5년, 3: 1~5년, 4: 1년 미만 |

# %%
origin = read_excel("https://data.hossam.kr/E05/gradeuate.xlsx")
origin.head()
# Out:
#    합격여부  필기점수  학부성적  병원경력
# 0     0   380  3.61     3
# 1     1   660  3.67     3
# 2     1   800  4.00     1
# 3     1   640  3.19     4
# 4     0   520  2.93     4

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### 결측치 확인

# %%
origin.isna().sum()
# Out:
# 합격여부    0
# 필기점수    0
# 학부성적    0
# 병원경력    0
# dtype: int64

# %% [markdown]
# ### 명목형에 대한 데이터 타입 설정

# %%
origin['합격여부'] = origin['합격여부'].astype('category')
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   합격여부    400 non-null    category
#  1   필기점수    400 non-null    int64
#  2   학부성적    400 non-null    float64
#  3   병원경력    400 non-null    int64
# dtypes: category(1), float64(1), int64(2)
# memory usage: 10.0 KB

# %% [markdown]
# ## #04. 탐색적 데이터 분석
#
# ### 기본통계 확인

# %%
origin.describe()
# Out:
#              필기점수        학부성적       병원경력
# count  400.000000  400.000000  400.00000
# mean   587.700000    3.389900    2.48500
# std    115.516536    0.380567    0.94446
# min    220.000000    2.260000    1.00000
# 25%    520.000000    3.130000    2.00000
# 50%    580.000000    3.395000    2.00000
# 75%    660.000000    3.670000    3.00000
# max    800.000000    4.000000    4.00000

# %% [markdown]
# ### 상자그림 확인

# %%
plt.figure(figsize=(10, 5))
sb.boxplot(data=origin)
plt.show()
plt.close()

# %% [markdown]
# > 데이터 단위가 크게 다르므로 표준화가 필요해 보임

# %% [markdown]
# ## #05. 데이터셋 분할하기
#
# ### 랜덤시드 고정

# %%
np.random.seed(777)

# %% [markdown]
# ### 훈련 데이터(독립변수)와 레이블(종속변수) 구분하기

# %%
x = origin[['필기점수','학부성적','병원경력']]
y = origin[['합격여부']]
x.shape, y.shape
# Out:
# ((400, 3), (400, 1))

# %% [markdown]
# ### 데이터 표준화

# %%
x_scaller = StandardScaler()
x_scale = x_scaller.fit_transform(x)
print(x_scale.shape)
x_scale
# Out:
# (400, 3)
# array([[-1.80026271,  0.57907192,  0.54596793],
#        [ 0.62666824,  0.73692942,  0.54596793],
#        [ 1.84013372,  1.60514289, -1.57429586],
#        ...,
#        [-1.10685387, -1.99925902, -0.51416397],
#        [ 0.97337266,  0.68431046, -0.51416397],
#        [ 0.10661161,  1.31573861,  0.54596793]])

# %% [markdown]
# ### 표준화 전 후 상자그림 비교

# %%
# 임시로 독립변수와 종속변수를 하나의 DataFrame으로 병합
x_scale_df = DataFrame(x_scale, columns=['필기점수','학부성적','병원경력'])

fig, ax = plt.subplots(1, 2, figsize=(15, 5), dpi=150)
sb.boxplot(data=origin, ax=ax[0])
sb.boxplot(data=x_scale_df, ax=ax[1])
ax[0].set_title('before')
ax[1].set_title('after')
plt.show()
plt.close()

# %% [markdown]
# ### 훈련 데이터와 검증 데이터로 분할

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scale, y, test_size=0.3, random_state=777)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((280, 3), (120, 3), (280, 1), (120, 1))

# %% [markdown]
# ## #06. 모델 개발
#
# ### 모델 정의
#
# [relu,] sigmoid	rmsporp	binary_crossentropy	acc

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(3, )))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss = 'binary_crossentropy', metrics = ['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                128
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 161 (644.00 Byte)
# Trainable params: 161 (644.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 학습하기

# %%
result = model.fit(x_train, y_train, epochs = 500, validation_data = (x_test, y_test), callbacks = [
    EarlyStopping(monitor = 'val_loss', patience=5, verbose = 1),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.5, min_lr=0.0001, verbose=1)
])
# Out:
# Epoch 1/500
# 9/9 [==============================] - 1s 25ms/step - loss: 0.7192 - acc: 0.4214 - val_loss: 0.6947 - val_acc: 0.5500 - lr: 0.0010
# Epoch 2/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6889 - acc: 0.5643 - val_loss: 0.6693 - val_acc: 0.6500 - lr: 0.0010
# Epoch 3/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6693 - acc: 0.6357 - val_loss: 0.6489 - val_acc: 0.6667 - lr: 0.0010
# Epoch 4/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6542 - acc: 0.6536 - val_loss: 0.6325 - val_acc: 0.7083 - lr: 0.0010
# Epoch 5/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6427 - acc: 0.6643 - val_loss: 0.6195 - val_acc: 0.7167 - lr: 0.0010
# Epoch 6/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6333 - acc: 0.6786 - val_loss: 0.6081 - val_acc: 0.7167 - lr: 0.0010
# Epoch 7/500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6261 - acc: 0.6714 - val_loss: 0.5990 - val_acc: 0.7250 - lr: 0.0010
# Epoch 8/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6204 - acc: 0.6786 - val_loss: 0.5913 - val_acc: 0.7167 - lr: 0.0010
# Epoch 9/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6154 - acc: 0.6679 - val_loss: 0.5838 - val_acc: 0.7167 - lr: 0.0010
# Epoch 10/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6116 - acc: 0.6607 - val_loss: 0.5782 - val_acc: 0.7250 - lr: 0.0010
# Epoch 11/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6087 - acc: 0.6679 - val_loss: 0.5735 - val_acc: 0.7167 - lr: 0.0010
# Epoch 12/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6064 - acc: 0.6679 - val_loss: 0.5697 - val_acc: 0.7250 - lr: 0.0010
# Epoch 13/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6047 - acc: 0.6714 - val_loss: 0.5663 - val_acc: 0.7250 - lr: 0.0010
# Epoch 14/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6033 - acc: 0.6679 - val_loss: 0.5635 - val_acc: 0.7250 - lr: 0.0010
# Epoch 15/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6019 - acc: 0.6750 - val_loss: 0.5614 - val_acc: 0.7250 - lr: 0.0010
# Epoch 16/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6008 - acc: 0.6750 - val_loss: 0.5593 - val_acc: 0.7250 - lr: 0.0010
# Epoch 17/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6001 - acc: 0.6750 - val_loss: 0.5574 - val_acc: 0.7250 - lr: 0.0010
# Epoch 18/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5992 - acc: 0.6750 - val_loss: 0.5555 - val_acc: 0.7250 - lr: 0.0010
# Epoch 19/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5987 - acc: 0.6679 - val_loss: 0.5541 - val_acc: 0.7250 - lr: 0.0010
# Epoch 20/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5977 - acc: 0.6714 - val_loss: 0.5528 - val_acc: 0.7333 - lr: 0.0010
# Epoch 21/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5972 - acc: 0.6714 - val_loss: 0.5518 - val_acc: 0.7333 - lr: 0.0010
# Epoch 22/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5973 - acc: 0.6714 - val_loss: 0.5506 - val_acc: 0.7333 - lr: 0.0010
# Epoch 23/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5960 - acc: 0.6786 - val_loss: 0.5497 - val_acc: 0.7250 - lr: 0.0010
# Epoch 24/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5963 - acc: 0.6750 - val_loss: 0.5488 - val_acc: 0.7333 - lr: 0.0010
# Epoch 25/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5951 - acc: 0.6786 - val_loss: 0.5481 - val_acc: 0.7333 - lr: 0.0010
# Epoch 26/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5951 - acc: 0.6750 - val_loss: 0.5476 - val_acc: 0.7333 - lr: 0.0010
# Epoch 27/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5944 - acc: 0.6786 - val_loss: 0.5472 - val_acc: 0.7333 - lr: 0.0010
# Epoch 28/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5945 - acc: 0.6821 - val_loss: 0.5467 - val_acc: 0.7333 - lr: 0.0010
# Epoch 29/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5943 - acc: 0.6857 - val_loss: 0.5463 - val_acc: 0.7333 - lr: 0.0010
# Epoch 30/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5937 - acc: 0.6893 - val_loss: 0.5460 - val_acc: 0.7333 - lr: 0.0010
# Epoch 31/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5932 - acc: 0.6893 - val_loss: 0.5456 - val_acc: 0.7333 - lr: 0.0010
# Epoch 32/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5929 - acc: 0.6857 - val_loss: 0.5452 - val_acc: 0.7333 - lr: 0.0010
# Epoch 33/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5929 - acc: 0.6893 - val_loss: 0.5447 - val_acc: 0.7333 - lr: 0.0010
# Epoch 34/500
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5924 - acc: 0.6821 - val_loss: 0.5445 - val_acc: 0.7333 - lr: 0.0010
# Epoch 35/500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5922 - acc: 0.6929 - val_loss: 0.5445 - val_acc: 0.7333 - lr: 0.0010
# Epoch 36/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5920 - acc: 0.6893 - val_loss: 0.5445 - val_acc: 0.7333 - lr: 0.0010
# Epoch 37/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5916 - acc: 0.6929 - val_loss: 0.5441 - val_acc: 0.7333 - lr: 0.0010
# Epoch 38/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5915 - acc: 0.6929 - val_loss: 0.5438 - val_acc: 0.7333 - lr: 0.0010
# Epoch 39/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5913 - acc: 0.6964 - val_loss: 0.5434 - val_acc: 0.7333 - lr: 0.0010
# Epoch 40/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5909 - acc: 0.6929 - val_loss: 0.5432 - val_acc: 0.7333 - lr: 0.0010
# Epoch 41/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5906 - acc: 0.6929 - val_loss: 0.5430 - val_acc: 0.7333 - lr: 0.0010
# Epoch 42/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5906 - acc: 0.6964 - val_loss: 0.5429 - val_acc: 0.7333 - lr: 0.0010
# Epoch 43/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5903 - acc: 0.6964 - val_loss: 0.5429 - val_acc: 0.7333 - lr: 0.0010
# Epoch 44/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5900 - acc: 0.6929 - val_loss: 0.5426 - val_acc: 0.7417 - lr: 0.0010
# Epoch 45/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5899 - acc: 0.6964 - val_loss: 0.5423 - val_acc: 0.7417 - lr: 0.0010
# Epoch 46/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5897 - acc: 0.7000 - val_loss: 0.5421 - val_acc: 0.7417 - lr: 0.0010
# Epoch 47/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5895 - acc: 0.6964 - val_loss: 0.5420 - val_acc: 0.7333 - lr: 0.0010
# Epoch 48/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5897 - acc: 0.7036 - val_loss: 0.5421 - val_acc: 0.7333 - lr: 0.0010
# Epoch 49/500
# 1/9 [==>...........................] - ETA: 0s - loss: 0.5668 - acc: 0.7812
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5891 - acc: 0.7000 - val_loss: 0.5421 - val_acc: 0.7333 - lr: 0.0010
# Epoch 50/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5885 - acc: 0.7000 - val_loss: 0.5422 - val_acc: 0.7333 - lr: 5.0000e-04
# Epoch 51/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5884 - acc: 0.6964 - val_loss: 0.5422 - val_acc: 0.7333 - lr: 5.0000e-04
# Epoch 52/500
# 1/9 [==>...........................] - ETA: 0s - loss: 0.5689 - acc: 0.7500
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5883 - acc: 0.7000 - val_loss: 0.5422 - val_acc: 0.7333 - lr: 5.0000e-04
# Epoch 52: early stopping

# %% [markdown]
# ## #07. 학습 결과 평가

# %%
helper.tf_result_plot(result)

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 정확도: %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 정확도: %f" % (evaluate2[0], evaluate2[1]))
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.5878 - acc: 0.6964
# 최종 훈련 손실률: 0.587795, 최종 훈련 정확도: 0.696429
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5422 - acc: 0.7333
# 최종 검증 손실률: 0.542196, 최종 검증 정확도: 0.733333

# %% [markdown]
# ## #08. 학습 결과 적용

# %% [markdown]
# ### 훈련 데이터에 대한 예측 결과 산정

# %%
train_pred = model.predict(x_train)
data_count, case_count = train_pred.shape
print("%d개의 훈련 데이터가 %d개의 경우의 수를 갖는다." % (data_count, case_count))
print(train_pred)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 9/9 [==============================] - 0s 1ms/step
# 280개의 훈련 데이터가 1개의 경우의 수를 갖는다.
# [[0.38554093]
#  [0.51931155]
#  [0.13864656]
#  [0.2419784 ]
#  [0.19153245]
#  [0.13362187]
#  [0.48184246]
#  [0.49934697]
#  [0.362153  ]
#  [0.41089076]
#  [0.3303688 ]
#  [0.4293607 ]
#  [0.44028932]
#  [0.32314318]
#  [0.17047554]
#  [0.41127643]
#  [0.23604397]
#  [0.4654048 ]
#  [0.5495999 ]
#  [0.51532394]
#  [0.38427538]
#  [0.47824615]
#  [0.3368628 ]
#  [0.13068505]
#  [0.35980323]
#  [0.33280298]
#  [0.40008608]
#  [0.35501587]
#  [0.4387945 ]
#  [0.49010807]
#  [0.3479687 ]
#  [0.48957804]
#  [0.35516596]
#  [0.22181113]
#  [0.4010152 ]
#  [0.29020542]
#  [0.18011667]
#  [0.08990365]
#  [0.37665305]
#  [0.420658  ]
#  [0.41790304]
#  [0.14220761]
#  [0.4367291 ]
#  [0.3176258 ]
#  [0.3148981 ]
#  [0.4350925 ]
#  [0.08425802]
#  [0.28214034]
#  [0.43267396]
#  [0.14362486]
#  [0.42351413]
#  [0.35214335]
#  [0.45076567]
#  [0.14897004]
#  [0.4737499 ]
#  [0.52960235]
#  [0.35832244]
#  [0.42351413]
#  [0.13581197]
#  [0.3142334 ]
#  [0.34985974]
#  [0.41485518]
#  [0.2400361 ]
#  [0.35234338]
#  [0.23816204]
#  [0.24527948]
#  [0.4906381 ]
#  [0.2523836 ]
#  [0.19617832]
#  [0.34903085]
#  [0.30037504]
#  [0.2715336 ]
#  [0.33770666]
#  [0.3519808 ]
#  [0.40726748]
#  [0.44882336]
#  [0.43267396]
#  [0.4352152 ]
#  [0.4268631 ]
#  [0.3530576 ]
#  [0.38819304]
#  [0.31307837]
#  [0.17036109]
#  [0.15976419]
#  [0.32155812]
#  [0.21863496]
#  [0.3227293 ]
#  [0.4330314 ]
#  [0.1611076 ]
#  [0.5567414 ]
#  [0.42164743]
#  [0.08758801]
#  [0.11722586]
#  [0.31166154]
#  [0.44640306]
#  [0.310299  ]
#  [0.4181336 ]
#  [0.5980083 ]
#  [0.2604684 ]
#  [0.47298783]
#  [0.34250215]
#  [0.20386621]
#  [0.46447915]
#  [0.45948544]
#  [0.53110296]
#  [0.2546385 ]
#  [0.233136  ]
#  [0.269842  ]
#  [0.19893765]
#  [0.10179952]
#  [0.45039293]
#  [0.36403683]
#  [0.41952825]
#  [0.45417607]
#  [0.41001567]
#  [0.19811943]
#  [0.12900123]
#  [0.34859228]
#  [0.35749954]
#  [0.08727309]
#  [0.11798686]
#  [0.21583709]
#  [0.4328518 ]
#  [0.35474613]
#  [0.18074426]
#  [0.3970284 ]
#  [0.3568405 ]
#  [0.2688679 ]
#  [0.3545253 ]
#  [0.09140593]
#  [0.24107017]
#  [0.35776395]
#  [0.3919924 ]
#  [0.2355894 ]
#  [0.22124542]
#  [0.26492047]
#  [0.09954388]
#  [0.30959827]
#  [0.24079634]
#  [0.2085177 ]
#  [0.05438805]
#  [0.37194315]
#  [0.27550587]
#  [0.36576435]
#  [0.18064132]
#  [0.46374962]
#  [0.33806553]
#  [0.4122435 ]
#  [0.2073196 ]
#  [0.5363203 ]
#  [0.4338875 ]
#  [0.4665048 ]
#  [0.05733335]
#  [0.4821153 ]
#  [0.4224609 ]
#  [0.24104561]
#  [0.4185473 ]
#  [0.3394429 ]
#  [0.41139996]
#  [0.42359802]
#  [0.3631992 ]
#  [0.28737712]
#  [0.50869817]
#  [0.4822425 ]
#  [0.04082526]
#  [0.41385424]
#  [0.4833478 ]
#  [0.1359527 ]
#  [0.3648103 ]
#  [0.4087567 ]
#  [0.5230437 ]
#  [0.24958223]
#  [0.29776368]
#  [0.37783387]
#  [0.21087563]
#  [0.25929582]
#  [0.3924684 ]
#  [0.17882694]
#  [0.50113744]
#  [0.26203233]
#  [0.37566695]
#  [0.44329917]
#  [0.18834978]
#  [0.16943924]
#  [0.20991978]
#  [0.43157375]
#  [0.24298993]
#  [0.2421    ]
#  [0.23511538]
#  [0.17279805]
#  [0.3604869 ]
#  [0.36691207]
#  [0.4720937 ]
#  [0.40851173]
#  [0.24552475]
#  [0.16646259]
#  [0.1891011 ]
#  [0.17414767]
#  [0.3621959 ]
#  [0.47298783]
#  [0.28492048]
#  [0.4649413 ]
#  [0.43606433]
#  [0.3587578 ]
#  [0.24259995]
#  [0.44018924]
#  [0.10480717]
#  [0.16878557]
#  [0.41186473]
#  [0.06399708]
#  [0.32921964]
#  [0.34744203]
#  [0.47828174]
#  [0.5266734 ]
#  [0.51409256]
#  [0.12776333]
#  [0.23391294]
#  [0.348687  ]
#  [0.43230748]
#  [0.21849109]
#  [0.11613338]
#  [0.34250215]
#  [0.36080188]
#  [0.42807543]
#  [0.33865562]
#  [0.35404566]
#  [0.3599681 ]
#  [0.42527962]
#  [0.38845688]
#  [0.33529428]
#  [0.41275424]
#  [0.36372197]
#  [0.43411443]
#  [0.2692003 ]
#  [0.16780142]
#  [0.4439863 ]
#  [0.38756567]
#  [0.54171646]
#  [0.46408927]
#  [0.24386252]
#  [0.39177835]
#  [0.35406035]
#  [0.45194158]
#  [0.6292784 ]
#  [0.31034768]
#  [0.25439996]
#  [0.39338112]
#  [0.5363203 ]
#  [0.11021347]
#  [0.43726942]
#  [0.35926884]
#  [0.14100377]
#  [0.12737557]
#  [0.2088853 ]
#  [0.36896673]
#  [0.1543559 ]
#  [0.26891893]
#  [0.39112803]
#  [0.27974766]
#  [0.34885985]
#  [0.46884373]
#  [0.38427538]
#  [0.5275414 ]
#  [0.13034512]
#  [0.3884933 ]
#  [0.39430645]
#  [0.49787664]
#  [0.3315104 ]
#  [0.2632076 ]
#  [0.2171727 ]
#  [0.4817212 ]
#  [0.23415302]
#  [0.33907336]
#  [0.25256655]
#  [0.51018745]
#  [0.04210027]
#  [0.44768167]
#  [0.14897004]
#  [0.47392267]
#  [0.41816786]]

# %% [markdown]
# ### 검증 데이터에 대한 예측 결과 산정

# %%
test_pred = model.predict(x_test)
data_count, case_count = test_pred.shape
print("%d개의 검증 데이터가 %d개의 경우의 수를 갖는다." % (data_count, case_count))
#print(test_pred)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 120개의 검증 데이터가 1개의 경우의 수를 갖는다.

# %% [markdown]
# ### 결과 데이터 셋 구성

# %%
kdf = DataFrame({
    '결과값': y_train['합격여부'].values,
    '예측치' : np.round(train_pred.flatten()),
    '합격확률(%)': np.round(train_pred.flatten() * 100, 1)
})

kdf
# Out:
#     결과값  예측치    합격확률(%)
# 0     1  0.0  38.599998
# 1     1  1.0  51.900002
# 2     1  0.0  13.900000
# 3     0  0.0  24.200001
# 4     0  0.0  19.200001
# ..   ..  ...        ...
# 275   0  0.0   4.200000
# 276   0  0.0  44.799999
# 277   0  0.0  14.900000
# 278   1  0.0  47.400002
# 279   0  0.0  41.799999
#
# [280 rows x 3 columns]

# %% [markdown]
# #### 혼동행렬

# %%
cm = confusion_matrix(kdf['결과값'], kdf['예측치'])
tn, fp, fn, tp = cm.ravel()
print(tn, fp, fn, tp)
cmdf1 = DataFrame([[tn, fn], [fp, tp]], index=['True', 'False'], columns=['Negative', 'Positive'])
cmdf1
# Out:
# 183 6 79 12
#        Negative  Positive
# True        183        79
# False         6        12

# %% [markdown]
# | | Negative|Positive|
# |--|--|--|
# | True | TN | FP |
# | False | FN | TP |
#
# #### 각 항목의 의미
#
# | 구분 | 설명 |
# |--|--|
# | TN(True Negative, Negative Negative) | 실제는 Negative인데, Negative로 예측함. |
# | FP(False Positive, Negative Positive) | 실제는 Negative인데, Positive로 예측함. (Type1 Error) |
# | FN(False Negative, Positive Negative) | 실제는 Positive인데, Negative로 예측함. (Type2 Error) |
# | TP(True Positive, Positive Positive) | 실제는 Positive인데, Positive로 예측함. |

# %%
plt.figure(figsize=(5,3))
# 오차 행렬을 히트맵 그래프로 표현
# -> annot : 그래프의 각 칸에 수치값 출력
# -> fmt : 수치값 출력 format (여기서는 10진수)
# -> cmap : 색상맵 (<https://matplotlib.org/3.2.1/tutorials/colors/colormaps.html>)
sb.heatmap(cm, annot = True, fmt = 'd',cmap = 'Blues')
plt.xticks([0.5, 1.5], ['Negative', 'Positive'])
plt.yticks([0.5, 1.5], ['True', 'False'])
plt.xlabel('예측값')
plt.ylabel('결과값')
plt.show()

# %% [markdown]
# ### 평가지표

# %%
ras = roc_auc_score(kdf['결과값'], kdf['예측치'])

# 위양성율, 재현율, 임계값(사용안함)
fpr, tpr, thresholds = roc_curve(kdf['결과값'], kdf['예측치'])

plt.figure()
sb.lineplot(x=fpr, y=tpr)
sb.lineplot(x=[0,1], y=[0,1], color='red', linestyle=':', alpha=0.5)
plt.title('AUC={:.4f}'.format(ras))
plt.grid()
plt.show()
plt.close()

# %%
# 정확도
acc = accuracy_score(kdf['결과값'], kdf['예측치'])

# 정밀도
pre = precision_score(kdf['결과값'], kdf['예측치'])

# 재현율
recall = recall_score(kdf['결과값'], kdf['예측치'])

# F1 score
f1 = f1_score(kdf['결과값'], kdf['예측치'])

# 위양성율
fallout = fp / (fp + tn)

# 특이성
spe = 1 - fallout

result_df = DataFrame({'정확도(Accuracy)':[acc], '정밀도(Precision)':[pre], '재현율(Recall, TPR)':[recall], '위양성율(Fallout, FPR)': [fallout], '특이성(Specificity, TNR)':[spe], 'RAS': [ras], 'f1_score':[f1]})

helper.prettyPrint(result_df.T)
# Out:
# +--------------------------+----------+
# |                          |        0 |
# |--------------------------+----------|
# | 정확도(Accuracy)         | 0.696429 |
# | 정밀도(Precision)        | 0.666667 |
# | 재현율(Recall, TPR)      | 0.131868 |
# | 위양성율(Fallout, FPR)   | 0.031746 |
# | 특이성(Specificity, TNR) | 0.968254 |
# | RAS                      | 0.550061 |
# | f1_score                 | 0.220183 |
# +--------------------------+----------+

# %% [markdown]
# ### 분류 보고서
#
# - precision : 정밀도 (분류기가 참으로 분류한 항목 중에서 실제 데이터가 참인 비율)
# - recall : 재현율 (실제 참 중에서 분류기가 참으로 분류한 비율)
# - f1-score : 2*(Recall * Precision) / (Recall + Precision)
#     - Precision과 Recall의 조화평균
#     - 주로 분류 클래스 간 데이터가 심각한 불균형을 이루는 경우에 사용
#     - 정확도의 경우, 클래스가 데이터 분류가 균일하지 못하면 머신의 성능을 제대로 나타내줄 수 없기 때문에 F1을 사용한다.
# - support : 전체 데이터 수

# %%
report = classification_report(kdf['결과값'], kdf['예측치'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.97      0.81       189
#            1       0.67      0.13      0.22        91
#
#     accuracy                           0.70       280
#    macro avg       0.68      0.55      0.52       280
# weighted avg       0.69      0.70      0.62       280
