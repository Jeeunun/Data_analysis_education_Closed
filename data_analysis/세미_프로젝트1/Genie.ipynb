# %% [markdown]
# #### Genie

# %%
import datetime as dt
import pandas as pd
import time
import bs4
import requests

# %%
session = requests.Session()
session.headers.update({
    "Referer":"",
    "user-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
})

# %%
def transtime(x):
    return "".join(str(x).split(" ")[0].split("-"))

# %%
days = list(map(transtime,pd.date_range(pd.to_datetime('20230102'),dt.datetime.now(), freq='6D')))
page_dic={1:range(1,51),2:range(51,101)}
Genie = {}
Artists=[]

# %%
artist_url={}
for day in days:
    ranking_data=[]
    for page in page_dic:
        genie = session.get(f"https://www.genie.co.kr/chart/genre?ditc=W&ymd={day}&genrecode=M0100&pg={page}")
        time.sleep(2)
        soup = bs4.BeautifulSoup(genie.text)
        for n in page_dic[page]:
            data=soup.select(f".list.rank-{n}")[0]
            insert_data={}
            insert_data["ranking"]=data.select(".number")[0].text.split()[0]
            insert_data["title"]=data.select(".title.ellipsis")[0].text.strip()
            #아티스트 정보 삽입
            pre_data=data.select(".artist.ellipsis")
            insert_data["artist"]=pre_data[0].text.strip()
            url_num=pre_data[0].attrs["onclick"].split("(")[1].split(")")[0]
            artist_url[pre_data[0].text.strip()]='https://www.genie.co.kr/detail/artistInfo?xxnm='+url_num
            ranking_data.append(insert_data)
    Genie[day]=ranking_data

# %%
artist_url["(여자)아이들"]
# Out:
# 'https://www.genie.co.kr/detail/artistInfo?xxnm=80632010'

# %% [markdown]
# #### 가수 정보

# %%
for artist in artist_url:
    insert_data={"name":artist}
    art=session.get(artist_url[artist])
    time.sleep(2)
    soup=bs4.BeautifulSoup(art.text)
    for data in soup.select(".info-data li"):
        if data.select(".attr img")[0].attrs["alt"]=="활동유형":
            insert_data["type"]=data.select(".value")[0].text.strip()
            if insert_data["type"].find("그룹")!=-1:
                insert_data["member"]=[]
                for member in soup.select(".artist-member-list li .name"):
                    insert_data["member"].append(member.text.strip())
                insert_data["member"]=",".join(insert_data["member"])
    Artists.append(insert_data)
        # if data.attrs["alt"]=="활동유형":
            # print(data.select(".value")[0].text.strip())

# %%
Artists
# Out:
# [{'name': 'NewJeans',
#   'type': '여성/그룹',
#   'member': '민지 (MINJI),하니 (HANNI),다니엘 (DANIELLE),해린 (HAERIN),혜인 (HYEIN)'},
#  {'name': '윤하 (YOUNHA)', 'type': '여성/솔로'},
#  {'name': '이영지', 'type': '여성/솔로'},
#  {'name': 'LE SSERAFIM (르세라핌)',
#   'type': '여성/그룹',
#   'member': '미야와키 사쿠라,김채원,허윤진,카즈하,홍은채'},
#  {'name': 'IVE (아이브)',
#   'type': '여성/그룹',
#   'member': '안유진 (IVE),가을 (IVE),레이 (IVE),장원영 (IVE),리즈 (IVE),이서 (IVE)'},
#  {'name': '(여자)아이들',
#   'type': '여성/그룹',
#   'member': '미연 ((여자)아이들),민니 ((여자)아이들),전소연,슈화 ((여자)아이들),우기 ((여자)아이들)'},
#  {'name': '지코 (ZICO)', 'type': '남성/솔로'},
#  {'name': 'NCT DREAM',
#   'type': '남성/그룹',
#   'member': '천러 (CHENLE),런쥔 (RENJUN),재민 (JAEMIN),지성 (JISUNG),제노 (JENO),해찬 (HAECHAN),마크 (MARK)'},
#  {'name': '테이 (Tei)', 'type': '남성/솔로'},
#  {'name': '저스디스 (JUSTHIS) & R.Tee & 던말릭 (DON MALIK) & 허성현 (Huh) & KHAN & 맥대디 (Mckdaddy) & Los',
#   'type': '남성/프로젝트'},
#  {'name': 'BLACKPINK',
#   'type': '여성/그룹',
#   'member': '지수 (JISOO),제니 (JENNIE),로제 (ROSÉ),리사 (LISA)'},
#  {'name': 'WSG워너비 (가야G)',
#   'type': '여성/그룹',
#   'member': '이보람 (씨야),소연 (LABOUM),HYNN (박혜원),정지소'},
#  {'name': 'Crush', 'type': '남성/솔로'},
#  {'name': '김민석 (멜로망스)', 'type': '남성/솔로'},
#  {'name': '경서예지 & 전건호', 'type': '혼성/프로젝트'},
#  {'name': '#안녕', 'type': '남성/솔로'},
#  {'name': '주호', 'type': '남성/솔로'},
#  {'name': '경서', 'type': '여성/솔로'},
#  {'name': '카라 (KARA)', 'type': '여성/그룹', 'member': '박규리,한승연,구하라,허영지,니콜,강지영'},
#  {'name': "BE'O (비오)", 'type': '남성/솔로'},
#  {'name': 'WSG워너비 (4FIRE)',
#   'type': '여성/그룹',
#   'member': '나비 (Navi),SOLE (쏠),엄지윤,권진아'},
#  {'name': '10CM', 'type': '남성/솔로'},
#  {'name': '우디 (Woody)', 'type': '남성/솔로'},
#  {'name': '송하예', 'type': '여성/솔로'},
#  {'name': '10CM & BIG Naughty (서동현)', 'type': '남성/프로젝트'},
#  {'name': 'BIG Naughty (서동현)', 'type': '남성/솔로'},
#  {'name': '임영웅', 'type': '남성/솔로'},
#  {'name': '강민경 (다비치) & 잔나비 최정훈', 'type': '혼성/프로젝트'},
#  {'name': '싸이 (Psy)', 'type': '남성/솔로'},
#  {'name': '이무진', 'type': '남성/솔로'},
#  {'name': 'BIGBANG (빅뱅)', 'type': '남성/그룹', 'member': 'G-DRAGON,T.O.P,태양,대성'},
#  {'name': '임한별', 'type': '남성/솔로'},
#  {'name': '아이유 (IU)', 'type': '여성/솔로'},
#  {'name': '김승민', 'type': '남성/솔로'},
#  {'name': '잔나비', 'type': '남성/밴드'},
#  {'name': '볼빨간사춘기', 'type': '여성/솔로'},
#  {'name': '다비치', 'type': '여성/듀엣'},
#  {'name': '최유리', 'type': '여성/솔로'},
#  {'name': 'sokodomo', 'type': '남성/솔로'},
#  {'name': '방탄소년단', 'type': '남성/그룹', 'member': 'RM,SUGA,진,j-hope,지민,V,정국'},
#  {'name': 'aespa',
#   'type': '여성/그룹',
#   'member': '카리나 (KARINA),지젤 (GISELLE),윈터 (WINTER),닝닝 (NINGNING)'},
#  {'name': '던말릭 (DON MALIK)', 'type': '남성/솔로'},
#  {'name': '한동근', 'type': '남성/솔로'},
#  {'name': "소녀시대 (GIRLS' GENERATION)",
#   'type': '여성/그룹',
#   'member': '태연 (TAEYEON),써니 (SUNNY),티파니 (TIFFANY),효연 (HYOYEON),유리 (YURI),수영 (SOOYOUNG),윤아 (YOONA),서현 (SEOHYUN)'},
#  {'name': '그루비룸 (GroovyRoom) & 릴보이 (lIlBOI) & Blase (블라세) & 노윤하 & Polodared & Chillin Homie & Fleeky Bang',
#   'type': '남성/프로젝트'},
#  {'name': '디핵 (D-Hack) & PATEKO', 'type': '남성/프로젝트'},
#  {'name': '멜로망스 (MeloMance)', 'type': '남성/듀엣'},
#  {'name': '비비 (BIBI) & 윤미래', 'type': '여성/프로젝트'},
#  {'name': 'ITZY (있지)',
#   'type': '여성/그룹',
#   'member': '예지 (ITZY),리아 (ITZY),류진 (ITZY),채령 (ITZY),유나 (ITZY)'},
#  {'name': '허성현 (Huh)', 'type': '남성/솔로'},
#  {'name': '마크툽 (Maktub)', 'type': '남성/솔로'},
#  {'name': '케이시 (Kassy)', 'type': '여성/솔로'},
#  {'name': 'MSG워너비 (M.O.M)', 'type': '남성/그룹', 'member': '별루지,강창모,박재정,원슈타인'},
#  {'name': '태연 (TAEYEON)', 'type': '여성/솔로'},
#  {'name': 'AKMU (악뮤)', 'type': '혼성/듀엣'},
#  {'name': 'Red Velvet (레드벨벳)',
#   'type': '여성/그룹',
#   'member': '웬디 (WENDY),아이린 (IRENE),슬기 (SEULGI),조이 (JOY),예리 (YERI)'},
#  {'name': '21학번', 'type': '여성/솔로'},
#  {'name': '나연 (TWICE)', 'type': '여성/솔로'},
#  {'name': 'KHAN', 'type': '남성/솔로'},
#  {'name': '헤이즈 (Heize)', 'type': '여성/솔로'},
#  {'name': '주시크 (Joosiq)', 'type': '남성/솔로'},
#  {'name': '이석훈', 'type': '남성/솔로'},
#  {'name': '박재범', 'type': '남성/솔로'},
#  {'name': '탑현', 'type': '남성/솔로'},
#  {'name': 'Standing Egg (스탠딩 에그)',
#   'type': '남성/그룹',
#   'member': 'Egg1,Egg2,Egg3'},
#  {'name': '태양', 'type': '남성/솔로'},
#  {'name': '김연지', 'type': '여성/솔로'},
#  {'name': '호미들', 'type': '남성/그룹', 'member': 'Louie,CK,Chin'},
#  {'name': '창모 (CHANGMO)', 'type': '남성/솔로'},
#  {'name': '신예영', 'type': '여성/솔로'},
#  {'name': '양다일', 'type': '남성/솔로'},
#  {'name': '이예준', 'type': '여성/솔로'},
#  {'name': '에픽하이 (EPIK HIGH)', 'type': '남성/그룹', 'member': '타블로,미쓰라,DJ 투컷'},
#  {'name': '투모로우바이투게더', 'type': '남성/그룹', 'member': '수빈,연준,범규,태현,휴닝카이'},
#  {'name': '부석순 (SEVENTEEN)',
#   'type': '남성/그룹',
#   'member': '승관 (SEVENTEEN),도겸 (SEVENTEEN),호시 (SEVENTEEN)'},
#  {'name': '허각', 'type': '남성/솔로'},
#  {'name': 'DK (디셈버)', 'type': '남성/솔로'},
#  {'name': 'STAYC (스테이씨)',
#   'type': '여성/그룹',
#   'member': '수민 (SUMIN),시은 (SIEUN),아이사 (ISA),세은 (SEEUN),윤 (YOON),재이 (J)'},
#  {'name': 'H1-KEY (하이키)',
#   'type': '여성/그룹',
#   'member': '리이나 (하이키),서이 (하이키),옐 (하이키),휘서 (하이키)'},
#  {'name': '지아 (Zia)', 'type': '여성/솔로'},
#  {'name': '포맨 (4MEN)', 'type': '남성/그룹', 'member': '요셉 (포맨),하은 (포맨),한빈 (포맨)'},
#  {'name': 'Zior Park', 'type': '남성/솔로'},
#  {'name': '정효빈', 'type': '여성/솔로'},
#  {'name': '임창정', 'type': '남성/솔로'},
#  {'name': 'DAY6 (데이식스)', 'type': '남성/밴드'},
#  {'name': '이홍기 (FT아일랜드)', 'type': '남성/솔로'},
#  {'name': '먼데이 키즈 (Monday Kiz)', 'type': '남성/솔로'},
#  {'name': '주주 시크릿', 'type': '여성/그룹', 'member': ''},
#  {'name': '버스커 버스커 (Busker Busker)', 'type': '남성/밴드'},
#  {'name': '지수 (JISOO)', 'type': '여성/솔로'},
#  {'name': 'HIGH4 & 아이유', 'type': '혼성/프로젝트'},
#  {'name': 'NMIXX',
#   'type': '여성/그룹',
#   'member': '릴리 (NMIXX),해원 (NMIXX),설윤 (NMIXX),배이 (NMIXX),지우 (NMIXX),규진 (NMIXX)'},
#  {'name': '송하예 & 한빈 (포맨)', 'type': '혼성/프로젝트'},
#  {'name': '지민', 'type': '남성/솔로'},
#  {'name': 'FIFTY FIFTY', 'type': '여성/그룹', 'member': '새나,아란,키나,시오'},
#  {'name': 'Agust D', 'type': '남성/솔로'},
#  {'name': '던 (DAWN)', 'type': '남성/솔로'},
#  {'name': '세븐틴 (SEVENTEEN)',
#   'type': '남성/그룹',
#   'member': 'Vernon (SEVENTEEN),S.COUPS (SEVENTEEN),정한 (SEVENTEEN),조슈아 (SEVENTEEN),준 (SEVENTEEN),호시 (SEVENTEEN),원우 (SEVENTEEN),도겸 (SEVENTEEN),민규 (SEVENTEEN),디에잇 (SEVENTEEN),승관 (SEVENTEEN),디노 (SEVENTEEN),WOOZI (SEVENTEEN)'},
#  {'name': '박재정', 'type': '남성/솔로'},
#  {'name': '김필', 'type': '남성/솔로'},
#  {'name': '비투비',
#   'type': '남성/그룹',
#   'member': '서은광 (비투비),육성재 (비투비),이민혁 (HUTA),이창섭,임현식 (비투비),프니엘 (PENIEL)'},
#  {'name': 'V.O.S', 'type': '남성/그룹', 'member': '김경록 (V.O.S),최현준 (V.O.S),박지헌'},
#  {'name': '이채연', 'type': '여성/솔로'},
#  {'name': '폴킴', 'type': '남성/솔로'},
#  {'name': '전상근', 'type': '남성/솔로'},
#  {'name': 'Stray Kids (스트레이 키즈)',
#   'type': '남성/그룹',
#   'member': '방찬 (3RACHA),리노,창빈 (3RACHA),현진,한 (3RACHA),필릭스,승민,아이엔'},
#  {'name': '제이세라 (J-Cera)', 'type': '여성/솔로'},
#  {'name': '거미 (Gummy)', 'type': '여성/솔로'},
#  {'name': '노을', 'type': '남성/그룹', 'member': '강균성 (노을),이상곤 (노을),전우성 (노을),나성호'}]

# %% [markdown]
# 데이터프레임 만들기

# %% [markdown]
# ##### 노래차트정보

# %%
A = pd.DataFrame(Genie)
A
# Out:
#                                              20230102  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': '사건의 지평선', 'artist':...
# 2   {'ranking': '3', 'title': 'OMG', 'artist': 'Ne...
# 3   {'ranking': '4', 'title': 'Hype boy', 'artist'...
# 4   {'ranking': '5', 'title': 'NOT SORRY (Feat. pH...
# ..                                                ...
# 95  {'ranking': '96', 'title': '그 겨울이 잠든 거리에서', 'a...
# 96  {'ranking': '97', 'title': 'Weekend', 'artist'...
# 97  {'ranking': '98', 'title': '아버지', 'artist': '임...
# 98  {'ranking': '99', 'title': 'WITCH (Feat. 박재범 &...
# 99  {'ranking': '100', 'title': '오래된 노래', 'artist'...
#
#                                              20230108  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': '사건의 지평선', 'artist':...
# 2   {'ranking': '3', 'title': 'OMG', 'artist': 'Ne...
# 3   {'ranking': '4', 'title': 'Hype boy', 'artist'...
# 4   {'ranking': '5', 'title': 'NOT SORRY (Feat. pH...
# ..                                                ...
# 95  {'ranking': '96', 'title': '그 겨울이 잠든 거리에서', 'a...
# 96  {'ranking': '97', 'title': 'Weekend', 'artist'...
# 97  {'ranking': '98', 'title': '아버지', 'artist': '임...
# 98  {'ranking': '99', 'title': 'WITCH (Feat. 박재범 &...
# 99  {'ranking': '100', 'title': '오래된 노래', 'artist'...
#
#                                              20230114  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': '사건의 지평선', 'artist':...
# 2   {'ranking': '3', 'title': 'Hype boy', 'artist'...
# 3   {'ranking': '4', 'title': 'OMG', 'artist': 'Ne...
# 4   {'ranking': '5', 'title': 'ANTIFRAGILE', 'arti...
# ..                                                ...
# 95  {'ranking': '96', 'title': '오래된 노래', 'artist':...
# 96  {'ranking': '97', 'title': '가슴으로 운다', 'artist'...
# 97  {'ranking': '98', 'title': '사이렌 Remix (Feat. U...
# 98  {'ranking': '99', 'title': '아버지', 'artist': '임...
# 99  {'ranking': '100', 'title': 'METEOR', 'artist'...
#
#                                              20230120  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': 'OMG', 'artist': 'Ne...
# 2   {'ranking': '3', 'title': 'Hype boy', 'artist'...
# 3   {'ranking': '4', 'title': '사건의 지평선', 'artist':...
# 4   {'ranking': '5', 'title': 'ANTIFRAGILE', 'arti...
# ..                                                ...
# 95  {'ranking': '96', 'title': '오래된 노래', 'artist':...
# 96  {'ranking': '97', 'title': '문득', 'artist': 'BE...
# 97  {'ranking': '98', 'title': 'Weekend', 'artist'...
# 98  {'ranking': '99', 'title': '사이렌 Remix (Feat. U...
# 99  {'ranking': '100', 'title': '눈 (EYE) (Feat. BI...
#
#                                              20230126  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': 'OMG', 'artist': 'Ne...
# 2   {'ranking': '3', 'title': 'Hype boy', 'artist'...
# 3   {'ranking': '4', 'title': '사건의 지평선', 'artist':...
# 4   {'ranking': '5', 'title': 'ANTIFRAGILE', 'arti...
# ..                                                ...
# 95  {'ranking': '96', 'title': '사이렌 Remix (Feat. U...
# 96  {'ranking': '97', 'title': '문득', 'artist': 'BE...
# 97  {'ranking': '98', 'title': '라일락', 'artist': '아...
# 98  {'ranking': '99', 'title': 'GANADARA (Feat. 아이...
# 99  {'ranking': '100', 'title': 'Weekend', 'artist...
#
#                                              20230201  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': 'OMG', 'artist': 'Ne...
# 2   {'ranking': '3', 'title': 'Hype boy', 'artist'...
# 3   {'ranking': '4', 'title': '사건의 지평선', 'artist':...
# 4   {'ranking': '5', 'title': 'ANTIFRAGILE', 'arti...
# ..                                                ...
# 95  {'ranking': '96', 'title': '오래된 노래', 'artist':...
# 96  {'ranking': '97', 'title': '바보에게 바보가 (웹툰 '연애의 ...
# 97  {'ranking': '98', 'title': 'GANADARA (Feat. 아이...
# 98  {'ranking': '99', 'title': '사이렌 Remix (Feat. U...
# 99  {'ranking': '100', 'title': '라일락', 'artist': '...
#
#                                              20230207  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': 'OMG', 'artist': 'Ne...
# 2   {'ranking': '3', 'title': 'Hype boy', 'artist'...
# 3   {'ranking': '4', 'title': '사건의 지평선', 'artist':...
# 4   {'ranking': '5', 'title': 'Attention', 'artist...
# ..                                                ...
# 95  {'ranking': '96', 'title': 'LAW (Prod. by Czae...
# 96  {'ranking': '97', 'title': '바보에게 바보가 (웹툰 '연애의 ...
# 97  {'ranking': '98', 'title': '눈이 오잖아 (Feat. 헤이즈)...
# 98  {'ranking': '99', 'title': '문득', 'artist': 'BE...
# 99  {'ranking': '100', 'title': '위하여 (We Higher) (...
#
#                                              20230213  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': 'OMG', 'artist': 'Ne...
# 2   {'ranking': '3', 'title': 'Hype boy', 'artist'...
# 3   {'ranking': '4', 'title': '사건의 지평선', 'artist':...
# 4   {'ranking': '5', 'title': 'Attention', 'artist...
# ..                                                ...
# 95  {'ranking': '96', 'title': '바보에게 바보가 (웹툰 '연애의 ...
# 96  {'ranking': '97', 'title': 'POP!', 'artist': '...
# 97  {'ranking': '98', 'title': '문득', 'artist': 'BE...
# 98  {'ranking': '99', 'title': 'LAW (Prod. by Czae...
# 99  {'ranking': '100', 'title': '눈이 오잖아 (Feat. 헤이즈...
#
#                                              20230219  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...
# 1   {'ranking': '2', 'title': 'OMG', 'artist': 'Ne...
# 2   {'ranking': '3', 'title': 'Hype boy', 'artist'...
# 3   {'ranking': '4', 'title': '사건의 지평선', 'artist':...
# 4   {'ranking': '5', 'title': 'Attention', 'artist...
# ..                                                ...
# 95  {'ranking': '96', 'title': '바보에게 바보가 (웹툰 '연애의 ...
# 96  {'ranking': '97', 'title': 'POP!', 'artist': '...
# 97  {'ranking': '98', 'title': '문득', 'artist': 'BE...
# 98  {'ranking': '99', 'title': 'LAW (Prod. by Czae...
# 99  {'ranking': '100', 'title': '눈이 오잖아 (Feat. 헤이즈...
#
#                                              20230225  ...  \
# 0   {'ranking': '1', 'title': 'Ditto', 'artist': '...  ...
# 1   {'ranking': '2', 'title': 'OMG', 'artist': 'Ne...  ...
# 2   {'ranking': '3', 'title': 'Hype boy', 'artist'...  ...
# 3   {'ranking': '4', 'title': '사건의 지평선', 'artist':...  ...
# 4   {'ranking': '5', 'title': 'Attention', 'artist...  ...
# ..                                                ...  ...
# 95  {'ranking': '96', 'title': 'GANADARA (Feat. 아이...  ...
# 96  {'ranking': '97', 'title': '듣고 싶을까', 'artist':...  ...
# 97  {'ranking': '98', 'title': '혼자서 걸어요 (Prod. by ...  ...
# 98  {'ranking': '99', 'title': '니 번호가 뜨는 일', 'arti...  ...
# 99  {'ranking': '100', 'title': '문득', 'artist': 'B...  ...
#
#                                              20230502  \
# 0   {'ranking': '1', 'title': 'I AM', 'artist': 'I...
# 1   {'ranking': '2', 'title': 'Kitsch', 'artist': ...
# 2   {'ranking': '3', 'title': '꽃', 'artist': '지수 (...
# 3   {'ranking': '4', 'title': 'UNFORGIVEN (Feat. N...
# 4   {'ranking': '5', 'title': 'Ditto', 'artist': '...
# ..                                                ...
# 95  {'ranking': '96', 'title': 'INVU', 'artist': '...
# 96  {'ranking': '97', 'title': '청소 (여름날 우리 X 스탠딩 에...
# 97  {'ranking': '98', 'title': '그대를 알고', 'artist':...
# 98  {'ranking': '99', 'title': '예뻤어', 'artist': 'D...
# 99  {'ranking': '100', 'title': '우린 그렇게 사랑해서', 'ar...
#
#                                              20230508  \
# 0   {'ranking': '1', 'title': 'I AM', 'artist': 'I...
# 1   {'ranking': '2', 'title': 'Kitsch', 'artist': ...
# 2   {'ranking': '3', 'title': 'UNFORGIVEN (Feat. N...
# 3   {'ranking': '4', 'title': '꽃', 'artist': '지수 (...
# 4   {'ranking': '5', 'title': 'Ditto', 'artist': '...
# ..                                                ...
# 95  {'ranking': '96', 'title': '예뻤어', 'artist': 'D...
# 96  {'ranking': '97', 'title': '팡파레', 'artist': '다...
# 97  {'ranking': '98', 'title': 'Thirsty', 'artist'...
# 98  {'ranking': '99', 'title': '새벽에 걸려온 너의 전화는', '...
# 99  {'ranking': '100', 'title': '헤픈 우연', 'artist':...
#
#                                              20230514  \
# 0   {'ranking': '1', 'title': 'I AM', 'artist': 'I...
# 1   {'ranking': '2', 'title': 'Kitsch', 'artist': ...
# 2   {'ranking': '3', 'title': 'UNFORGIVEN (Feat. N...
# 3   {'ranking': '4', 'title': '꽃', 'artist': '지수 (...
# 4   {'ranking': '5', 'title': 'Ditto', 'artist': '...
# ..                                                ...
# 95  {'ranking': '96', 'title': '예뻤어', 'artist': 'D...
# 96  {'ranking': '97', 'title': '팡파레', 'artist': '다...
# 97  {'ranking': '98', 'title': 'Thirsty', 'artist'...
# 98  {'ranking': '99', 'title': '새벽에 걸려온 너의 전화는', '...
# 99  {'ranking': '100', 'title': '헤픈 우연', 'artist':...
#
#                                              20230520  \
# 0   {'ranking': '1', 'title': 'I AM', 'artist': 'I...
# 1   {'ranking': '2', 'title': 'Spicy', 'artist': '...
# 2   {'ranking': '3', 'title': 'Kitsch', 'artist': ...
# 3   {'ranking': '4', 'title': 'UNFORGIVEN (Feat. N...
# 4   {'ranking': '5', 'title': '퀸카 (Queencard)', 'a...
# ..                                                ...
# 95  {'ranking': '96', 'title': '예뻤어', 'artist': 'D...
# 96  {'ranking': '97', 'title': '헤픈 우연', 'artist': ...
# 97  {'ranking': '98', 'title': '찰나가 영원이 될 때 (The E...
# 98  {'ranking': '99', 'title': 'Thirsty', 'artist'...
# 99  {'ranking': '100', 'title': '바라만 본다', 'artist'...
#
#                                              20230526  \
# 0   {'ranking': '1', 'title': 'I AM', 'artist': 'I...
# 1   {'ranking': '2', 'title': '퀸카 (Queencard)', 'a...
# 2   {'ranking': '3', 'title': 'Spicy', 'artist': '...
# 3   {'ranking': '4', 'title': 'Kitsch', 'artist': ...
# 4   {'ranking': '5', 'title': 'UNFORGIVEN (Feat. N...
# ..                                                ...
# 95  {'ranking': '96', 'title': '바라만 본다', 'artist':...
# 96  {'ranking': '97', 'title': '찰나가 영원이 될 때 (The E...
# 97  {'ranking': '98', 'title': 'Celebrity', 'artis...
# 98  {'ranking': '99', 'title': '예뻤어', 'artist': 'D...
# 99  {'ranking': '100', 'title': 'F*ck My Life', 'a...
#
#                                              20230601  \
# 0   {'ranking': '1', 'title': '퀸카 (Queencard)', 'a...
# 1   {'ranking': '2', 'title': 'I AM', 'artist': 'I...
# 2   {'ranking': '3', 'title': 'Spicy', 'artist': '...
# 3   {'ranking': '4', 'title': 'Kitsch', 'artist': ...
# 4   {'ranking': '5', 'title': 'UNFORGIVEN (Feat. N...
# ..                                                ...
# 95  {'ranking': '96', 'title': 'strawberry moon', ...
# 96  {'ranking': '97', 'title': '사랑하지 않아서 그랬어', 'ar...
# 97  {'ranking': '98', 'title': '다시 사랑한다면 (니글니글 버터플...
# 98  {'ranking': '99', 'title': '바라만 본다', 'artist':...
# 99  {'ranking': '100', 'title': '한강에서 (Feat. BIG N...
#
#                                              20230607  \
# 0   {'ranking': '1', 'title': '퀸카 (Queencard)', 'a...
# 1   {'ranking': '2', 'title': 'I AM', 'artist': 'I...
# 2   {'ranking': '3', 'title': 'Spicy', 'artist': '...
# 3   {'ranking': '4', 'title': 'Kitsch', 'artist': ...
# 4   {'ranking': '5', 'title': 'UNFORGIVEN (Feat. N...
# ..                                                ...
# 95  {'ranking': '96', 'title': '떠나보낼 준비해 둘걸 그랬어', ...
# 96  {'ranking': '97', 'title': '밤이 무서워요 (Lonely Ni...
# 97  {'ranking': '98', 'title': '다시 사랑한다면 (니글니글 버터플...
# 98  {'ranking': '99', 'title': '발걸음', 'artist': 'D...
# 99  {'ranking': '100', 'title': '안녕이라고 말하지마', 'art...
#
#                                              20230613  \
# 0   {'ranking': '1', 'title': '퀸카 (Queencard)', 'a...
# 1   {'ranking': '2', 'title': 'I AM', 'artist': 'I...
# 2   {'ranking': '3', 'title': 'Spicy', 'artist': '...
# 3   {'ranking': '4', 'title': 'Kitsch', 'artist': ...
# 4   {'ranking': '5', 'title': 'UNFORGIVEN (Feat. N...
# ..                                                ...
# 95  {'ranking': '96', 'title': '떠나보낼 준비해 둘걸 그랬어', ...
# 96  {'ranking': '97', 'title': '헤어질 결심', 'artist':...
# 97  {'ranking': '98', 'title': 'Polaroid', 'artist...
# 98  {'ranking': '99', 'title': 'Nostalgia', 'artis...
# 99  {'ranking': '100', 'title': 'Love Me Like This...
#
#                                              20230619  \
# 0   {'ranking': '1', 'title': '퀸카 (Queencard)', 'a...
# 1   {'ranking': '2', 'title': 'I AM', 'artist': 'I...
# 2   {'ranking': '3', 'title': 'Spicy', 'artist': '...
# 3   {'ranking': '4', 'title': '이브, 프시케 그리고 푸른 수염의 ...
# 4   {'ranking': '5', 'title': 'Kitsch', 'artist': ...
# ..                                                ...
# 95  {'ranking': '96', 'title': 'Love story', 'arti...
# 96  {'ranking': '97', 'title': 'Celebrity', 'artis...
# 97  {'ranking': '98', 'title': '어떻게 이별까지 사랑하겠어, 널 ...
# 98  {'ranking': '99', 'title': '에잇 (Prod. & Feat. ...
# 99  {'ranking': '100', 'title': '다시 사랑한다면 (니글니글 버터...
#
#                                              20230625
# 0   {'ranking': '1', 'title': '퀸카 (Queencard)', 'a...
# 1   {'ranking': '2', 'title': 'I AM', 'artist': 'I...
# 2   {'ranking': '3', 'title': 'Spicy', 'artist': '...
# 3   {'ranking': '4', 'title': '이브, 프시케 그리고 푸른 수염의 ...
# 4   {'ranking': '5', 'title': 'Kitsch', 'artist': ...
# ..                                                ...
# 95  {'ranking': '96', 'title': 'Love story', 'arti...
# 96  {'ranking': '97', 'title': 'Celebrity', 'artis...
# 97  {'ranking': '98', 'title': '어떻게 이별까지 사랑하겠어, 널 ...
# 98  {'ranking': '99', 'title': '에잇 (Prod. & Feat. ...
# 99  {'ranking': '100', 'title': '다시 사랑한다면 (니글니글 버터...
#
# [100 rows x 30 columns]

# %% [markdown]
# ##### 가수 정보

# %%
B = pd.DataFrame(Artists)
B
# Out:
#                      name   type  \
# 0                NewJeans  여성/그룹
# 1             윤하 (YOUNHA)  여성/솔로
# 2                     이영지  여성/솔로
# 3      LE SSERAFIM (르세라핌)  여성/그룹
# 4               IVE (아이브)  여성/그룹
# ..                    ...    ...
# 104                   전상근  남성/솔로
# 105  Stray Kids (스트레이 키즈)  남성/그룹
# 106         제이세라 (J-Cera)  여성/솔로
# 107            거미 (Gummy)  여성/솔로
# 108                    노을  남성/그룹
#
#                                                 member
# 0    민지 (MINJI),하니 (HANNI),다니엘 (DANIELLE),해린 (HAERI...
# 1                                                  NaN
# 2                                                  NaN
# 3                             미야와키 사쿠라,김채원,허윤진,카즈하,홍은채
# 4    안유진 (IVE),가을 (IVE),레이 (IVE),장원영 (IVE),리즈 (IVE)...
# ..                                                 ...
# 104                                                NaN
# 105  방찬 (3RACHA),리노,창빈 (3RACHA),현진,한 (3RACHA),필릭스,승...
# 106                                                NaN
# 107                                                NaN
# 108                     강균성 (노을),이상곤 (노을),전우성 (노을),나성호
#
# [109 rows x 3 columns]

# %%
# 1) 패키지 참조
import pymysql
from sqlalchemy import create_engine
from pandas import DataFrame
from pandas import read_sql, read_sql_table

import MySQLdb

# %%
# 2) 접속 문자열 생성
# mysql+mysqldb://계정이름:비밀번호@포트번호/데이터베이스이름?charset=인코딩
conStr = "mysql+mysqldb://root:1234@127.0.0.1:3406/semi_project?charset=utf8"
conStr
# Out:
# 'mysql+mysqldb://root:1234@127.0.0.1:3406/semi_project?charset=utf8'

# %%
# 3) 데이터베이스 접속
engine = create_engine(conStr)
conn = engine.connect()

# %%
B.to_sql(name='artist_table',con=conn, if_exists='append', index=False)
# Out:
# 109

# %%
for day in Genie:
    for i in range(len(Genie[day])):
        Genie[day][i]['day']=day
    pd.DataFrame(Genie[day]).to_sql(name='Genie',con=conn, if_exists='append', index=False)
